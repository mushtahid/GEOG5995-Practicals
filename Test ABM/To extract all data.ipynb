# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 100
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
    
    for i in range(len(wolves)):
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print(f"min_dist a = {min_dist}, sheep {sheep_count}, wolf {i}")
            elif distance <= eat_dist:
                wolves[i].store += j.store
                print('Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i].y, wolves[i].x)
                j.store = 0
                sheep.remove(j)
                break
            else:
                continue
        if closest_sheep != None:
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
        else:
            wolves[i].move
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    for i in range(len(sheep)):
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print(f"***Iteration no {a}***")
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***Iteration no 0***
# min_dist a = 40.0, sheep 1, wolf 1
# min_dist a = 28.0178514522438, sheep 8, wolf 4
# 0 Sheep y=293, x=15, store=10
# 1 Sheep y=218, x=246, store=10
# 2 Sheep y=294, x=8, store=10
# 3 Sheep y=106, x=237, store=10
# 4 Sheep y=250, x=143, store=10
# 5 Sheep y=83, x=16, store=10
# 6 Sheep y=267, x=249, store=10
# 7 Sheep y=168, x=39, store=10
# 8 Sheep y=126, x=183, store=10
# 9 Sheep y=23, x=216, store=10
# ***Iteration no 0***
# min_dist a = 18.601075237738275, sheep 1, wolf 1
# min_dist a = 15.074813431681335, sheep 8, wolf 4
# 0 Sheep y=294, x=16, store=20
# 1 Sheep y=219, x=245, store=20
# 2 Sheep y=293, x=7, store=20
# 3 Sheep y=105, x=238, store=20
# 4 Sheep y=249, x=144, store=20
# 5 Sheep y=82, x=17, store=20
# 6 Sheep y=266, x=250, store=20
# 7 Sheep y=169, x=38, store=20
# 8 Sheep y=125, x=184, store=20
# 9 Sheep y=24, x=217, store=20
# ***Iteration no 1***
# min_dist a = 9.192388155425117, sheep 1, wolf 1
# min_dist a = 8.503675675847475, sheep 8, wolf 4
# 0 Sheep y=295, x=15, store=30
# 1 Sheep y=220, x=246, store=30
# 2 Sheep y=294, x=8, store=30
# 3 Sheep y=104, x=237, store=30
# 4 Sheep y=248, x=145, store=30
# 5 Sheep y=83, x=18, store=30
# 6 Sheep y=267, x=249, store=30
# 7 Sheep y=170, x=39, store=30
# 8 Sheep y=126, x=185, store=30
# 9 Sheep y=23, x=218, store=30
# ***Iteration no 2***
# min_dist a = 6.010407640085654, sheep 1, wolf 1
# Sheep eaten 8 y=126, x=185, store=30 by Wolf 4 129.25 183.875
# 0 Sheep y=294, x=14, store=40
# 1 Sheep y=221, x=245, store=40
# 2 Sheep y=293, x=7, store=40
# 3 Sheep y=103, x=238, store=40
# 4 Sheep y=249, x=146, store=40
# 5 Sheep y=84, x=19, store=40
# 6 Sheep y=266, x=248, store=40
# 7 Sheep y=171, x=40, store=40
# 8 Sheep y=24, x=217, store=40
# ***Iteration no 3***
# Sheep eaten 1 y=221, x=245, store=40 by Wolf 1 217.875 243.875
# 0 Sheep y=295, x=15, store=50
# 1 Sheep y=294, x=6, store=50
# 2 Sheep y=104, x=239, store=50
# 3 Sheep y=250, x=147, store=50
# 4 Sheep y=83, x=20, store=50
# 5 Sheep y=267, x=249, store=50
# 6 Sheep y=170, x=41, store=50
# 7 Sheep y=23, x=216, store=50
# ***Iteration no 4***
# min_dist a = 49.39161112982649, sheep 5, wolf 1
# 0 Sheep y=294, x=16, store=60
# 1 Sheep y=293, x=5, store=60
# 2 Sheep y=105, x=240, store=60
# 3 Sheep y=249, x=146, store=60
# 4 Sheep y=82, x=19, store=60
# 5 Sheep y=266, x=250, store=60
# 6 Sheep y=169, x=40, store=60
# 7 Sheep y=24, x=215, store=60
# ***Iteration no 5***
# min_dist a = 23.830291909668247, sheep 5, wolf 1
# 0 Sheep y=293, x=15, store=70
# 1 Sheep y=294, x=4, store=70
# 2 Sheep y=104, x=239, store=70
# 3 Sheep y=248, x=147, store=70
# 4 Sheep y=81, x=20, store=70
# 5 Sheep y=265, x=249, store=70
# 6 Sheep y=170, x=41, store=70
# 7 Sheep y=25, x=216, store=70
# ***Iteration no 6***
# min_dist a = 10.809519097767486, sheep 5, wolf 1
# 0 Sheep y=294, x=16, store=80
# 1 Sheep y=293, x=3, store=80
# 2 Sheep y=105, x=238, store=80
# 3 Sheep y=247, x=146, store=80
# 4 Sheep y=82, x=19, store=80
# 5 Sheep y=264, x=250, store=80
# 6 Sheep y=171, x=40, store=80
# 7 Sheep y=24, x=217, store=80
# ***Iteration no 7***
# Sheep eaten 5 y=264, x=250, store=80 by Wolf 1 259.609375 248.609375
# 0 Sheep y=293, x=15, store=90
# 1 Sheep y=292, x=2, store=90
# 2 Sheep y=106, x=239, store=90
# 3 Sheep y=248, x=147, store=90
# 4 Sheep y=83, x=20, store=90
# 5 Sheep y=170, x=39, store=90
# 6 Sheep y=25, x=216, store=90
# ***Iteration no 8***
# 0 Sheep y=292, x=14, store=100
# 1 Sheep y=293, x=3, store=100
# 2 Sheep y=107, x=238, store=100
# 3 Sheep y=249, x=148, store=100
# 4 Sheep y=84, x=21, store=100
# 5 Sheep y=169, x=38, store=100
# 6 Sheep y=24, x=217, store=100
# ***Iteration no 9***
# 0 Sheep y=291, x=13, store=110
# 1 Sheep y=292, x=2, store=110
# 2 Sheep y=108, x=237, store=110
# 3 Sheep y=248, x=149, store=110
# 4 Sheep y=85, x=22, store=110
# 5 Sheep y=168, x=37, store=110
# 5 Sheep y=169, x=36, store=660
# ***Iteration no 65***
# 0 Sheep y=289, x=17, store=670
# 1 Sheep y=288, x=2, store=670
# 2 Sheep y=100, x=239, store=670
# 3 Sheep y=242, x=143, store=670
# 4 Sheep y=83, x=20, store=670
# 5 Sheep y=168, x=35, store=670
# ***Iteration no 66***
# 0 Sheep y=290, x=16, store=680
# 1 Sheep y=287, x=1, store=680
# 2 Sheep y=101, x=238, store=680
# 3 Sheep y=241, x=142, store=680
# 4 Sheep y=82, x=19, store=680
# 5 Sheep y=169, x=34, store=680
# ***Iteration no 67***
# 0 Sheep y=291, x=17, store=690
# 1 Sheep y=286, x=0, store=690
# 2 Sheep y=100, x=239, store=690
# 3 Sheep y=240, x=143, store=690
# 4 Sheep y=83, x=18, store=690
# 5 Sheep y=168, x=35, store=690
# ***Iteration no 68***
# 0 Sheep y=290, x=18, store=700
# 1 Sheep y=287, x=1, store=700
# 2 Sheep y=101, x=238, store=700
# 3 Sheep y=241, x=142, store=700
# 4 Sheep y=84, x=19, store=700
# 5 Sheep y=169, x=34, store=700
# ***Iteration no 69***
# 0 Sheep y=289, x=17, store=710
# 1 Sheep y=288, x=0, store=710
# 2 Sheep y=102, x=239, store=710
# 3 Sheep y=242, x=141, store=710
# 4 Sheep y=83, x=20, store=710
# 5 Sheep y=168, x=33, store=710
# ***Iteration no 70***
# 0 Sheep y=288, x=18, store=720
# 1 Sheep y=287, x=299, store=720
# 2 Sheep y=103, x=238, store=720
# 3 Sheep y=241, x=142, store=720
# 4 Sheep y=84, x=21, store=720
# 5 Sheep y=167, x=34, store=720
# ***Iteration no 71***
# 0 Sheep y=289, x=19, store=730
# 1 Sheep y=288, x=298, store=730
# 2 Sheep y=104, x=239, store=730
# 3 Sheep y=242, x=143, store=730
# 4 Sheep y=85, x=22, store=730
# 5 Sheep y=166, x=33, store=730
# ***Iteration no 72***
# 0 Sheep y=288, x=18, store=740
# 1 Sheep y=287, x=299, store=740
# 2 Sheep y=103, x=238, store=740
# 3 Sheep y=241, x=142, store=740
# 4 Sheep y=84, x=23, store=740
# 5 Sheep y=165, x=34, store=740
# ***Iteration no 73***
# 0 Sheep y=289, x=17, store=750
# 1 Sheep y=286, x=0, store=750
# 2 Sheep y=102, x=239, store=750
# 3 Sheep y=242, x=141, store=750
# 4 Sheep y=85, x=24, store=750
# 5 Sheep y=164, x=33, store=750
# ***Iteration no 74***
# 0 Sheep y=288, x=18, store=760
# 1 Sheep y=287, x=1, store=760
# 2 Sheep y=101, x=238, store=760
# 3 Sheep y=243, x=142, store=760
# 4 Sheep y=84, x=25, store=760
# 5 Sheep y=165, x=32, store=760
# ***Iteration no 75***
# 0 Sheep y=287, x=17, store=770
# 1 Sheep y=286, x=2, store=770
# 2 Sheep y=100, x=237, store=770
# 3 Sheep y=244, x=143, store=770
# 4 Sheep y=85, x=24, store=770
# 5 Sheep y=166, x=31, store=770
# ***Iteration no 76***
# 0 Sheep y=286, x=16, store=780
# 1 Sheep y=285, x=3, store=780
# 2 Sheep y=101, x=238, store=780
# 3 Sheep y=245, x=144, store=780
# 4 Sheep y=84, x=25, store=780
# 5 Sheep y=165, x=30, store=780
# ***Iteration no 77***
# 0 Sheep y=287, x=17, store=790
# 1 Sheep y=286, x=2, store=790
# 2 Sheep y=102, x=239, store=790
# 3 Sheep y=244, x=145, store=790
# 4 Sheep y=85, x=26, store=790
# 5 Sheep y=166, x=31, store=790
# ***Iteration no 78***
# 0 Sheep y=286, x=16, store=800
# 1 Sheep y=287, x=1, store=800
# 2 Sheep y=101, x=238, store=800
# 3 Sheep y=243, x=144, store=800
# 4 Sheep y=84, x=25, store=800
# 5 Sheep y=165, x=30, store=800
# ***Iteration no 79***
# 0 Sheep y=287, x=17, store=810
# 1 Sheep y=286, x=0, store=810
# 2 Sheep y=100, x=237, store=810
# 3 Sheep y=244, x=145, store=810
# 4 Sheep y=83, x=24, store=810
# 5 Sheep y=166, x=31, store=810
# ***Iteration no 80***
# 0 Sheep y=288, x=18, store=820
# 1 Sheep y=285, x=1, store=820
# 2 Sheep y=99, x=236, store=820
# 3 Sheep y=245, x=146, store=820
# 4 Sheep y=84, x=23, store=820
# 5 Sheep y=165, x=30, store=820
# ***Iteration no 81***
# 0 Sheep y=287, x=17, store=830
# 1 Sheep y=286, x=2, store=830
# 2 Sheep y=98, x=235, store=830
# 3 Sheep y=244, x=145, store=830
# 4 Sheep y=85, x=24, store=830
# 5 Sheep y=166, x=29, store=830
# ***Iteration no 82***
# 0 Sheep y=286, x=18, store=840
# 1 Sheep y=287, x=3, store=840
# 2 Sheep y=97, x=236, store=840
# 3 Sheep y=245, x=146, store=840
# 4 Sheep y=86, x=23, store=840
# 5 Sheep y=167, x=28, store=840
# ***Iteration no 83***
# 0 Sheep y=287, x=19, store=850
# 1 Sheep y=288, x=2, store=850
# 2 Sheep y=98, x=235, store=850
# 3 Sheep y=246, x=145, store=850
# 4 Sheep y=87, x=22, store=850
# 5 Sheep y=168, x=27, store=850
# ***Iteration no 84***
# 0 Sheep y=286, x=20, store=860
# 1 Sheep y=289, x=1, store=860
# 2 Sheep y=97, x=234, store=860
# 3 Sheep y=245, x=144, store=860
# 4 Sheep y=88, x=21, store=860
# 5 Sheep y=167, x=28, store=860
# ***Iteration no 85***
# 0 Sheep y=287, x=21, store=870
# 1 Sheep y=290, x=0, store=870
# 2 Sheep y=98, x=235, store=870
# 3 Sheep y=246, x=145, store=870
# 4 Sheep y=87, x=22, store=870
# 5 Sheep y=166, x=27, store=870
# ***Iteration no 86***
# 0 Sheep y=286, x=20, store=880
# 1 Sheep y=289, x=299, store=880
# 2 Sheep y=97, x=234, store=880
# 3 Sheep y=247, x=146, store=880
# 4 Sheep y=86, x=23, store=880
# 5 Sheep y=165, x=26, store=880
# ***Iteration no 87***
# 0 Sheep y=285, x=19, store=890
# 1 Sheep y=290, x=298, store=890
# 2 Sheep y=96, x=235, store=890
# 3 Sheep y=246, x=147, store=890
# 4 Sheep y=87, x=24, store=890
# 5 Sheep y=166, x=27, store=890
# ***Iteration no 88***
# 0 Sheep y=286, x=18, store=900
# 1 Sheep y=291, x=297, store=900
