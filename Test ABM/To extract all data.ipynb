# %% [markdown]
# with break

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('.........................................')
    print('_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
            elif distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('_________________________________________')
                break
        if closest_sheep != None:
            print('YCL before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('YCL after', closest_sheep, 'Wolf', i, wolves[i])
            print('.........................................')
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('.........................................')
    print('_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# .........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# .........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# .........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# .........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# .........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# .........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# .........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# .........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# .........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# YCL before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# YCL after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# YCL before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# YCL after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# .........................................
# _________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# .........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# .........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# .........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# .........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# .........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# .........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# .........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# .........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# .........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# YCL before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# YCL after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# .........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# .........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# YCL before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# YCL after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# .........................................
# _________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# .........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# .........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# .........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# .........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# .........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# .........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# .........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# .........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# .........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# .........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# YCL before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# YCL after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# YCL before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# YCL after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# .........................................
# _________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# .........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# .........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# .........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# .........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# .........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# .........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# .........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# .........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# .........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# YCL before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# YCL after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# .........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# _________________________________________
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=185.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=15, store=50
# .........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=220, x=246, store=50
# .........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=294, x=10, store=50
# .........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=106, x=239, store=50
# .........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=248, x=141, store=50
# .........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=18, store=50
# .........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# .........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=37, store=50
# .........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=25, x=218, store=50
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=220, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=220, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# _________________________________________
# Else activate before by Wolf 1 y=216.9375, x=245.1875, store=50
# Else activate after by Wolf 1 y=217.9375, x=246.1875, store=50
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=234, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=185.5, store=40
# Else activate before by Wolf 4 y=129.875, x=185.5, store=40
# Else activate after by Wolf 4 y=128.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=50
# 0 Sheep-after moving+eating y=294, x=14, store=60
# .........................................
# 1 Sheep-before moving+eating y=294, x=10, store=50
# 1 Sheep-after moving+eating y=293, x=11, store=60
# .........................................
# 2 Sheep-before moving+eating y=106, x=239, store=50
# 2 Sheep-after moving+eating y=107, x=238, store=60
# .........................................
# 3 Sheep-before moving+eating y=248, x=141, store=50
# 3 Sheep-after moving+eating y=247, x=142, store=60
# .........................................
# 4 Sheep-before moving+eating y=83, x=18, store=50
# 4 Sheep-after moving+eating y=82, x=17, store=60
# .........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=264, x=250, store=60
# .........................................
# 6 Sheep-before moving+eating y=166, x=37, store=50
# 6 Sheep-after moving+eating y=167, x=38, store=60
# .........................................
# 7 Sheep-before moving+eating y=25, x=218, store=50
# 7 Sheep-after moving+eating y=26, x=219, store=60
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# .........................................
# 1 Wolf - before moving/eating y=217.9375, x=246.1875, store=50
# >>> min_dist = 46.22000716681035 Sheep 5 y=264, x=250, store=60 by Wolf 1 y=217.9375, x=246.1875, store=50
# YCL before y=264, x=250, store=60 Wolf 1 y=217.9375, x=246.1875, store=50
# YCL after y=264, x=250, store=60 Wolf 1 y=240.96875, x=248.09375, store=50
# .........................................
# 2 Wolf - before moving/eating y=144, x=133, store=0
# Else activate before by Wolf 2 y=144, x=133, store=0
# Else activate after by Wolf 2 y=143, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=86, store=0
# Else activate before by Wolf 3 y=234, x=86, store=0
# Else activate after by Wolf 3 y=235, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=128.875, x=184.5, store=40
# Else activate before by Wolf 4 y=128.875, x=184.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=294, x=14, store=60
# 0 Sheep-after moving+eating y=295, x=15, store=70
# .........................................
# 1 Sheep-before moving+eating y=293, x=11, store=60
# 1 Sheep-after moving+eating y=294, x=10, store=70
# .........................................
# 2 Sheep-before moving+eating y=107, x=238, store=60
# 2 Sheep-after moving+eating y=108, x=239, store=70
# .........................................
# 3 Sheep-before moving+eating y=247, x=142, store=60
# 3 Sheep-after moving+eating y=248, x=143, store=70
# .........................................
# 4 Sheep-before moving+eating y=82, x=17, store=60
# 4 Sheep-after moving+eating y=81, x=16, store=70
# .........................................
# 5 Sheep-before moving+eating y=264, x=250, store=60
# 5 Sheep-after moving+eating y=263, x=251, store=70
# .........................................
# 6 Sheep-before moving+eating y=167, x=38, store=60
# 6 Sheep-after moving+eating y=166, x=37, store=70
# .........................................
# 7 Sheep-before moving+eating y=26, x=219, store=60
# 7 Sheep-after moving+eating y=25, x=218, store=70
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=74, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=240.96875, x=248.09375, store=50
# >>> min_dist = 22.222112087400692 Sheep 5 y=263, x=251, store=70 by Wolf 1 y=240.96875, x=248.09375, store=50
# YCL before y=263, x=251, store=70 Wolf 1 y=240.96875, x=248.09375, store=50
# YCL after y=263, x=251, store=70 Wolf 1 y=251.984375, x=249.546875, store=50
# .........................................
# 2 Wolf - before moving/eating y=143, x=132, store=0
# Else activate before by Wolf 2 y=143, x=132, store=0
# Else activate after by Wolf 2 y=142, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=235, x=85, store=0
# Else activate before by Wolf 3 y=235, x=85, store=0
# Else activate after by Wolf 3 y=236, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=70
# 0 Sheep-after moving+eating y=296, x=16, store=80
# .........................................
# 1 Sheep-before moving+eating y=294, x=10, store=70
# 1 Sheep-after moving+eating y=295, x=11, store=80
# .........................................
# 2 Sheep-before moving+eating y=108, x=239, store=70
# 2 Sheep-after moving+eating y=107, x=238, store=80
# .........................................
# 3 Sheep-before moving+eating y=248, x=143, store=70
# 3 Sheep-after moving+eating y=249, x=142, store=80
# .........................................
# 4 Sheep-before moving+eating y=81, x=16, store=70
# 4 Sheep-after moving+eating y=80, x=17, store=80
# .........................................
# 5 Sheep-before moving+eating y=263, x=251, store=70
# 5 Sheep-after moving+eating y=262, x=252, store=80
# .........................................
# 6 Sheep-before moving+eating y=166, x=37, store=70
# 6 Sheep-after moving+eating y=165, x=36, store=80
# .........................................
# 7 Sheep-before moving+eating y=25, x=218, store=70
# 7 Sheep-after moving+eating y=26, x=219, store=80
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=182, store=0
# Else activate before by Wolf 0 y=74, x=182, store=0
# Else activate after by Wolf 0 y=73, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=251.984375, x=249.546875, store=50
# >>> min_dist = 10.31167136822397 Sheep 5 y=262, x=252, store=80 by Wolf 1 y=251.984375, x=249.546875, store=50
# YCL before y=262, x=252, store=80 Wolf 1 y=251.984375, x=249.546875, store=50
# YCL after y=262, x=252, store=80 Wolf 1 y=256.9921875, x=250.7734375, store=50
# .........................................
# 2 Wolf - before moving/eating y=142, x=133, store=0
# Else activate before by Wolf 2 y=142, x=133, store=0
# Else activate after by Wolf 2 y=141, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=236, x=86, store=0
# Else activate before by Wolf 3 y=236, x=86, store=0
# Else activate after by Wolf 3 y=235, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=80
# 0 Sheep-after moving+eating y=295, x=17, store=90
# .........................................
# 1 Sheep-before moving+eating y=295, x=11, store=80
# 1 Sheep-after moving+eating y=294, x=10, store=90
# .........................................
# 2 Sheep-before moving+eating y=107, x=238, store=80
# 2 Sheep-after moving+eating y=108, x=237, store=90
# .........................................
# 3 Sheep-before moving+eating y=249, x=142, store=80
# 3 Sheep-after moving+eating y=250, x=143, store=90
# .........................................
# 4 Sheep-before moving+eating y=80, x=17, store=80
# 4 Sheep-after moving+eating y=79, x=16, store=90
# .........................................
# 5 Sheep-before moving+eating y=262, x=252, store=80
# 5 Sheep-after moving+eating y=261, x=253, store=90
# .........................................
# 6 Sheep-before moving+eating y=165, x=36, store=80
# 6 Sheep-after moving+eating y=164, x=35, store=90
# .........................................
# 7 Sheep-before moving+eating y=26, x=219, store=80
# 7 Sheep-after moving+eating y=27, x=220, store=90
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=181, store=0
# Else activate before by Wolf 0 y=73, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.9921875, x=250.7734375, store=50
# >>> Sheep going to be eaten 5 y=261, x=253, store=90 by Wolf 1 y=256.9921875, x=250.7734375, store=50
# >>> Sheep eaten 5 y=261, x=253, store=0 by Wolf 1 y=256.9921875, x=250.7734375, store=140
# _________________________________________
# Else activate before by Wolf 1 y=256.9921875, x=250.7734375, store=140
# Else activate after by Wolf 1 y=257.9921875, x=249.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=141, x=132, store=0
# Else activate before by Wolf 2 y=141, x=132, store=0
# Else activate after by Wolf 2 y=140, x=131, store=0
# .........................................
# 3 Wolf - before moving/eating y=235, x=85, store=0
# Else activate before by Wolf 3 y=235, x=85, store=0
# Else activate after by Wolf 3 y=234, x=84, store=0
# .........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=90
# 0 Sheep-after moving+eating y=294, x=18, store=100
# .........................................
# 1 Sheep-before moving+eating y=294, x=10, store=90
# 1 Sheep-after moving+eating y=293, x=11, store=100
# .........................................
# 2 Sheep-before moving+eating y=108, x=237, store=90
# 2 Sheep-after moving+eating y=109, x=238, store=100
# .........................................
# 3 Sheep-before moving+eating y=250, x=143, store=90
# 3 Sheep-after moving+eating y=251, x=142, store=100
# .........................................
# 4 Sheep-before moving+eating y=79, x=16, store=90
# 4 Sheep-after moving+eating y=80, x=15, store=100
# .........................................
# 5 Sheep-before moving+eating y=164, x=35, store=90
# 5 Sheep-after moving+eating y=163, x=34, store=100
# .........................................
# 6 Sheep-before moving+eating y=27, x=220, store=90
# 6 Sheep-after moving+eating y=26, x=221, store=100
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# .........................................
# 1 Wolf - before moving/eating y=257.9921875, x=249.7734375, store=140
# Else activate before by Wolf 1 y=257.9921875, x=249.7734375, store=140
# Else activate after by Wolf 1 y=258.9921875, x=250.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=140, x=131, store=0
# Else activate before by Wolf 2 y=140, x=131, store=0
# Else activate after by Wolf 2 y=139, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=84, store=0
# Else activate before by Wolf 3 y=234, x=84, store=0
# Else activate after by Wolf 3 y=235, x=83, store=0
# .........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=100
# 0 Sheep-after moving+eating y=293, x=19, store=110
# .........................................
# 1 Sheep-before moving+eating y=293, x=11, store=100
# 1 Sheep-after moving+eating y=292, x=12, store=110
# .........................................
# 2 Sheep-before moving+eating y=109, x=238, store=100
# 2 Sheep-after moving+eating y=110, x=239, store=110
# .........................................
# 3 Sheep-before moving+eating y=251, x=142, store=100
# 3 Sheep-after moving+eating y=252, x=143, store=110
# .........................................
# 4 Sheep-before moving+eating y=80, x=15, store=100
# 4 Sheep-after moving+eating y=79, x=16, store=110
# .........................................
# 5 Sheep-before moving+eating y=163, x=34, store=100
# 5 Sheep-after moving+eating y=162, x=33, store=110
# .........................................
# 6 Sheep-before moving+eating y=26, x=221, store=100
# 6 Sheep-after moving+eating y=27, x=220, store=110
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=72, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=258.9921875, x=250.7734375, store=140
# Else activate before by Wolf 1 y=258.9921875, x=250.7734375, store=140
# Else activate after by Wolf 1 y=257.9921875, x=249.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=139, x=132, store=0
# Else activate before by Wolf 2 y=139, x=132, store=0
# Else activate after by Wolf 2 y=140, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=235, x=83, store=0
# Else activate before by Wolf 3 y=235, x=83, store=0
# Else activate after by Wolf 3 y=234, x=84, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=130.875, x=182.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=293, x=19, store=110
# 0 Sheep-after moving+eating y=294, x=20, store=120
# .........................................
# 1 Sheep-before moving+eating y=292, x=12, store=110
# 1 Sheep-after moving+eating y=291, x=11, store=120
# .........................................
# 2 Sheep-before moving+eating y=110, x=239, store=110
# 2 Sheep-after moving+eating y=111, x=238, store=120
# .........................................
# 3 Sheep-before moving+eating y=252, x=143, store=110
# 3 Sheep-after moving+eating y=251, x=142, store=120
# .........................................
# 4 Sheep-before moving+eating y=79, x=16, store=110
# 4 Sheep-after moving+eating y=78, x=17, store=120
# .........................................
# 5 Sheep-before moving+eating y=162, x=33, store=110
# 5 Sheep-after moving+eating y=163, x=32, store=120
# .........................................
# 6 Sheep-before moving+eating y=27, x=220, store=110
# 6 Sheep-after moving+eating y=26, x=221, store=120
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=184, store=0
# Else activate before by Wolf 0 y=72, x=184, store=0
# Else activate after by Wolf 0 y=71, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=257.9921875, x=249.7734375, store=140
# Else activate before by Wolf 1 y=257.9921875, x=249.7734375, store=140
# Else activate after by Wolf 1 y=256.9921875, x=250.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=140, x=133, store=0
# Else activate before by Wolf 2 y=140, x=133, store=0
# Else activate after by Wolf 2 y=141, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=84, store=0
# Else activate before by Wolf 3 y=234, x=84, store=0
# Else activate after by Wolf 3 y=233, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=182.5, store=40
# Else activate before by Wolf 4 y=130.875, x=182.5, store=40
# Else activate after by Wolf 4 y=129.875, x=181.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=294, x=20, store=120
# 0 Sheep-after moving+eating y=295, x=19, store=130
# .........................................
# 1 Sheep-before moving+eating y=291, x=11, store=120
# 1 Sheep-after moving+eating y=292, x=10, store=130
# .........................................
# 2 Sheep-before moving+eating y=111, x=238, store=120
# 2 Sheep-after moving+eating y=112, x=237, store=130
# .........................................
# 3 Sheep-before moving+eating y=251, x=142, store=120
# 3 Sheep-after moving+eating y=250, x=143, store=130
# .........................................
# 4 Sheep-before moving+eating y=78, x=17, store=120
# 4 Sheep-after moving+eating y=77, x=16, store=130
# .........................................
# 5 Sheep-before moving+eating y=163, x=32, store=120
# 5 Sheep-after moving+eating y=164, x=33, store=130
# .........................................
# 6 Sheep-before moving+eating y=26, x=221, store=120
# 6 Sheep-after moving+eating y=27, x=220, store=130
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=185, store=0
# Else activate before by Wolf 0 y=71, x=185, store=0
# Else activate after by Wolf 0 y=72, x=186, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.9921875, x=250.7734375, store=140
# Else activate before by Wolf 1 y=256.9921875, x=250.7734375, store=140
# Else activate after by Wolf 1 y=255.9921875, x=249.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=141, x=134, store=0
# Else activate before by Wolf 2 y=141, x=134, store=0
# Else activate after by Wolf 2 y=142, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=85, store=0
# Else activate before by Wolf 3 y=233, x=85, store=0
# Else activate after by Wolf 3 y=234, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=181.5, store=40
# Else activate before by Wolf 4 y=129.875, x=181.5, store=40
# Else activate after by Wolf 4 y=130.875, x=182.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=295, x=19, store=130
# 0 Sheep-after moving+eating y=294, x=18, store=140
# .........................................
# 1 Sheep-before moving+eating y=292, x=10, store=130
# 1 Sheep-after moving+eating y=293, x=11, store=140
# .........................................
# 2 Sheep-before moving+eating y=112, x=237, store=130
# 2 Sheep-after moving+eating y=113, x=238, store=140
# .........................................
# 3 Sheep-before moving+eating y=250, x=143, store=130
# 3 Sheep-after moving+eating y=249, x=142, store=140
# .........................................
# 4 Sheep-before moving+eating y=77, x=16, store=130
# 4 Sheep-after moving+eating y=76, x=15, store=140
# .........................................
# 5 Sheep-before moving+eating y=164, x=33, store=130
# 5 Sheep-after moving+eating y=165, x=34, store=140
# .........................................
# 6 Sheep-before moving+eating y=27, x=220, store=130
# 6 Sheep-after moving+eating y=28, x=221, store=140
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=186, store=0
# Else activate before by Wolf 0 y=72, x=186, store=0
# Else activate after by Wolf 0 y=73, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.9921875, x=249.7734375, store=140
# Else activate before by Wolf 1 y=255.9921875, x=249.7734375, store=140
# Else activate after by Wolf 1 y=256.9921875, x=248.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=142, x=133, store=0
# Else activate before by Wolf 2 y=142, x=133, store=0
# Else activate after by Wolf 2 y=143, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=86, store=0
# Else activate before by Wolf 3 y=234, x=86, store=0
# Else activate after by Wolf 3 y=235, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=182.5, store=40
# Else activate before by Wolf 4 y=130.875, x=182.5, store=40
# Else activate after by Wolf 4 y=131.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=140
# 0 Sheep-after moving+eating y=295, x=17, store=150
# .........................................
# 1 Sheep-before moving+eating y=293, x=11, store=140
# 1 Sheep-after moving+eating y=294, x=12, store=150
# .........................................
# 2 Sheep-before moving+eating y=113, x=238, store=140
# 2 Sheep-after moving+eating y=114, x=237, store=150
# .........................................
# 3 Sheep-before moving+eating y=249, x=142, store=140
# 3 Sheep-after moving+eating y=248, x=141, store=150
# .........................................
# 4 Sheep-before moving+eating y=76, x=15, store=140
# 4 Sheep-after moving+eating y=75, x=14, store=150
# .........................................
# 5 Sheep-before moving+eating y=165, x=34, store=140
# 5 Sheep-after moving+eating y=164, x=35, store=150
# .........................................
# 6 Sheep-before moving+eating y=28, x=221, store=140
# 6 Sheep-after moving+eating y=27, x=220, store=150
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=185, store=0
# Else activate before by Wolf 0 y=73, x=185, store=0
# Else activate after by Wolf 0 y=72, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.9921875, x=248.7734375, store=140
# Else activate before by Wolf 1 y=256.9921875, x=248.7734375, store=140
# Else activate after by Wolf 1 y=255.9921875, x=247.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=143, x=134, store=0
# Else activate before by Wolf 2 y=143, x=134, store=0
# Else activate after by Wolf 2 y=144, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=235, x=87, store=0
# Else activate before by Wolf 3 y=235, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=131.875, x=183.5, store=40
# Else activate before by Wolf 4 y=131.875, x=183.5, store=40
# Else activate after by Wolf 4 y=130.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=150
# 0 Sheep-after moving+eating y=294, x=18, store=160
# .........................................
# 1 Sheep-before moving+eating y=294, x=12, store=150
# 1 Sheep-after moving+eating y=295, x=11, store=160
# .........................................
# 2 Sheep-before moving+eating y=114, x=237, store=150
# 2 Sheep-after moving+eating y=115, x=236, store=160
# .........................................
# 3 Sheep-before moving+eating y=248, x=141, store=150
# 3 Sheep-after moving+eating y=249, x=140, store=160
# .........................................
# 4 Sheep-before moving+eating y=75, x=14, store=150
# 4 Sheep-after moving+eating y=76, x=13, store=160
# .........................................
# 5 Sheep-before moving+eating y=164, x=35, store=150
# 5 Sheep-after moving+eating y=163, x=34, store=160
# .........................................
# 6 Sheep-before moving+eating y=27, x=220, store=150
# 6 Sheep-after moving+eating y=28, x=219, store=160
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=184, store=0
# Else activate before by Wolf 0 y=72, x=184, store=0
# Else activate after by Wolf 0 y=73, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.9921875, x=247.7734375, store=140
# Else activate before by Wolf 1 y=255.9921875, x=247.7734375, store=140
# Else activate after by Wolf 1 y=256.9921875, x=248.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=144, x=135, store=0
# Else activate before by Wolf 2 y=144, x=135, store=0
# Else activate after by Wolf 2 y=145, x=136, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=160
# 0 Sheep-after moving+eating y=293, x=19, store=170
# .........................................
# 1 Sheep-before moving+eating y=295, x=11, store=160
# 1 Sheep-after moving+eating y=294, x=12, store=170
# .........................................
# 2 Sheep-before moving+eating y=115, x=236, store=160
# 2 Sheep-after moving+eating y=114, x=237, store=170
# .........................................
# 3 Sheep-before moving+eating y=249, x=140, store=160
# 3 Sheep-after moving+eating y=250, x=139, store=170
# .........................................
# 4 Sheep-before moving+eating y=76, x=13, store=160
# 4 Sheep-after moving+eating y=75, x=12, store=170
# .........................................
# 5 Sheep-before moving+eating y=163, x=34, store=160
# 5 Sheep-after moving+eating y=164, x=33, store=170
# .........................................
# 6 Sheep-before moving+eating y=28, x=219, store=160
# 6 Sheep-after moving+eating y=27, x=218, store=170
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=185, store=0
# Else activate before by Wolf 0 y=73, x=185, store=0
# Else activate after by Wolf 0 y=72, x=186, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.9921875, x=248.7734375, store=140
# Else activate before by Wolf 1 y=256.9921875, x=248.7734375, store=140
# Else activate after by Wolf 1 y=255.9921875, x=247.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=145, x=136, store=0
# Else activate before by Wolf 2 y=145, x=136, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=232, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=293, x=19, store=170
# 0 Sheep-after moving+eating y=294, x=20, store=180
# .........................................
# 1 Sheep-before moving+eating y=294, x=12, store=170
# 1 Sheep-after moving+eating y=295, x=13, store=180
# .........................................
# 2 Sheep-before moving+eating y=114, x=237, store=170
# 2 Sheep-after moving+eating y=113, x=236, store=180
# .........................................
# 3 Sheep-before moving+eating y=250, x=139, store=170
# 3 Sheep-after moving+eating y=251, x=138, store=180
# .........................................
# 4 Sheep-before moving+eating y=75, x=12, store=170
# 4 Sheep-after moving+eating y=76, x=11, store=180
# .........................................
# 5 Sheep-before moving+eating y=164, x=33, store=170
# 5 Sheep-after moving+eating y=165, x=34, store=180
# .........................................
# 6 Sheep-before moving+eating y=27, x=218, store=170
# 6 Sheep-after moving+eating y=28, x=217, store=180
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=186, store=0
# Else activate before by Wolf 0 y=72, x=186, store=0
# Else activate after by Wolf 0 y=71, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.9921875, x=247.7734375, store=140
# Else activate before by Wolf 1 y=255.9921875, x=247.7734375, store=140
# Else activate after by Wolf 1 y=254.9921875, x=248.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=86, store=0
# Else activate before by Wolf 3 y=232, x=86, store=0
# Else activate after by Wolf 3 y=231, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=128.875, x=184.5, store=40
# Else activate before by Wolf 4 y=128.875, x=184.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=294, x=20, store=180
# 0 Sheep-after moving+eating y=295, x=19, store=190
# .........................................
# 1 Sheep-before moving+eating y=295, x=13, store=180
# 1 Sheep-after moving+eating y=296, x=12, store=190
# .........................................
# 2 Sheep-before moving+eating y=113, x=236, store=180
# 2 Sheep-after moving+eating y=114, x=237, store=190
# .........................................
# 3 Sheep-before moving+eating y=251, x=138, store=180
# 3 Sheep-after moving+eating y=252, x=139, store=190
# .........................................
# 4 Sheep-before moving+eating y=76, x=11, store=180
# 4 Sheep-after moving+eating y=77, x=12, store=190
# .........................................
# 5 Sheep-before moving+eating y=165, x=34, store=180
# 5 Sheep-after moving+eating y=166, x=33, store=190
# .........................................
# 6 Sheep-before moving+eating y=28, x=217, store=180
# 6 Sheep-after moving+eating y=29, x=218, store=190
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=185, store=0
# Else activate before by Wolf 0 y=71, x=185, store=0
# Else activate after by Wolf 0 y=72, x=186, store=0
# .........................................
# 1 Wolf - before moving/eating y=254.9921875, x=248.7734375, store=140
# Else activate before by Wolf 1 y=254.9921875, x=248.7734375, store=140
# Else activate after by Wolf 1 y=253.9921875, x=247.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=231, x=85, store=0
# Else activate before by Wolf 3 y=231, x=85, store=0
# Else activate after by Wolf 3 y=232, x=84, store=0
# .........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=295, x=19, store=190
# 0 Sheep-after moving+eating y=296, x=18, store=200
# .........................................
# 1 Sheep-before moving+eating y=296, x=12, store=190
# 1 Sheep-after moving+eating y=297, x=13, store=200
# .........................................
# 2 Sheep-before moving+eating y=114, x=237, store=190
# 2 Sheep-after moving+eating y=115, x=236, store=200
# .........................................
# 3 Sheep-before moving+eating y=252, x=139, store=190
# 3 Sheep-after moving+eating y=253, x=140, store=200
# .........................................
# 4 Sheep-before moving+eating y=77, x=12, store=190
# 4 Sheep-after moving+eating y=78, x=13, store=200
# .........................................
# 5 Sheep-before moving+eating y=166, x=33, store=190
# 5 Sheep-after moving+eating y=165, x=32, store=200
# .........................................
# 6 Sheep-before moving+eating y=29, x=218, store=190
# 6 Sheep-after moving+eating y=28, x=217, store=200
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=186, store=0
# Else activate before by Wolf 0 y=72, x=186, store=0
# Else activate after by Wolf 0 y=73, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=253.9921875, x=247.7734375, store=140
# Else activate before by Wolf 1 y=253.9921875, x=247.7734375, store=140
# Else activate after by Wolf 1 y=252.9921875, x=246.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=144, x=133, store=0
# Else activate before by Wolf 2 y=144, x=133, store=0
# Else activate after by Wolf 2 y=143, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=84, store=0
# Else activate before by Wolf 3 y=232, x=84, store=0
# Else activate after by Wolf 3 y=233, x=83, store=0
# .........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=296, x=18, store=200
# 0 Sheep-after moving+eating y=295, x=19, store=210
# .........................................
# 1 Sheep-before moving+eating y=297, x=13, store=200
# 1 Sheep-after moving+eating y=296, x=14, store=210
# .........................................
# 2 Sheep-before moving+eating y=115, x=236, store=200
# 2 Sheep-after moving+eating y=116, x=237, store=210
# .........................................
# 3 Sheep-before moving+eating y=253, x=140, store=200
# 3 Sheep-after moving+eating y=254, x=141, store=210
# .........................................
# 4 Sheep-before moving+eating y=78, x=13, store=200
# 4 Sheep-after moving+eating y=77, x=12, store=210
# .........................................
# 5 Sheep-before moving+eating y=165, x=32, store=200
# 5 Sheep-after moving+eating y=164, x=33, store=210
# .........................................
# 6 Sheep-before moving+eating y=28, x=217, store=200
# 6 Sheep-after moving+eating y=27, x=216, store=210
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=185, store=0
# Else activate before by Wolf 0 y=73, x=185, store=0
# Else activate after by Wolf 0 y=72, x=186, store=0
# .........................................
# 1 Wolf - before moving/eating y=252.9921875, x=246.7734375, store=140
# Else activate before by Wolf 1 y=252.9921875, x=246.7734375, store=140
# Else activate after by Wolf 1 y=253.9921875, x=247.7734375, store=140
# .........................................
# 2 Wolf - before moving/eating y=143, x=134, store=0
# Else activate before by Wolf 2 y=143, x=134, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=83, store=0
# Else activate before by Wolf 3 y=233, x=83, store=0
# Else activate after by Wolf 3 y=234, x=82, store=0
# .........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# .........................................
# _________________________________________

# %% [markdown]
# with continue

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('.........................................')
    print('_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
            elif distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('_________________________________________')
                # break # with break no 4 activates else after eating.
                continue
        if closest_sheep != None:
            print('YCL before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('YCL after', closest_sheep, 'Wolf', i, wolves[i])
            print('.........................................')
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('.........................................')
    print('_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# .........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# .........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# .........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# .........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# .........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# .........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# .........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# .........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# .........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# YCL before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# YCL after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# YCL before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# YCL after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# .........................................
# _________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# .........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# .........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# .........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# .........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# .........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# .........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# .........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# .........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# .........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# YCL before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# YCL after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# .........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# .........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# YCL before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# YCL after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# .........................................
# _________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# .........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# .........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# .........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# .........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# .........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# .........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# .........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# .........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# .........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# .........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# YCL before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# YCL after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# YCL before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# YCL after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# .........................................
# _________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# .........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# .........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# .........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# .........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# .........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# .........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# .........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# .........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# .........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# YCL before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# YCL after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# .........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# _________________________________________
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=185.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=15, store=50
# .........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=220, x=246, store=50
# .........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=294, x=10, store=50
# .........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=106, x=239, store=50
# .........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=248, x=141, store=50
# .........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=18, store=50
# .........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# .........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=37, store=50
# .........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=25, x=218, store=50
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=220, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=220, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# _________________________________________
# >>> min_dist = 48.41269526167697 Sheep 6 y=265, x=251, store=50 by Wolf 1 y=216.9375, x=245.1875, store=50
# YCL before y=265, x=251, store=50 Wolf 1 y=216.9375, x=245.1875, store=50
# YCL after y=265, x=251, store=50 Wolf 1 y=240.96875, x=248.09375, store=50
# .........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=232, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=185.5, store=40
# Else activate before by Wolf 4 y=129.875, x=185.5, store=40
# Else activate after by Wolf 4 y=130.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=50
# 0 Sheep-after moving+eating y=292, x=14, store=60
# .........................................
# 1 Sheep-before moving+eating y=294, x=10, store=50
# 1 Sheep-after moving+eating y=295, x=9, store=60
# .........................................
# 2 Sheep-before moving+eating y=106, x=239, store=50
# 2 Sheep-after moving+eating y=105, x=240, store=60
# .........................................
# 3 Sheep-before moving+eating y=248, x=141, store=50
# 3 Sheep-after moving+eating y=249, x=140, store=60
# .........................................
# 4 Sheep-before moving+eating y=83, x=18, store=50
# 4 Sheep-after moving+eating y=82, x=19, store=60
# .........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=264, x=250, store=60
# .........................................
# 6 Sheep-before moving+eating y=166, x=37, store=50
# 6 Sheep-after moving+eating y=165, x=36, store=60
# .........................................
# 7 Sheep-before moving+eating y=25, x=218, store=50
# 7 Sheep-after moving+eating y=26, x=219, store=60
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# .........................................
# 1 Wolf - before moving/eating y=240.96875, x=248.09375, store=50
# >>> min_dist = 23.110003583405174 Sheep 5 y=264, x=250, store=60 by Wolf 1 y=240.96875, x=248.09375, store=50
# YCL before y=264, x=250, store=60 Wolf 1 y=240.96875, x=248.09375, store=50
# YCL after y=264, x=250, store=60 Wolf 1 y=252.484375, x=249.046875, store=50
# .........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=86, store=0
# Else activate before by Wolf 3 y=232, x=86, store=0
# Else activate after by Wolf 3 y=231, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=131.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=292, x=14, store=60
# 0 Sheep-after moving+eating y=291, x=13, store=70
# .........................................
# 1 Sheep-before moving+eating y=295, x=9, store=60
# 1 Sheep-after moving+eating y=296, x=10, store=70
# .........................................
# 2 Sheep-before moving+eating y=105, x=240, store=60
# 2 Sheep-after moving+eating y=106, x=239, store=70
# .........................................
# 3 Sheep-before moving+eating y=249, x=140, store=60
# 3 Sheep-after moving+eating y=250, x=141, store=70
# .........................................
# 4 Sheep-before moving+eating y=82, x=19, store=60
# 4 Sheep-after moving+eating y=83, x=20, store=70
# .........................................
# 5 Sheep-before moving+eating y=264, x=250, store=60
# 5 Sheep-after moving+eating y=263, x=249, store=70
# .........................................
# 6 Sheep-before moving+eating y=165, x=36, store=60
# 6 Sheep-after moving+eating y=164, x=37, store=70
# .........................................
# 7 Sheep-before moving+eating y=26, x=219, store=60
# 7 Sheep-after moving+eating y=25, x=218, store=70
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=252.484375, x=249.046875, store=50
# >>> min_dist = 10.515729475706857 Sheep 5 y=263, x=249, store=70 by Wolf 1 y=252.484375, x=249.046875, store=50
# YCL before y=263, x=249, store=70 Wolf 1 y=252.484375, x=249.046875, store=50
# YCL after y=263, x=249, store=70 Wolf 1 y=257.7421875, x=249.0234375, store=50
# .........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=148, x=135, store=0
# .........................................
# 3 Wolf - before moving/eating y=231, x=85, store=0
# Else activate before by Wolf 3 y=231, x=85, store=0
# Else activate after by Wolf 3 y=230, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=131.875, x=183.5, store=40
# Else activate before by Wolf 4 y=131.875, x=183.5, store=40
# Else activate after by Wolf 4 y=132.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=291, x=13, store=70
# 0 Sheep-after moving+eating y=290, x=12, store=80
# .........................................
# 1 Sheep-before moving+eating y=296, x=10, store=70
# 1 Sheep-after moving+eating y=297, x=11, store=80
# .........................................
# 2 Sheep-before moving+eating y=106, x=239, store=70
# 2 Sheep-after moving+eating y=107, x=240, store=80
# .........................................
# 3 Sheep-before moving+eating y=250, x=141, store=70
# 3 Sheep-after moving+eating y=249, x=140, store=80
# .........................................
# 4 Sheep-before moving+eating y=83, x=20, store=70
# 4 Sheep-after moving+eating y=84, x=19, store=80
# .........................................
# 5 Sheep-before moving+eating y=263, x=249, store=70
# 5 Sheep-after moving+eating y=262, x=250, store=80
# .........................................
# 6 Sheep-before moving+eating y=164, x=37, store=70
# 6 Sheep-after moving+eating y=163, x=38, store=80
# .........................................
# 7 Sheep-before moving+eating y=25, x=218, store=70
# 7 Sheep-after moving+eating y=24, x=217, store=80
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# .........................................
# 1 Wolf - before moving/eating y=257.7421875, x=249.0234375, store=50
# >>> Sheep going to be eaten 5 y=262, x=250, store=80 by Wolf 1 y=257.7421875, x=249.0234375, store=50
# >>> Sheep eaten 5 y=262, x=250, store=0 by Wolf 1 y=257.7421875, x=249.0234375, store=130
# _________________________________________
# Else activate before by Wolf 1 y=257.7421875, x=249.0234375, store=130
# Else activate after by Wolf 1 y=256.7421875, x=248.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=148, x=135, store=0
# Else activate before by Wolf 2 y=148, x=135, store=0
# Else activate after by Wolf 2 y=147, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=230, x=86, store=0
# Else activate before by Wolf 3 y=230, x=86, store=0
# Else activate after by Wolf 3 y=229, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=132.875, x=184.5, store=40
# Else activate before by Wolf 4 y=132.875, x=184.5, store=40
# Else activate after by Wolf 4 y=133.875, x=185.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=290, x=12, store=80
# 0 Sheep-after moving+eating y=289, x=13, store=90
# .........................................
# 1 Sheep-before moving+eating y=297, x=11, store=80
# 1 Sheep-after moving+eating y=296, x=10, store=90
# .........................................
# 2 Sheep-before moving+eating y=107, x=240, store=80
# 2 Sheep-after moving+eating y=108, x=239, store=90
# .........................................
# 3 Sheep-before moving+eating y=249, x=140, store=80
# 3 Sheep-after moving+eating y=250, x=141, store=90
# .........................................
# 4 Sheep-before moving+eating y=84, x=19, store=80
# 4 Sheep-after moving+eating y=83, x=18, store=90
# .........................................
# 5 Sheep-before moving+eating y=163, x=38, store=80
# 5 Sheep-after moving+eating y=162, x=39, store=90
# .........................................
# 6 Sheep-before moving+eating y=24, x=217, store=80
# 6 Sheep-after moving+eating y=23, x=216, store=90
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.7421875, x=248.0234375, store=130
# Else activate before by Wolf 1 y=256.7421875, x=248.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=249.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=147, x=134, store=0
# Else activate before by Wolf 2 y=147, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=229, x=85, store=0
# Else activate before by Wolf 3 y=229, x=85, store=0
# Else activate after by Wolf 3 y=228, x=84, store=0
# .........................................
# 4 Wolf - before moving/eating y=133.875, x=185.5, store=40
# Else activate before by Wolf 4 y=133.875, x=185.5, store=40
# Else activate after by Wolf 4 y=132.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=289, x=13, store=90
# 0 Sheep-after moving+eating y=290, x=12, store=100
# .........................................
# 1 Sheep-before moving+eating y=296, x=10, store=90
# 1 Sheep-after moving+eating y=295, x=11, store=100
# .........................................
# 2 Sheep-before moving+eating y=108, x=239, store=90
# 2 Sheep-after moving+eating y=107, x=240, store=100
# .........................................
# 3 Sheep-before moving+eating y=250, x=141, store=90
# 3 Sheep-after moving+eating y=251, x=142, store=100
# .........................................
# 4 Sheep-before moving+eating y=83, x=18, store=90
# 4 Sheep-after moving+eating y=84, x=17, store=100
# .........................................
# 5 Sheep-before moving+eating y=162, x=39, store=90
# 5 Sheep-after moving+eating y=163, x=38, store=100
# .........................................
# 6 Sheep-before moving+eating y=23, x=216, store=90
# 6 Sheep-after moving+eating y=22, x=215, store=100
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=73, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=249.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=249.0234375, store=130
# Else activate after by Wolf 1 y=256.7421875, x=250.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=148, x=133, store=0
# Else activate before by Wolf 2 y=148, x=133, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=228, x=84, store=0
# Else activate before by Wolf 3 y=228, x=84, store=0
# Else activate after by Wolf 3 y=227, x=85, store=0
# .........................................
# 4 Wolf - before moving/eating y=132.875, x=184.5, store=40
# Else activate before by Wolf 4 y=132.875, x=184.5, store=40
# Else activate after by Wolf 4 y=133.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=290, x=12, store=100
# 0 Sheep-after moving+eating y=291, x=13, store=110
# .........................................
# 1 Sheep-before moving+eating y=295, x=11, store=100
# 1 Sheep-after moving+eating y=294, x=12, store=110
# .........................................
# 2 Sheep-before moving+eating y=107, x=240, store=100
# 2 Sheep-after moving+eating y=106, x=241, store=110
# .........................................
# 3 Sheep-before moving+eating y=251, x=142, store=100
# 3 Sheep-after moving+eating y=252, x=143, store=110
# .........................................
# 4 Sheep-before moving+eating y=84, x=17, store=100
# 4 Sheep-after moving+eating y=85, x=18, store=110
# .........................................
# 5 Sheep-before moving+eating y=163, x=38, store=100
# 5 Sheep-after moving+eating y=162, x=39, store=110
# .........................................
# 6 Sheep-before moving+eating y=22, x=215, store=100
# 6 Sheep-after moving+eating y=21, x=214, store=110
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=185, store=0
# Else activate before by Wolf 0 y=73, x=185, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.7421875, x=250.0234375, store=130
# Else activate before by Wolf 1 y=256.7421875, x=250.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=251.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=227, x=85, store=0
# Else activate before by Wolf 3 y=227, x=85, store=0
# Else activate after by Wolf 3 y=228, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=133.875, x=183.5, store=40
# Else activate before by Wolf 4 y=133.875, x=183.5, store=40
# Else activate after by Wolf 4 y=132.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=291, x=13, store=110
# 0 Sheep-after moving+eating y=292, x=12, store=120
# .........................................
# 1 Sheep-before moving+eating y=294, x=12, store=110
# 1 Sheep-after moving+eating y=295, x=13, store=120
# .........................................
# 2 Sheep-before moving+eating y=106, x=241, store=110
# 2 Sheep-after moving+eating y=105, x=240, store=120
# .........................................
# 3 Sheep-before moving+eating y=252, x=143, store=110
# 3 Sheep-after moving+eating y=253, x=142, store=120
# .........................................
# 4 Sheep-before moving+eating y=85, x=18, store=110
# 4 Sheep-after moving+eating y=84, x=17, store=120
# .........................................
# 5 Sheep-before moving+eating y=162, x=39, store=110
# 5 Sheep-after moving+eating y=161, x=40, store=120
# .........................................
# 6 Sheep-before moving+eating y=21, x=214, store=110
# 6 Sheep-after moving+eating y=22, x=213, store=120
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=73, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=251.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=251.0234375, store=130
# Else activate after by Wolf 1 y=254.7421875, x=252.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=148, x=133, store=0
# Else activate before by Wolf 2 y=148, x=133, store=0
# Else activate after by Wolf 2 y=147, x=134, store=0
# .........................................
# 3 Wolf - before moving/eating y=228, x=86, store=0
# Else activate before by Wolf 3 y=228, x=86, store=0
# Else activate after by Wolf 3 y=229, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=132.875, x=184.5, store=40
# Else activate before by Wolf 4 y=132.875, x=184.5, store=40
# Else activate after by Wolf 4 y=131.875, x=185.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=292, x=12, store=120
# 0 Sheep-after moving+eating y=291, x=11, store=130
# .........................................
# 1 Sheep-before moving+eating y=295, x=13, store=120
# 1 Sheep-after moving+eating y=296, x=12, store=130
# .........................................
# 2 Sheep-before moving+eating y=105, x=240, store=120
# 2 Sheep-after moving+eating y=106, x=239, store=130
# .........................................
# 3 Sheep-before moving+eating y=253, x=142, store=120
# 3 Sheep-after moving+eating y=254, x=141, store=130
# .........................................
# 4 Sheep-before moving+eating y=84, x=17, store=120
# 4 Sheep-after moving+eating y=83, x=18, store=130
# .........................................
# 5 Sheep-before moving+eating y=161, x=40, store=120
# 5 Sheep-after moving+eating y=160, x=39, store=130
# .........................................
# 6 Sheep-before moving+eating y=22, x=213, store=120
# 6 Sheep-after moving+eating y=23, x=214, store=130
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=73, x=185, store=0
# Else activate before by Wolf 0 y=73, x=185, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=254.7421875, x=252.0234375, store=130
# Else activate before by Wolf 1 y=254.7421875, x=252.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=253.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=147, x=134, store=0
# Else activate before by Wolf 2 y=147, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# .........................................
# 3 Wolf - before moving/eating y=229, x=87, store=0
# Else activate before by Wolf 3 y=229, x=87, store=0
# Else activate after by Wolf 3 y=230, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=131.875, x=185.5, store=40
# Else activate before by Wolf 4 y=131.875, x=185.5, store=40
# Else activate after by Wolf 4 y=132.875, x=186.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=291, x=11, store=130
# 0 Sheep-after moving+eating y=292, x=12, store=140
# .........................................
# 1 Sheep-before moving+eating y=296, x=12, store=130
# 1 Sheep-after moving+eating y=295, x=11, store=140
# .........................................
# 2 Sheep-before moving+eating y=106, x=239, store=130
# 2 Sheep-after moving+eating y=107, x=240, store=140
# .........................................
# 3 Sheep-before moving+eating y=254, x=141, store=130
# 3 Sheep-after moving+eating y=255, x=142, store=140
# .........................................
# 4 Sheep-before moving+eating y=83, x=18, store=130
# 4 Sheep-after moving+eating y=82, x=17, store=140
# .........................................
# 5 Sheep-before moving+eating y=160, x=39, store=130
# 5 Sheep-after moving+eating y=159, x=38, store=140
# .........................................
# 6 Sheep-before moving+eating y=23, x=214, store=130
# 6 Sheep-after moving+eating y=24, x=215, store=140
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=75, x=185, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=253.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=253.0234375, store=130
# Else activate after by Wolf 1 y=256.7421875, x=252.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=147, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=230, x=86, store=0
# Else activate before by Wolf 3 y=230, x=86, store=0
# Else activate after by Wolf 3 y=231, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=132.875, x=186.5, store=40
# Else activate before by Wolf 4 y=132.875, x=186.5, store=40
# Else activate after by Wolf 4 y=133.875, x=187.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=292, x=12, store=140
# 0 Sheep-after moving+eating y=293, x=13, store=150
# .........................................
# 1 Sheep-before moving+eating y=295, x=11, store=140
# 1 Sheep-after moving+eating y=296, x=10, store=150
# .........................................
# 2 Sheep-before moving+eating y=107, x=240, store=140
# 2 Sheep-after moving+eating y=108, x=241, store=150
# .........................................
# 3 Sheep-before moving+eating y=255, x=142, store=140
# 3 Sheep-after moving+eating y=256, x=141, store=150
# .........................................
# 4 Sheep-before moving+eating y=82, x=17, store=140
# 4 Sheep-after moving+eating y=81, x=16, store=150
# .........................................
# 5 Sheep-before moving+eating y=159, x=38, store=140
# 5 Sheep-after moving+eating y=158, x=37, store=150
# .........................................
# 6 Sheep-before moving+eating y=24, x=215, store=140
# 6 Sheep-after moving+eating y=23, x=216, store=150
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=75, x=185, store=0
# Else activate before by Wolf 0 y=75, x=185, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.7421875, x=252.0234375, store=130
# Else activate before by Wolf 1 y=256.7421875, x=252.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=251.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=147, x=132, store=0
# Else activate before by Wolf 2 y=147, x=132, store=0
# Else activate after by Wolf 2 y=146, x=131, store=0
# .........................................
# 3 Wolf - before moving/eating y=231, x=87, store=0
# Else activate before by Wolf 3 y=231, x=87, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=133.875, x=187.5, store=40
# Else activate before by Wolf 4 y=133.875, x=187.5, store=40
# Else activate after by Wolf 4 y=132.875, x=188.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=293, x=13, store=150
# 0 Sheep-after moving+eating y=292, x=14, store=160
# .........................................
# 1 Sheep-before moving+eating y=296, x=10, store=150
# 1 Sheep-after moving+eating y=295, x=11, store=160
# .........................................
# 2 Sheep-before moving+eating y=108, x=241, store=150
# 2 Sheep-after moving+eating y=109, x=240, store=160
# .........................................
# 3 Sheep-before moving+eating y=256, x=141, store=150
# 3 Sheep-after moving+eating y=257, x=140, store=160
# .........................................
# 4 Sheep-before moving+eating y=81, x=16, store=150
# 4 Sheep-after moving+eating y=82, x=15, store=160
# .........................................
# 5 Sheep-before moving+eating y=158, x=37, store=150
# 5 Sheep-after moving+eating y=159, x=36, store=160
# .........................................
# 6 Sheep-before moving+eating y=23, x=216, store=150
# 6 Sheep-after moving+eating y=22, x=215, store=160
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=75, x=183, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=251.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=251.0234375, store=130
# Else activate after by Wolf 1 y=256.7421875, x=252.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=146, x=131, store=0
# Else activate before by Wolf 2 y=146, x=131, store=0
# Else activate after by Wolf 2 y=147, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# .........................................
# 4 Wolf - before moving/eating y=132.875, x=188.5, store=40
# Else activate before by Wolf 4 y=132.875, x=188.5, store=40
# Else activate after by Wolf 4 y=131.875, x=187.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=292, x=14, store=160
# 0 Sheep-after moving+eating y=291, x=13, store=170
# .........................................
# 1 Sheep-before moving+eating y=295, x=11, store=160
# 1 Sheep-after moving+eating y=294, x=12, store=170
# .........................................
# 2 Sheep-before moving+eating y=109, x=240, store=160
# 2 Sheep-after moving+eating y=108, x=241, store=170
# .........................................
# 3 Sheep-before moving+eating y=257, x=140, store=160
# 3 Sheep-after moving+eating y=256, x=141, store=170
# .........................................
# 4 Sheep-before moving+eating y=82, x=15, store=160
# 4 Sheep-after moving+eating y=83, x=14, store=170
# .........................................
# 5 Sheep-before moving+eating y=159, x=36, store=160
# 5 Sheep-after moving+eating y=158, x=35, store=170
# .........................................
# 6 Sheep-before moving+eating y=22, x=215, store=160
# 6 Sheep-after moving+eating y=23, x=214, store=170
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=75, x=183, store=0
# Else activate before by Wolf 0 y=75, x=183, store=0
# Else activate after by Wolf 0 y=74, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.7421875, x=252.0234375, store=130
# Else activate before by Wolf 1 y=256.7421875, x=252.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=253.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=147, x=132, store=0
# Else activate before by Wolf 2 y=147, x=132, store=0
# Else activate after by Wolf 2 y=146, x=131, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# .........................................
# 4 Wolf - before moving/eating y=131.875, x=187.5, store=40
# Else activate before by Wolf 4 y=131.875, x=187.5, store=40
# Else activate after by Wolf 4 y=130.875, x=186.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=291, x=13, store=170
# 0 Sheep-after moving+eating y=290, x=14, store=180
# .........................................
# 1 Sheep-before moving+eating y=294, x=12, store=170
# 1 Sheep-after moving+eating y=295, x=13, store=180
# .........................................
# 2 Sheep-before moving+eating y=108, x=241, store=170
# 2 Sheep-after moving+eating y=109, x=242, store=180
# .........................................
# 3 Sheep-before moving+eating y=256, x=141, store=170
# 3 Sheep-after moving+eating y=255, x=140, store=180
# .........................................
# 4 Sheep-before moving+eating y=83, x=14, store=170
# 4 Sheep-after moving+eating y=84, x=13, store=180
# .........................................
# 5 Sheep-before moving+eating y=158, x=35, store=170
# 5 Sheep-after moving+eating y=159, x=34, store=180
# .........................................
# 6 Sheep-before moving+eating y=23, x=214, store=170
# 6 Sheep-after moving+eating y=24, x=215, store=180
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=74, x=182, store=0
# Else activate before by Wolf 0 y=74, x=182, store=0
# Else activate after by Wolf 0 y=75, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=253.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=253.0234375, store=130
# Else activate after by Wolf 1 y=254.7421875, x=252.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=146, x=131, store=0
# Else activate before by Wolf 2 y=146, x=131, store=0
# Else activate after by Wolf 2 y=145, x=132, store=0
# .........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=186.5, store=40
# Else activate before by Wolf 4 y=130.875, x=186.5, store=40
# Else activate after by Wolf 4 y=129.875, x=185.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=290, x=14, store=180
# 0 Sheep-after moving+eating y=289, x=13, store=190
# .........................................
# 1 Sheep-before moving+eating y=295, x=13, store=180
# 1 Sheep-after moving+eating y=296, x=12, store=190
# .........................................
# 2 Sheep-before moving+eating y=109, x=242, store=180
# 2 Sheep-after moving+eating y=110, x=241, store=190
# .........................................
# 3 Sheep-before moving+eating y=255, x=140, store=180
# 3 Sheep-after moving+eating y=256, x=141, store=190
# .........................................
# 4 Sheep-before moving+eating y=84, x=13, store=180
# 4 Sheep-after moving+eating y=85, x=14, store=190
# .........................................
# 5 Sheep-before moving+eating y=159, x=34, store=180
# 5 Sheep-after moving+eating y=160, x=35, store=190
# .........................................
# 6 Sheep-before moving+eating y=24, x=215, store=180
# 6 Sheep-after moving+eating y=25, x=214, store=190
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=75, x=181, store=0
# Else activate before by Wolf 0 y=75, x=181, store=0
# Else activate after by Wolf 0 y=76, x=182, store=0
# .........................................
# 1 Wolf - before moving/eating y=254.7421875, x=252.0234375, store=130
# Else activate before by Wolf 1 y=254.7421875, x=252.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=253.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=145, x=132, store=0
# Else activate before by Wolf 2 y=145, x=132, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# .........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=232, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=129.875, x=185.5, store=40
# Else activate before by Wolf 4 y=129.875, x=185.5, store=40
# Else activate after by Wolf 4 y=130.875, x=184.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=289, x=13, store=190
# 0 Sheep-after moving+eating y=290, x=12, store=200
# .........................................
# 1 Sheep-before moving+eating y=296, x=12, store=190
# 1 Sheep-after moving+eating y=297, x=11, store=200
# .........................................
# 2 Sheep-before moving+eating y=110, x=241, store=190
# 2 Sheep-after moving+eating y=111, x=242, store=200
# .........................................
# 3 Sheep-before moving+eating y=256, x=141, store=190
# 3 Sheep-after moving+eating y=257, x=140, store=200
# .........................................
# 4 Sheep-before moving+eating y=85, x=14, store=190
# 4 Sheep-after moving+eating y=86, x=15, store=200
# .........................................
# 5 Sheep-before moving+eating y=160, x=35, store=190
# 5 Sheep-after moving+eating y=161, x=36, store=200
# .........................................
# 6 Sheep-before moving+eating y=25, x=214, store=190
# 6 Sheep-after moving+eating y=24, x=213, store=200
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=76, x=182, store=0
# Else activate before by Wolf 0 y=76, x=182, store=0
# Else activate after by Wolf 0 y=75, x=181, store=0
# .........................................
# 1 Wolf - before moving/eating y=255.7421875, x=253.0234375, store=130
# Else activate before by Wolf 1 y=255.7421875, x=253.0234375, store=130
# Else activate after by Wolf 1 y=256.7421875, x=252.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=144, x=131, store=0
# Else activate before by Wolf 2 y=144, x=131, store=0
# Else activate after by Wolf 2 y=143, x=130, store=0
# .........................................
# 3 Wolf - before moving/eating y=232, x=86, store=0
# Else activate before by Wolf 3 y=232, x=86, store=0
# Else activate after by Wolf 3 y=231, x=87, store=0
# .........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=131.875, x=183.5, store=40
# .........................................
# _________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=290, x=12, store=200
# 0 Sheep-after moving+eating y=289, x=11, store=210
# .........................................
# 1 Sheep-before moving+eating y=297, x=11, store=200
# 1 Sheep-after moving+eating y=296, x=12, store=210
# .........................................
# 2 Sheep-before moving+eating y=111, x=242, store=200
# 2 Sheep-after moving+eating y=110, x=243, store=210
# .........................................
# 3 Sheep-before moving+eating y=257, x=140, store=200
# 3 Sheep-after moving+eating y=258, x=141, store=210
# .........................................
# 4 Sheep-before moving+eating y=86, x=15, store=200
# 4 Sheep-after moving+eating y=87, x=16, store=210
# .........................................
# 5 Sheep-before moving+eating y=161, x=36, store=200
# 5 Sheep-after moving+eating y=160, x=35, store=210
# .........................................
# 6 Sheep-before moving+eating y=24, x=213, store=200
# 6 Sheep-after moving+eating y=23, x=214, store=210
# .........................................
# _________________________________________
# 0 Wolf - before moving/eating y=75, x=181, store=0
# Else activate before by Wolf 0 y=75, x=181, store=0
# Else activate after by Wolf 0 y=74, x=180, store=0
# .........................................
# 1 Wolf - before moving/eating y=256.7421875, x=252.0234375, store=130
# Else activate before by Wolf 1 y=256.7421875, x=252.0234375, store=130
# Else activate after by Wolf 1 y=255.7421875, x=253.0234375, store=130
# .........................................
# 2 Wolf - before moving/eating y=143, x=130, store=0
# Else activate before by Wolf 2 y=143, x=130, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# .........................................
# 3 Wolf - before moving/eating y=231, x=87, store=0
# Else activate before by Wolf 3 y=231, x=87, store=0
# Else activate after by Wolf 3 y=232, x=86, store=0
# .........................................
# 4 Wolf - before moving/eating y=131.875, x=183.5, store=40
# Else activate before by Wolf 4 y=131.875, x=183.5, store=40
# Else activate after by Wolf 4 y=132.875, x=182.5, store=40
# .........................................
# _________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-bfb19c7927bb> in <module>
#     179 model_menu.add_command(label="Run model", command=run)
#     180
# --> 181 tkinter.mainloop()
#     182
#     183 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:

# %% [markdown]
# with eaten variable

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('S.........................................')
    print('Sheep_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
            elif distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works? still target. what's getting activated?
        if closest_sheep != None:
            print('YCL before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('YCL after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')
        elif eaten == True:
            pass            
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Else_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# S.........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# S.........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# S.........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# YCL before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# YCL after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# YCL before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# YCL after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# Y.........................................
# Else_________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# S.........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# S.........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# S.........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# S.........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# S.........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# S.........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# YCL before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# YCL after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# YCL before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# YCL after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# Y.........................................
# Else_________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# S.........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# S.........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# S.........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# S.........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# S.........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# S.........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# YCL before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# YCL after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# YCL before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# YCL after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# Y.........................................
# Else_________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# S.........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# S.........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# S.........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# S.........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# S.........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# S.........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# YCL before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# YCL after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# Eaten_________________________________________
# Else_________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=17, store=50
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=218, x=246, store=50
# S.........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=296, x=10, store=50
# S.........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=104, x=239, store=50
# S.........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=250, x=141, store=50
# S.........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=16, store=50
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=39, store=50
# S.........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=23, x=216, store=50
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=218, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=218, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# Eaten_________________________________________
# >>> min_dist = 48.41269526167697 Sheep 6 y=265, x=251, store=50 by Wolf 1 y=216.9375, x=245.1875, store=50
# YCL before y=265, x=251, store=50 Wolf 1 y=216.9375, x=245.1875, store=50
# YCL after y=265, x=251, store=50 Wolf 1 y=240.96875, x=248.09375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=17, store=50
# 0 Sheep-after moving+eating y=294, x=16, store=60
# S.........................................
# 1 Sheep-before moving+eating y=296, x=10, store=50
# 1 Sheep-after moving+eating y=295, x=9, store=60
# S.........................................
# 2 Sheep-before moving+eating y=104, x=239, store=50
# 2 Sheep-after moving+eating y=105, x=238, store=60
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=50
# 3 Sheep-after moving+eating y=249, x=142, store=60
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=50
# 4 Sheep-after moving+eating y=84, x=15, store=60
# S.........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=264, x=252, store=60
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=50
# 6 Sheep-after moving+eating y=165, x=38, store=60
# S.........................................
# 7 Sheep-before moving+eating y=23, x=216, store=50
# 7 Sheep-after moving+eating y=22, x=215, store=60
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating y=240.96875, x=248.09375, store=50
# >>> min_dist = 23.360164075301356 Sheep 5 y=264, x=252, store=60 by Wolf 1 y=240.96875, x=248.09375, store=50
# YCL before y=264, x=252, store=60 Wolf 1 y=240.96875, x=248.09375, store=50
# YCL after y=264, x=252, store=60 Wolf 1 y=252.484375, x=250.046875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=60
# 0 Sheep-after moving+eating y=295, x=15, store=70
# S.........................................
# 1 Sheep-before moving+eating y=295, x=9, store=60
# 1 Sheep-after moving+eating y=294, x=8, store=70
# S.........................................
# 2 Sheep-before moving+eating y=105, x=238, store=60
# 2 Sheep-after moving+eating y=106, x=239, store=70
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=60
# 3 Sheep-after moving+eating y=250, x=141, store=70
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=60
# 4 Sheep-after moving+eating y=85, x=16, store=70
# S.........................................
# 5 Sheep-before moving+eating y=264, x=252, store=60
# 5 Sheep-after moving+eating y=265, x=253, store=70
# S.........................................
# 6 Sheep-before moving+eating y=165, x=38, store=60
# 6 Sheep-after moving+eating y=164, x=37, store=70
# S.........................................
# 7 Sheep-before moving+eating y=22, x=215, store=60
# 7 Sheep-after moving+eating y=21, x=216, store=70
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=252.484375, x=250.046875, store=50
# >>> min_dist = 12.859308550861122 Sheep 5 y=265, x=253, store=70 by Wolf 1 y=252.484375, x=250.046875, store=50
# YCL before y=265, x=253, store=70 Wolf 1 y=252.484375, x=250.046875, store=50
# YCL after y=265, x=253, store=70 Wolf 1 y=258.7421875, x=251.5234375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=236, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=70
# 0 Sheep-after moving+eating y=296, x=16, store=80
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=70
# 1 Sheep-after moving+eating y=293, x=7, store=80
# S.........................................
# 2 Sheep-before moving+eating y=106, x=239, store=70
# 2 Sheep-after moving+eating y=107, x=240, store=80
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=70
# 3 Sheep-after moving+eating y=251, x=142, store=80
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=70
# 4 Sheep-after moving+eating y=84, x=15, store=80
# S.........................................
# 5 Sheep-before moving+eating y=265, x=253, store=70
# 5 Sheep-after moving+eating y=266, x=252, store=80
# S.........................................
# 6 Sheep-before moving+eating y=164, x=37, store=70
# 6 Sheep-after moving+eating y=163, x=38, store=80
# S.........................................
# 7 Sheep-before moving+eating y=21, x=216, store=70
# 7 Sheep-after moving+eating y=20, x=217, store=80
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=258.7421875, x=251.5234375, store=50
# >>> min_dist = 7.27344169575604 Sheep 5 y=266, x=252, store=80 by Wolf 1 y=258.7421875, x=251.5234375, store=50
# YCL before y=266, x=252, store=80 Wolf 1 y=258.7421875, x=251.5234375, store=50
# YCL after y=266, x=252, store=80 Wolf 1 y=262.37109375, x=251.76171875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=236, x=88, store=0
# Else activate before by Wolf 3 y=236, x=88, store=0
# Else activate after by Wolf 3 y=235, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=80
# 0 Sheep-after moving+eating y=295, x=15, store=90
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=80
# 1 Sheep-after moving+eating y=294, x=8, store=90
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=80
# 2 Sheep-after moving+eating y=106, x=241, store=90
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=80
# 3 Sheep-after moving+eating y=250, x=141, store=90
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=80
# 4 Sheep-after moving+eating y=85, x=14, store=90
# S.........................................
# 5 Sheep-before moving+eating y=266, x=252, store=80
# 5 Sheep-after moving+eating y=267, x=253, store=90
# S.........................................
# 6 Sheep-before moving+eating y=163, x=38, store=80
# 6 Sheep-after moving+eating y=162, x=37, store=90
# S.........................................
# 7 Sheep-before moving+eating y=20, x=217, store=80
# 7 Sheep-after moving+eating y=19, x=218, store=90
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=262.37109375, x=251.76171875, store=50
# >>> Sheep going to be eaten 5 y=267, x=253, store=90 by Wolf 1 y=262.37109375, x=251.76171875, store=50
# >>> Sheep eaten 5 y=267, x=253, store=0 by Wolf 1 y=262.37109375, x=251.76171875, store=140
# Eaten_________________________________________
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=87, store=0
# Else activate before by Wolf 3 y=235, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=90
# 0 Sheep-after moving+eating y=294, x=14, store=100
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=90
# 1 Sheep-after moving+eating y=293, x=7, store=100
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=90
# 2 Sheep-after moving+eating y=107, x=240, store=100
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=90
# 3 Sheep-after moving+eating y=249, x=142, store=100
# S.........................................
# 4 Sheep-before moving+eating y=85, x=14, store=90
# 4 Sheep-after moving+eating y=84, x=15, store=100
# S.........................................
# 5 Sheep-before moving+eating y=162, x=37, store=90
# 5 Sheep-after moving+eating y=163, x=38, store=100
# S.........................................
# 6 Sheep-before moving+eating y=19, x=218, store=90
# 6 Sheep-after moving+eating y=20, x=217, store=100
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=262.37109375, x=251.76171875, store=140
# Else activate before by Wolf 1 y=262.37109375, x=251.76171875, store=140
# Else activate after by Wolf 1 y=261.37109375, x=250.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=294, x=14, store=100
# 0 Sheep-after moving+eating y=293, x=15, store=110
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=100
# 1 Sheep-after moving+eating y=294, x=6, store=110
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=100
# 2 Sheep-after moving+eating y=108, x=241, store=110
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=100
# 3 Sheep-after moving+eating y=248, x=143, store=110
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=100
# 4 Sheep-after moving+eating y=83, x=16, store=110
# S.........................................
# 5 Sheep-before moving+eating y=163, x=38, store=100
# 5 Sheep-after moving+eating y=164, x=39, store=110
# S.........................................
# 6 Sheep-before moving+eating y=20, x=217, store=100
# 6 Sheep-after moving+eating y=21, x=218, store=110
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=179, store=0
# Else activate before by Wolf 0 y=71, x=179, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=261.37109375, x=250.76171875, store=140
# Else activate before by Wolf 1 y=261.37109375, x=250.76171875, store=140
# Else activate after by Wolf 1 y=260.37109375, x=249.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=110
# 0 Sheep-after moving+eating y=294, x=16, store=120
# S.........................................
# 1 Sheep-before moving+eating y=294, x=6, store=110
# 1 Sheep-after moving+eating y=293, x=7, store=120
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=110
# 2 Sheep-after moving+eating y=109, x=240, store=120
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=110
# 3 Sheep-after moving+eating y=249, x=144, store=120
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=110
# 4 Sheep-after moving+eating y=82, x=15, store=120
# S.........................................
# 5 Sheep-before moving+eating y=164, x=39, store=110
# 5 Sheep-after moving+eating y=165, x=38, store=120
# S.........................................
# 6 Sheep-before moving+eating y=21, x=218, store=110
# 6 Sheep-after moving+eating y=20, x=217, store=120
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=69, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=260.37109375, x=249.76171875, store=140
# Else activate before by Wolf 1 y=260.37109375, x=249.76171875, store=140
# Else activate after by Wolf 1 y=261.37109375, x=248.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=120
# 0 Sheep-after moving+eating y=295, x=17, store=130
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=120
# 1 Sheep-after moving+eating y=292, x=8, store=130
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=120
# 2 Sheep-after moving+eating y=108, x=239, store=130
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=120
# 3 Sheep-after moving+eating y=250, x=143, store=130
# S.........................................
# 4 Sheep-before moving+eating y=82, x=15, store=120
# 4 Sheep-after moving+eating y=83, x=14, store=130
# S.........................................
# 5 Sheep-before moving+eating y=165, x=38, store=120
# 5 Sheep-after moving+eating y=166, x=37, store=130
# S.........................................
# 6 Sheep-before moving+eating y=20, x=217, store=120
# 6 Sheep-after moving+eating y=19, x=218, store=130
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=69, x=181, store=0
# Else activate before by Wolf 0 y=69, x=181, store=0
# Else activate after by Wolf 0 y=68, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=261.37109375, x=248.76171875, store=140
# Else activate before by Wolf 1 y=261.37109375, x=248.76171875, store=140
# Else activate after by Wolf 1 y=262.37109375, x=249.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=125.875, x=181.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=130
# 0 Sheep-after moving+eating y=296, x=16, store=140
# S.........................................
# 1 Sheep-before moving+eating y=292, x=8, store=130
# 1 Sheep-after moving+eating y=293, x=9, store=140
# S.........................................
# 2 Sheep-before moving+eating y=108, x=239, store=130
# 2 Sheep-after moving+eating y=109, x=240, store=140
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=130
# 3 Sheep-after moving+eating y=249, x=142, store=140
# S.........................................
# 4 Sheep-before moving+eating y=83, x=14, store=130
# 4 Sheep-after moving+eating y=84, x=15, store=140
# S.........................................
# 5 Sheep-before moving+eating y=166, x=37, store=130
# 5 Sheep-after moving+eating y=167, x=38, store=140
# S.........................................
# 6 Sheep-before moving+eating y=19, x=218, store=130
# 6 Sheep-after moving+eating y=18, x=217, store=140
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=68, x=180, store=0
# Else activate before by Wolf 0 y=68, x=180, store=0
# Else activate after by Wolf 0 y=67, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=262.37109375, x=249.76171875, store=140
# Else activate before by Wolf 1 y=262.37109375, x=249.76171875, store=140
# Else activate after by Wolf 1 y=263.37109375, x=250.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=181.5, store=40
# Else activate before by Wolf 4 y=125.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=140
# 0 Sheep-after moving+eating y=297, x=17, store=150
# S.........................................
# 1 Sheep-before moving+eating y=293, x=9, store=140
# 1 Sheep-after moving+eating y=294, x=10, store=150
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=140
# 2 Sheep-after moving+eating y=110, x=241, store=150
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=140
# 3 Sheep-after moving+eating y=250, x=141, store=150
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=140
# 4 Sheep-after moving+eating y=85, x=16, store=150
# S.........................................
# 5 Sheep-before moving+eating y=167, x=38, store=140
# 5 Sheep-after moving+eating y=168, x=37, store=150
# S.........................................
# 6 Sheep-before moving+eating y=18, x=217, store=140
# 6 Sheep-after moving+eating y=17, x=216, store=150
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=179, store=0
# Else activate before by Wolf 0 y=67, x=179, store=0
# Else activate after by Wolf 0 y=66, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.37109375, x=250.76171875, store=140
# Else activate before by Wolf 1 y=263.37109375, x=250.76171875, store=140
# Else activate after by Wolf 1 y=262.37109375, x=251.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=149, x=138, store=0
# Else activate before by Wolf 2 y=149, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=297, x=17, store=150
# 0 Sheep-after moving+eating y=298, x=18, store=160
# S.........................................
# 1 Sheep-before moving+eating y=294, x=10, store=150
# 1 Sheep-after moving+eating y=293, x=11, store=160
# S.........................................
# 2 Sheep-before moving+eating y=110, x=241, store=150
# 2 Sheep-after moving+eating y=109, x=242, store=160
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=150
# 3 Sheep-after moving+eating y=249, x=142, store=160
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=150
# 4 Sheep-after moving+eating y=86, x=15, store=160
# S.........................................
# 5 Sheep-before moving+eating y=168, x=37, store=150
# 5 Sheep-after moving+eating y=169, x=36, store=160
# S.........................................
# 6 Sheep-before moving+eating y=17, x=216, store=150
# 6 Sheep-after moving+eating y=18, x=215, store=160
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=178, store=0
# Else activate before by Wolf 0 y=66, x=178, store=0
# Else activate after by Wolf 0 y=67, x=177, store=0
# E.........................................
# 1 Wolf - before moving/eating y=262.37109375, x=251.76171875, store=140
# Else activate before by Wolf 1 y=262.37109375, x=251.76171875, store=140
# Else activate after by Wolf 1 y=261.37109375, x=250.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=298, x=18, store=160
# 0 Sheep-after moving+eating y=299, x=19, store=170
# S.........................................
# 1 Sheep-before moving+eating y=293, x=11, store=160
# 1 Sheep-after moving+eating y=292, x=10, store=170
# S.........................................
# 2 Sheep-before moving+eating y=109, x=242, store=160
# 2 Sheep-after moving+eating y=108, x=241, store=170
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=160
# 3 Sheep-after moving+eating y=248, x=143, store=170
# S.........................................
# 4 Sheep-before moving+eating y=86, x=15, store=160
# 4 Sheep-after moving+eating y=85, x=16, store=170
# S.........................................
# 5 Sheep-before moving+eating y=169, x=36, store=160
# 5 Sheep-after moving+eating y=168, x=37, store=170
# S.........................................
# 6 Sheep-before moving+eating y=18, x=215, store=160
# 6 Sheep-after moving+eating y=19, x=214, store=170
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=177, store=0
# Else activate before by Wolf 0 y=67, x=177, store=0
# Else activate after by Wolf 0 y=66, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating y=261.37109375, x=250.76171875, store=140
# Else activate before by Wolf 1 y=261.37109375, x=250.76171875, store=140
# Else activate after by Wolf 1 y=262.37109375, x=249.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=149, x=136, store=0
# Else activate before by Wolf 2 y=149, x=136, store=0
# Else activate after by Wolf 2 y=148, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=299, x=19, store=170
# 0 Sheep-after moving+eating y=0, x=18, store=180
# S.........................................
# 1 Sheep-before moving+eating y=292, x=10, store=170
# 1 Sheep-after moving+eating y=291, x=9, store=180
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=170
# 2 Sheep-after moving+eating y=107, x=242, store=180
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=170
# 3 Sheep-after moving+eating y=249, x=144, store=180
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=170
# 4 Sheep-after moving+eating y=86, x=17, store=180
# S.........................................
# 5 Sheep-before moving+eating y=168, x=37, store=170
# 5 Sheep-after moving+eating y=167, x=36, store=180
# S.........................................
# 6 Sheep-before moving+eating y=19, x=214, store=170
# 6 Sheep-after moving+eating y=20, x=213, store=180
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=176, store=0
# Else activate before by Wolf 0 y=66, x=176, store=0
# Else activate after by Wolf 0 y=67, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating y=262.37109375, x=249.76171875, store=140
# Else activate before by Wolf 1 y=262.37109375, x=249.76171875, store=140
# Else activate after by Wolf 1 y=263.37109375, x=250.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=148, x=135, store=0
# Else activate before by Wolf 2 y=148, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=124.875, x=180.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=0, x=18, store=180
# 0 Sheep-after moving+eating y=299, x=17, store=190
# S.........................................
# 1 Sheep-before moving+eating y=291, x=9, store=180
# 1 Sheep-after moving+eating y=290, x=8, store=190
# S.........................................
# 2 Sheep-before moving+eating y=107, x=242, store=180
# 2 Sheep-after moving+eating y=106, x=241, store=190
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=180
# 3 Sheep-after moving+eating y=250, x=143, store=190
# S.........................................
# 4 Sheep-before moving+eating y=86, x=17, store=180
# 4 Sheep-after moving+eating y=87, x=16, store=190
# S.........................................
# 5 Sheep-before moving+eating y=167, x=36, store=180
# 5 Sheep-after moving+eating y=168, x=37, store=190
# S.........................................
# 6 Sheep-before moving+eating y=20, x=213, store=180
# 6 Sheep-after moving+eating y=21, x=214, store=190
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=175, store=0
# Else activate before by Wolf 0 y=67, x=175, store=0
# Else activate after by Wolf 0 y=68, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.37109375, x=250.76171875, store=140
# Else activate before by Wolf 1 y=263.37109375, x=250.76171875, store=140
# Else activate after by Wolf 1 y=264.37109375, x=249.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=124.875, x=180.5, store=40
# Else activate before by Wolf 4 y=124.875, x=180.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=299, x=17, store=190
# 0 Sheep-after moving+eating y=298, x=16, store=200
# S.........................................
# 1 Sheep-before moving+eating y=290, x=8, store=190
# 1 Sheep-after moving+eating y=291, x=7, store=200
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=190
# 2 Sheep-after moving+eating y=107, x=240, store=200
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=190
# 3 Sheep-after moving+eating y=251, x=142, store=200
# S.........................................
# 4 Sheep-before moving+eating y=87, x=16, store=190
# 4 Sheep-after moving+eating y=88, x=17, store=200
# S.........................................
# 5 Sheep-before moving+eating y=168, x=37, store=190
# 5 Sheep-after moving+eating y=169, x=36, store=200
# S.........................................
# 6 Sheep-before moving+eating y=21, x=214, store=190
# 6 Sheep-after moving+eating y=22, x=215, store=200
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=68, x=176, store=0
# Else activate before by Wolf 0 y=68, x=176, store=0
# Else activate after by Wolf 0 y=69, x=177, store=0
# E.........................................
# 1 Wolf - before moving/eating y=264.37109375, x=249.76171875, store=140
# Else activate before by Wolf 1 y=264.37109375, x=249.76171875, store=140
# Else activate after by Wolf 1 y=263.37109375, x=248.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=123.875, x=179.5, store=40
# Else activate before by Wolf 4 y=123.875, x=179.5, store=40
# Else activate after by Wolf 4 y=122.875, x=178.5, store=40
# E.........................................
# Else_________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=298, x=16, store=200
# 0 Sheep-after moving+eating y=297, x=17, store=210
# S.........................................
# 1 Sheep-before moving+eating y=291, x=7, store=200
# 1 Sheep-after moving+eating y=292, x=6, store=210
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=200
# 2 Sheep-after moving+eating y=106, x=239, store=210
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=200
# 3 Sheep-after moving+eating y=250, x=143, store=210
# S.........................................
# 4 Sheep-before moving+eating y=88, x=17, store=200
# 4 Sheep-after moving+eating y=87, x=18, store=210
# S.........................................
# 5 Sheep-before moving+eating y=169, x=36, store=200
# 5 Sheep-after moving+eating y=170, x=37, store=210
# S.........................................
# 6 Sheep-before moving+eating y=22, x=215, store=200
# 6 Sheep-after moving+eating y=23, x=216, store=210
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=69, x=177, store=0
# Else activate before by Wolf 0 y=69, x=177, store=0
# Else activate after by Wolf 0 y=68, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.37109375, x=248.76171875, store=140
# Else activate before by Wolf 1 y=263.37109375, x=248.76171875, store=140
# Else activate after by Wolf 1 y=262.37109375, x=249.76171875, store=140
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=122.875, x=178.5, store=40
# Else activate before by Wolf 4 y=122.875, x=178.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Else_________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3dc6d93fe103> in <module>
#     183 model_menu.add_command(label="Run model", command=run)
#     184
# --> 185 tkinter.mainloop()
#     186
#     187 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:

# %% [markdown]
# with eaten and break

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('S.........................................')
    print('Sheep_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
            elif distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works? still target. what's getting activated?
        if eaten == True:
            break 
        elif closest_sheep != None:
            print('CL+ before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('CL+ after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')           
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Ends_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# S.........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# S.........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# S.........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# CL+ before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# CL+ after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# CL+ before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# CL+ after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# S.........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# S.........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# S.........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# S.........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# S.........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# S.........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# CL+ before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# CL+ after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# CL+ before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# CL+ after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# S.........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# S.........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# S.........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# S.........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# S.........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# S.........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# CL+ before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# CL+ after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# CL+ before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# CL+ after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# S.........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# S.........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# S.........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# S.........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# S.........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# S.........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# CL+ before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# CL+ after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# Eaten_________________________________________
# Ends_________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=17, store=50
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=218, x=246, store=50
# S.........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=296, x=10, store=50
# S.........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=104, x=239, store=50
# S.........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=250, x=141, store=50
# S.........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=16, store=50
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=39, store=50
# S.........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=23, x=216, store=50
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=218, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=218, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# Eaten_________________________________________
# >>> min_dist = 48.41269526167697 Sheep 6 y=265, x=251, store=50 by Wolf 1 y=216.9375, x=245.1875, store=50
# Ends_________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=17, store=50
# 0 Sheep-after moving+eating y=294, x=18, store=60
# S.........................................
# 1 Sheep-before moving+eating y=296, x=10, store=50
# 1 Sheep-after moving+eating y=297, x=11, store=60
# S.........................................
# 2 Sheep-before moving+eating y=104, x=239, store=50
# 2 Sheep-after moving+eating y=103, x=238, store=60
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=50
# 3 Sheep-after moving+eating y=251, x=140, store=60
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=50
# 4 Sheep-after moving+eating y=82, x=15, store=60
# S.........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=266, x=250, store=60
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=50
# 6 Sheep-after moving+eating y=165, x=40, store=60
# S.........................................
# 7 Sheep-before moving+eating y=23, x=216, store=50
# 7 Sheep-after moving+eating y=24, x=215, store=60
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=50
# >>> min_dist = 49.297962052198464 Sheep 5 y=266, x=250, store=60 by Wolf 1 y=216.9375, x=245.1875, store=50
# CL+ before y=266, x=250, store=60 Wolf 1 y=216.9375, x=245.1875, store=50
# CL+ after y=266, x=250, store=60 Wolf 1 y=241.46875, x=247.59375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=232, x=86, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=131.875, x=185.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=60
# 0 Sheep-after moving+eating y=295, x=19, store=70
# S.........................................
# 1 Sheep-before moving+eating y=297, x=11, store=60
# 1 Sheep-after moving+eating y=298, x=12, store=70
# S.........................................
# 2 Sheep-before moving+eating y=103, x=238, store=60
# 2 Sheep-after moving+eating y=102, x=237, store=70
# S.........................................
# 3 Sheep-before moving+eating y=251, x=140, store=60
# 3 Sheep-after moving+eating y=252, x=139, store=70
# S.........................................
# 4 Sheep-before moving+eating y=82, x=15, store=60
# 4 Sheep-after moving+eating y=81, x=14, store=70
# S.........................................
# 5 Sheep-before moving+eating y=266, x=250, store=60
# 5 Sheep-after moving+eating y=267, x=251, store=70
# S.........................................
# 6 Sheep-before moving+eating y=165, x=40, store=60
# 6 Sheep-after moving+eating y=166, x=39, store=70
# S.........................................
# 7 Sheep-before moving+eating y=24, x=215, store=60
# 7 Sheep-after moving+eating y=25, x=216, store=70
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=183, store=0
# Else activate before by Wolf 0 y=71, x=183, store=0
# Else activate after by Wolf 0 y=72, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating y=241.46875, x=247.59375, store=50
# >>> min_dist = 25.757470093644677 Sheep 5 y=267, x=251, store=70 by Wolf 1 y=241.46875, x=247.59375, store=50
# CL+ before y=267, x=251, store=70 Wolf 1 y=241.46875, x=247.59375, store=50
# CL+ after y=267, x=251, store=70 Wolf 1 y=254.234375, x=249.296875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=144, x=133, store=0
# Else activate before by Wolf 2 y=144, x=133, store=0
# Else activate after by Wolf 2 y=143, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating y=232, x=86, store=0
# Else activate before by Wolf 3 y=232, x=86, store=0
# Else activate after by Wolf 3 y=231, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=131.875, x=185.5, store=40
# Else activate before by Wolf 4 y=131.875, x=185.5, store=40
# Else activate after by Wolf 4 y=130.875, x=184.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=295, x=19, store=70
# 0 Sheep-after moving+eating y=294, x=18, store=80
# S.........................................
# 1 Sheep-before moving+eating y=298, x=12, store=70
# 1 Sheep-after moving+eating y=299, x=11, store=80
# S.........................................
# 2 Sheep-before moving+eating y=102, x=237, store=70
# 2 Sheep-after moving+eating y=101, x=238, store=80
# S.........................................
# 3 Sheep-before moving+eating y=252, x=139, store=70
# 3 Sheep-after moving+eating y=253, x=140, store=80
# S.........................................
# 4 Sheep-before moving+eating y=81, x=14, store=70
# 4 Sheep-after moving+eating y=80, x=13, store=80
# S.........................................
# 5 Sheep-before moving+eating y=267, x=251, store=70
# 5 Sheep-after moving+eating y=268, x=252, store=80
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=70
# 6 Sheep-after moving+eating y=167, x=40, store=80
# S.........................................
# 7 Sheep-before moving+eating y=25, x=216, store=70
# 7 Sheep-after moving+eating y=24, x=215, store=80
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=184, store=0
# Else activate before by Wolf 0 y=72, x=184, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating y=254.234375, x=249.296875, store=50
# >>> min_dist = 14.028517968989098 Sheep 5 y=268, x=252, store=80 by Wolf 1 y=254.234375, x=249.296875, store=50
# CL+ before y=268, x=252, store=80 Wolf 1 y=254.234375, x=249.296875, store=50
# CL+ after y=268, x=252, store=80 Wolf 1 y=261.1171875, x=250.6484375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=143, x=132, store=0
# Else activate before by Wolf 2 y=143, x=132, store=0
# Else activate after by Wolf 2 y=142, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=231, x=87, store=0
# Else activate before by Wolf 3 y=231, x=87, store=0
# Else activate after by Wolf 3 y=230, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=80
# 0 Sheep-after moving+eating y=295, x=19, store=90
# S.........................................
# 1 Sheep-before moving+eating y=299, x=11, store=80
# 1 Sheep-after moving+eating y=298, x=10, store=90
# S.........................................
# 2 Sheep-before moving+eating y=101, x=238, store=80
# 2 Sheep-after moving+eating y=100, x=237, store=90
# S.........................................
# 3 Sheep-before moving+eating y=253, x=140, store=80
# 3 Sheep-after moving+eating y=252, x=139, store=90
# S.........................................
# 4 Sheep-before moving+eating y=80, x=13, store=80
# 4 Sheep-after moving+eating y=81, x=14, store=90
# S.........................................
# 5 Sheep-before moving+eating y=268, x=252, store=80
# 5 Sheep-after moving+eating y=267, x=253, store=90
# S.........................................
# 6 Sheep-before moving+eating y=167, x=40, store=80
# 6 Sheep-after moving+eating y=166, x=39, store=90
# S.........................................
# 7 Sheep-before moving+eating y=24, x=215, store=80
# 7 Sheep-after moving+eating y=25, x=214, store=90
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating y=261.1171875, x=250.6484375, store=50
# >>> min_dist = 6.335402836565525 Sheep 5 y=267, x=253, store=90 by Wolf 1 y=261.1171875, x=250.6484375, store=50
# CL+ before y=267, x=253, store=90 Wolf 1 y=261.1171875, x=250.6484375, store=50
# CL+ after y=267, x=253, store=90 Wolf 1 y=264.05859375, x=251.82421875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=142, x=133, store=0
# Else activate before by Wolf 2 y=142, x=133, store=0
# Else activate after by Wolf 2 y=141, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating y=230, x=88, store=0
# Else activate before by Wolf 3 y=230, x=88, store=0
# Else activate after by Wolf 3 y=229, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=295, x=19, store=90
# 0 Sheep-after moving+eating y=296, x=20, store=100
# S.........................................
# 1 Sheep-before moving+eating y=298, x=10, store=90
# 1 Sheep-after moving+eating y=297, x=11, store=100
# S.........................................
# 2 Sheep-before moving+eating y=100, x=237, store=90
# 2 Sheep-after moving+eating y=101, x=236, store=100
# S.........................................
# 3 Sheep-before moving+eating y=252, x=139, store=90
# 3 Sheep-after moving+eating y=251, x=138, store=100
# S.........................................
# 4 Sheep-before moving+eating y=81, x=14, store=90
# 4 Sheep-after moving+eating y=80, x=13, store=100
# S.........................................
# 5 Sheep-before moving+eating y=267, x=253, store=90
# 5 Sheep-after moving+eating y=268, x=252, store=100
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=90
# 6 Sheep-after moving+eating y=165, x=40, store=100
# S.........................................
# 7 Sheep-before moving+eating y=25, x=214, store=90
# 7 Sheep-after moving+eating y=24, x=215, store=100
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=75, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating y=264.05859375, x=251.82421875, store=50
# >>> Sheep going to be eaten 5 y=268, x=252, store=100 by Wolf 1 y=264.05859375, x=251.82421875, store=50
# >>> Sheep eaten 5 y=268, x=252, store=0 by Wolf 1 y=264.05859375, x=251.82421875, store=150
# Eaten_________________________________________
# Ends_________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=296, x=20, store=100
# 0 Sheep-after moving+eating y=297, x=19, store=110
# S.........................................
# 1 Sheep-before moving+eating y=297, x=11, store=100
# 1 Sheep-after moving+eating y=298, x=10, store=110
# S.........................................
# 2 Sheep-before moving+eating y=101, x=236, store=100
# 2 Sheep-after moving+eating y=100, x=235, store=110
# S.........................................
# 3 Sheep-before moving+eating y=251, x=138, store=100
# 3 Sheep-after moving+eating y=250, x=139, store=110
# S.........................................
# 4 Sheep-before moving+eating y=80, x=13, store=100
# 4 Sheep-after moving+eating y=81, x=14, store=110
# S.........................................
# 5 Sheep-before moving+eating y=165, x=40, store=100
# 5 Sheep-after moving+eating y=166, x=41, store=110
# S.........................................
# 6 Sheep-before moving+eating y=24, x=215, store=100
# 6 Sheep-after moving+eating y=23, x=216, store=110
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=75, x=185, store=0
# Else activate before by Wolf 0 y=75, x=185, store=0
# Else activate after by Wolf 0 y=76, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating y=264.05859375, x=251.82421875, store=150
# Else activate before by Wolf 1 y=264.05859375, x=251.82421875, store=150
# Else activate after by Wolf 1 y=265.05859375, x=252.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=141, x=132, store=0
# Else activate before by Wolf 2 y=141, x=132, store=0
# Else activate after by Wolf 2 y=140, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=229, x=89, store=0
# Else activate before by Wolf 3 y=229, x=89, store=0
# Else activate after by Wolf 3 y=228, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=297, x=19, store=110
# 0 Sheep-after moving+eating y=298, x=20, store=120
# S.........................................
# 1 Sheep-before moving+eating y=298, x=10, store=110
# 1 Sheep-after moving+eating y=297, x=11, store=120
# S.........................................
# 2 Sheep-before moving+eating y=100, x=235, store=110
# 2 Sheep-after moving+eating y=99, x=234, store=120
# S.........................................
# 3 Sheep-before moving+eating y=250, x=139, store=110
# 3 Sheep-after moving+eating y=251, x=138, store=120
# S.........................................
# 4 Sheep-before moving+eating y=81, x=14, store=110
# 4 Sheep-after moving+eating y=80, x=15, store=120
# S.........................................
# 5 Sheep-before moving+eating y=166, x=41, store=110
# 5 Sheep-after moving+eating y=165, x=40, store=120
# S.........................................
# 6 Sheep-before moving+eating y=23, x=216, store=110
# 6 Sheep-after moving+eating y=24, x=217, store=120
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=76, x=184, store=0
# Else activate before by Wolf 0 y=76, x=184, store=0
# Else activate after by Wolf 0 y=75, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.05859375, x=252.82421875, store=150
# Else activate before by Wolf 1 y=265.05859375, x=252.82421875, store=150
# Else activate after by Wolf 1 y=266.05859375, x=251.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=140, x=133, store=0
# Else activate before by Wolf 2 y=140, x=133, store=0
# Else activate after by Wolf 2 y=141, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=228, x=90, store=0
# Else activate before by Wolf 3 y=228, x=90, store=0
# Else activate after by Wolf 3 y=227, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=130.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=298, x=20, store=120
# 0 Sheep-after moving+eating y=297, x=19, store=130
# S.........................................
# 1 Sheep-before moving+eating y=297, x=11, store=120
# 1 Sheep-after moving+eating y=296, x=12, store=130
# S.........................................
# 2 Sheep-before moving+eating y=99, x=234, store=120
# 2 Sheep-after moving+eating y=100, x=233, store=130
# S.........................................
# 3 Sheep-before moving+eating y=251, x=138, store=120
# 3 Sheep-after moving+eating y=250, x=139, store=130
# S.........................................
# 4 Sheep-before moving+eating y=80, x=15, store=120
# 4 Sheep-after moving+eating y=79, x=16, store=130
# S.........................................
# 5 Sheep-before moving+eating y=165, x=40, store=120
# 5 Sheep-after moving+eating y=164, x=41, store=130
# S.........................................
# 6 Sheep-before moving+eating y=24, x=217, store=120
# 6 Sheep-after moving+eating y=25, x=218, store=130
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=75, x=185, store=0
# Else activate before by Wolf 0 y=75, x=185, store=0
# Else activate after by Wolf 0 y=74, x=186, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.05859375, x=251.82421875, store=150
# Else activate before by Wolf 1 y=266.05859375, x=251.82421875, store=150
# Else activate after by Wolf 1 y=265.05859375, x=250.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=141, x=134, store=0
# Else activate before by Wolf 2 y=141, x=134, store=0
# Else activate after by Wolf 2 y=142, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=227, x=89, store=0
# Else activate before by Wolf 3 y=227, x=89, store=0
# Else activate after by Wolf 3 y=228, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=182.5, store=40
# Else activate before by Wolf 4 y=130.875, x=182.5, store=40
# Else activate after by Wolf 4 y=131.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=297, x=19, store=130
# 0 Sheep-after moving+eating y=296, x=20, store=140
# S.........................................
# 1 Sheep-before moving+eating y=296, x=12, store=130
# 1 Sheep-after moving+eating y=295, x=11, store=140
# S.........................................
# 2 Sheep-before moving+eating y=100, x=233, store=130
# 2 Sheep-after moving+eating y=101, x=234, store=140
# S.........................................
# 3 Sheep-before moving+eating y=250, x=139, store=130
# 3 Sheep-after moving+eating y=251, x=138, store=140
# S.........................................
# 4 Sheep-before moving+eating y=79, x=16, store=130
# 4 Sheep-after moving+eating y=80, x=17, store=140
# S.........................................
# 5 Sheep-before moving+eating y=164, x=41, store=130
# 5 Sheep-after moving+eating y=163, x=40, store=140
# S.........................................
# 6 Sheep-before moving+eating y=25, x=218, store=130
# 6 Sheep-after moving+eating y=26, x=217, store=140
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=74, x=186, store=0
# Else activate before by Wolf 0 y=74, x=186, store=0
# Else activate after by Wolf 0 y=75, x=187, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.05859375, x=250.82421875, store=150
# Else activate before by Wolf 1 y=265.05859375, x=250.82421875, store=150
# Else activate after by Wolf 1 y=266.05859375, x=251.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=142, x=133, store=0
# Else activate before by Wolf 2 y=142, x=133, store=0
# Else activate after by Wolf 2 y=141, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating y=228, x=88, store=0
# Else activate before by Wolf 3 y=228, x=88, store=0
# Else activate after by Wolf 3 y=229, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=131.875, x=181.5, store=40
# Else activate before by Wolf 4 y=131.875, x=181.5, store=40
# Else activate after by Wolf 4 y=132.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=296, x=20, store=140
# 0 Sheep-after moving+eating y=295, x=19, store=150
# S.........................................
# 1 Sheep-before moving+eating y=295, x=11, store=140
# 1 Sheep-after moving+eating y=294, x=10, store=150
# S.........................................
# 2 Sheep-before moving+eating y=101, x=234, store=140
# 2 Sheep-after moving+eating y=102, x=235, store=150
# S.........................................
# 3 Sheep-before moving+eating y=251, x=138, store=140
# 3 Sheep-after moving+eating y=252, x=139, store=150
# S.........................................
# 4 Sheep-before moving+eating y=80, x=17, store=140
# 4 Sheep-after moving+eating y=81, x=16, store=150
# S.........................................
# 5 Sheep-before moving+eating y=163, x=40, store=140
# 5 Sheep-after moving+eating y=164, x=39, store=150
# S.........................................
# 6 Sheep-before moving+eating y=26, x=217, store=140
# 6 Sheep-after moving+eating y=27, x=218, store=150
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=75, x=187, store=0
# Else activate before by Wolf 0 y=75, x=187, store=0
# Else activate after by Wolf 0 y=76, x=188, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.05859375, x=251.82421875, store=150
# Else activate before by Wolf 1 y=266.05859375, x=251.82421875, store=150
# Else activate after by Wolf 1 y=267.05859375, x=252.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=141, x=132, store=0
# Else activate before by Wolf 2 y=141, x=132, store=0
# Else activate after by Wolf 2 y=142, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating y=229, x=89, store=0
# Else activate before by Wolf 3 y=229, x=89, store=0
# Else activate after by Wolf 3 y=230, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=132.875, x=182.5, store=40
# Else activate before by Wolf 4 y=132.875, x=182.5, store=40
# Else activate after by Wolf 4 y=133.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=295, x=19, store=150
# 0 Sheep-after moving+eating y=294, x=18, store=160
# S.........................................
# 1 Sheep-before moving+eating y=294, x=10, store=150
# 1 Sheep-after moving+eating y=293, x=9, store=160
# S.........................................
# 2 Sheep-before moving+eating y=102, x=235, store=150
# 2 Sheep-after moving+eating y=101, x=236, store=160
# S.........................................
# 3 Sheep-before moving+eating y=252, x=139, store=150
# 3 Sheep-after moving+eating y=251, x=138, store=160
# S.........................................
# 4 Sheep-before moving+eating y=81, x=16, store=150
# 4 Sheep-after moving+eating y=80, x=15, store=160
# S.........................................
# 5 Sheep-before moving+eating y=164, x=39, store=150
# 5 Sheep-after moving+eating y=163, x=38, store=160
# S.........................................
# 6 Sheep-before moving+eating y=27, x=218, store=150
# 6 Sheep-after moving+eating y=28, x=219, store=160
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=76, x=188, store=0
# Else activate before by Wolf 0 y=76, x=188, store=0
# Else activate after by Wolf 0 y=75, x=189, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.05859375, x=252.82421875, store=150
# Else activate before by Wolf 1 y=267.05859375, x=252.82421875, store=150
# Else activate after by Wolf 1 y=266.05859375, x=253.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=142, x=131, store=0
# Else activate before by Wolf 2 y=142, x=131, store=0
# Else activate after by Wolf 2 y=141, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating y=230, x=90, store=0
# Else activate before by Wolf 3 y=230, x=90, store=0
# Else activate after by Wolf 3 y=231, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.875, x=181.5, store=40
# Else activate before by Wolf 4 y=133.875, x=181.5, store=40
# Else activate after by Wolf 4 y=134.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=294, x=18, store=160
# 0 Sheep-after moving+eating y=295, x=17, store=170
# S.........................................
# 1 Sheep-before moving+eating y=293, x=9, store=160
# 1 Sheep-after moving+eating y=294, x=8, store=170
# S.........................................
# 2 Sheep-before moving+eating y=101, x=236, store=160
# 2 Sheep-after moving+eating y=100, x=235, store=170
# S.........................................
# 3 Sheep-before moving+eating y=251, x=138, store=160
# 3 Sheep-after moving+eating y=252, x=137, store=170
# S.........................................
# 4 Sheep-before moving+eating y=80, x=15, store=160
# 4 Sheep-after moving+eating y=81, x=16, store=170
# S.........................................
# 5 Sheep-before moving+eating y=163, x=38, store=160
# 5 Sheep-after moving+eating y=164, x=39, store=170
# S.........................................
# 6 Sheep-before moving+eating y=28, x=219, store=160
# 6 Sheep-after moving+eating y=29, x=220, store=170
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=75, x=189, store=0
# Else activate before by Wolf 0 y=75, x=189, store=0
# Else activate after by Wolf 0 y=74, x=188, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.05859375, x=253.82421875, store=150
# Else activate before by Wolf 1 y=266.05859375, x=253.82421875, store=150
# Else activate after by Wolf 1 y=265.05859375, x=252.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=141, x=132, store=0
# Else activate before by Wolf 2 y=141, x=132, store=0
# Else activate after by Wolf 2 y=140, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=231, x=89, store=0
# Else activate before by Wolf 3 y=231, x=89, store=0
# Else activate after by Wolf 3 y=230, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=134.875, x=180.5, store=40
# Else activate before by Wolf 4 y=134.875, x=180.5, store=40
# Else activate after by Wolf 4 y=133.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=170
# 0 Sheep-after moving+eating y=296, x=16, store=180
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=170
# 1 Sheep-after moving+eating y=293, x=7, store=180
# S.........................................
# 2 Sheep-before moving+eating y=100, x=235, store=170
# 2 Sheep-after moving+eating y=101, x=234, store=180
# S.........................................
# 3 Sheep-before moving+eating y=252, x=137, store=170
# 3 Sheep-after moving+eating y=251, x=136, store=180
# S.........................................
# 4 Sheep-before moving+eating y=81, x=16, store=170
# 4 Sheep-after moving+eating y=80, x=17, store=180
# S.........................................
# 5 Sheep-before moving+eating y=164, x=39, store=170
# 5 Sheep-after moving+eating y=163, x=38, store=180
# S.........................................
# 6 Sheep-before moving+eating y=29, x=220, store=170
# 6 Sheep-after moving+eating y=30, x=219, store=180
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=74, x=188, store=0
# Else activate before by Wolf 0 y=74, x=188, store=0
# Else activate after by Wolf 0 y=73, x=187, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.05859375, x=252.82421875, store=150
# Else activate before by Wolf 1 y=265.05859375, x=252.82421875, store=150
# Else activate after by Wolf 1 y=264.05859375, x=253.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=140, x=133, store=0
# Else activate before by Wolf 2 y=140, x=133, store=0
# Else activate after by Wolf 2 y=141, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=230, x=90, store=0
# Else activate before by Wolf 3 y=230, x=90, store=0
# Else activate after by Wolf 3 y=231, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.875, x=181.5, store=40
# Else activate before by Wolf 4 y=133.875, x=181.5, store=40
# Else activate after by Wolf 4 y=132.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=180
# 0 Sheep-after moving+eating y=297, x=15, store=190
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=180
# 1 Sheep-after moving+eating y=294, x=6, store=190
# S.........................................
# 2 Sheep-before moving+eating y=101, x=234, store=180
# 2 Sheep-after moving+eating y=102, x=235, store=190
# S.........................................
# 3 Sheep-before moving+eating y=251, x=136, store=180
# 3 Sheep-after moving+eating y=252, x=135, store=190
# S.........................................
# 4 Sheep-before moving+eating y=80, x=17, store=180
# 4 Sheep-after moving+eating y=79, x=16, store=190
# S.........................................
# 5 Sheep-before moving+eating y=163, x=38, store=180
# 5 Sheep-after moving+eating y=162, x=39, store=190
# S.........................................
# 6 Sheep-before moving+eating y=30, x=219, store=180
# 6 Sheep-after moving+eating y=29, x=218, store=190
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=73, x=187, store=0
# Else activate before by Wolf 0 y=73, x=187, store=0
# Else activate after by Wolf 0 y=72, x=186, store=0
# E.........................................
# 1 Wolf - before moving/eating y=264.05859375, x=253.82421875, store=150
# Else activate before by Wolf 1 y=264.05859375, x=253.82421875, store=150
# Else activate after by Wolf 1 y=263.05859375, x=252.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=141, x=134, store=0
# Else activate before by Wolf 2 y=141, x=134, store=0
# Else activate after by Wolf 2 y=142, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=231, x=91, store=0
# >>> min_dist = 48.75448697299562 Sheep 3 y=252, x=135, store=190 by Wolf 3 y=231, x=91, store=0
# CL+ before y=252, x=135, store=190 Wolf 3 y=231, x=91, store=0
# CL+ after y=252, x=135, store=190 Wolf 3 y=241.5, x=113.0, store=0
# Y.........................................
# 4 Wolf - before moving/eating y=132.875, x=180.5, store=40
# Else activate before by Wolf 4 y=132.875, x=180.5, store=40
# Else activate after by Wolf 4 y=133.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=297, x=15, store=190
# 0 Sheep-after moving+eating y=298, x=16, store=200
# S.........................................
# 1 Sheep-before moving+eating y=294, x=6, store=190
# 1 Sheep-after moving+eating y=295, x=7, store=200
# S.........................................
# 2 Sheep-before moving+eating y=102, x=235, store=190
# 2 Sheep-after moving+eating y=103, x=236, store=200
# S.........................................
# 3 Sheep-before moving+eating y=252, x=135, store=190
# 3 Sheep-after moving+eating y=253, x=134, store=200
# S.........................................
# 4 Sheep-before moving+eating y=79, x=16, store=190
# 4 Sheep-after moving+eating y=80, x=17, store=200
# S.........................................
# 5 Sheep-before moving+eating y=162, x=39, store=190
# 5 Sheep-after moving+eating y=163, x=40, store=200
# S.........................................
# 6 Sheep-before moving+eating y=29, x=218, store=190
# 6 Sheep-after moving+eating y=28, x=217, store=200
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=186, store=0
# Else activate before by Wolf 0 y=72, x=186, store=0
# Else activate after by Wolf 0 y=71, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.05859375, x=252.82421875, store=150
# Else activate before by Wolf 1 y=263.05859375, x=252.82421875, store=150
# Else activate after by Wolf 1 y=264.05859375, x=251.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=142, x=133, store=0
# Else activate before by Wolf 2 y=142, x=133, store=0
# Else activate after by Wolf 2 y=143, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating y=241.5, x=113.0, store=0
# >>> min_dist = 23.942639787625758 Sheep 3 y=253, x=134, store=200 by Wolf 3 y=241.5, x=113.0, store=0
# CL+ before y=253, x=134, store=200 Wolf 3 y=241.5, x=113.0, store=0
# CL+ after y=253, x=134, store=200 Wolf 3 y=247.25, x=123.5, store=0
# Y.........................................
# 4 Wolf - before moving/eating y=133.875, x=179.5, store=40
# Else activate before by Wolf 4 y=133.875, x=179.5, store=40
# Else activate after by Wolf 4 y=134.875, x=178.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=298, x=16, store=200
# 0 Sheep-after moving+eating y=299, x=17, store=210
# S.........................................
# 1 Sheep-before moving+eating y=295, x=7, store=200
# 1 Sheep-after moving+eating y=296, x=6, store=210
# S.........................................
# 2 Sheep-before moving+eating y=103, x=236, store=200
# 2 Sheep-after moving+eating y=104, x=237, store=210
# S.........................................
# 3 Sheep-before moving+eating y=253, x=134, store=200
# 3 Sheep-after moving+eating y=254, x=135, store=210
# S.........................................
# 4 Sheep-before moving+eating y=80, x=17, store=200
# 4 Sheep-after moving+eating y=79, x=16, store=210
# S.........................................
# 5 Sheep-before moving+eating y=163, x=40, store=200
# 5 Sheep-after moving+eating y=162, x=39, store=210
# S.........................................
# 6 Sheep-before moving+eating y=28, x=217, store=200
# 6 Sheep-after moving+eating y=29, x=216, store=210
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=185, store=0
# Else activate before by Wolf 0 y=71, x=185, store=0
# Else activate after by Wolf 0 y=70, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating y=264.05859375, x=251.82421875, store=150
# Else activate before by Wolf 1 y=264.05859375, x=251.82421875, store=150
# Else activate after by Wolf 1 y=263.05859375, x=252.82421875, store=150
# E.........................................
# 2 Wolf - before moving/eating y=143, x=132, store=0
# Else activate before by Wolf 2 y=143, x=132, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating y=247.25, x=123.5, store=0
# >>> min_dist = 13.334635353094587 Sheep 3 y=254, x=135, store=210 by Wolf 3 y=247.25, x=123.5, store=0
# CL+ before y=254, x=135, store=210 Wolf 3 y=247.25, x=123.5, store=0
# CL+ after y=254, x=135, store=210 Wolf 3 y=250.625, x=129.25, store=0
# Y.........................................
# 4 Wolf - before moving/eating y=134.875, x=178.5, store=40
# Else activate before by Wolf 4 y=134.875, x=178.5, store=40
# Else activate after by Wolf 4 y=133.875, x=177.5, store=40
# E.........................................
# Ends_________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-58c02bdb460b> in <module>
#     183 model_menu.add_command(label="Run model", command=run)
#     184
# --> 185 tkinter.mainloop()
#     186
#     187 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:

# %% [markdown]
# with eaten and continue instead of break

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('S.........................................')
    print('Sheep_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
            elif distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works? still target. what's getting activated?
        if eaten == True:
            #break
            continue
        elif closest_sheep != None:
            print('CL+ before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('CL+ after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')           
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Ends_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# S.........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# S.........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# S.........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# CL+ before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# CL+ after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# CL+ before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# CL+ after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# S.........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# S.........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# S.........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# S.........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# S.........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# S.........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# CL+ before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# CL+ after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# CL+ before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# CL+ after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# S.........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# S.........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# S.........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# S.........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# S.........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# S.........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# CL+ before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# CL+ after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# CL+ before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# CL+ after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# S.........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# S.........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# S.........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# S.........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# S.........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# S.........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# CL+ before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# CL+ after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# Eaten_________________________________________
# Ends_________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=17, store=50
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=218, x=246, store=50
# S.........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=296, x=10, store=50
# S.........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=104, x=239, store=50
# S.........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=250, x=141, store=50
# S.........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=16, store=50
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=39, store=50
# S.........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=23, x=216, store=50
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=218, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=218, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# Eaten_________________________________________
# >>> min_dist = 48.41269526167697 Sheep 6 y=265, x=251, store=50 by Wolf 1 y=216.9375, x=245.1875, store=50
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=17, store=50
# 0 Sheep-after moving+eating y=294, x=16, store=60
# S.........................................
# 1 Sheep-before moving+eating y=296, x=10, store=50
# 1 Sheep-after moving+eating y=295, x=9, store=60
# S.........................................
# 2 Sheep-before moving+eating y=104, x=239, store=50
# 2 Sheep-after moving+eating y=105, x=238, store=60
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=50
# 3 Sheep-after moving+eating y=249, x=142, store=60
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=50
# 4 Sheep-after moving+eating y=84, x=15, store=60
# S.........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=264, x=252, store=60
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=50
# 6 Sheep-after moving+eating y=165, x=38, store=60
# S.........................................
# 7 Sheep-before moving+eating y=23, x=216, store=50
# 7 Sheep-after moving+eating y=22, x=215, store=60
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=50
# >>> min_dist = 47.55301318002888 Sheep 5 y=264, x=252, store=60 by Wolf 1 y=216.9375, x=245.1875, store=50
# CL+ before y=264, x=252, store=60 Wolf 1 y=216.9375, x=245.1875, store=50
# CL+ after y=264, x=252, store=60 Wolf 1 y=240.46875, x=248.59375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=60
# 0 Sheep-after moving+eating y=295, x=15, store=70
# S.........................................
# 1 Sheep-before moving+eating y=295, x=9, store=60
# 1 Sheep-after moving+eating y=294, x=8, store=70
# S.........................................
# 2 Sheep-before moving+eating y=105, x=238, store=60
# 2 Sheep-after moving+eating y=106, x=239, store=70
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=60
# 3 Sheep-after moving+eating y=250, x=141, store=70
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=60
# 4 Sheep-after moving+eating y=85, x=16, store=70
# S.........................................
# 5 Sheep-before moving+eating y=264, x=252, store=60
# 5 Sheep-after moving+eating y=265, x=253, store=70
# S.........................................
# 6 Sheep-before moving+eating y=165, x=38, store=60
# 6 Sheep-after moving+eating y=164, x=37, store=70
# S.........................................
# 7 Sheep-before moving+eating y=22, x=215, store=60
# 7 Sheep-after moving+eating y=21, x=216, store=70
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=240.46875, x=248.59375, store=50
# >>> min_dist = 24.92382927290668 Sheep 5 y=265, x=253, store=70 by Wolf 1 y=240.46875, x=248.59375, store=50
# CL+ before y=265, x=253, store=70 Wolf 1 y=240.46875, x=248.59375, store=50
# CL+ after y=265, x=253, store=70 Wolf 1 y=252.734375, x=250.796875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=236, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=70
# 0 Sheep-after moving+eating y=296, x=16, store=80
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=70
# 1 Sheep-after moving+eating y=293, x=7, store=80
# S.........................................
# 2 Sheep-before moving+eating y=106, x=239, store=70
# 2 Sheep-after moving+eating y=107, x=240, store=80
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=70
# 3 Sheep-after moving+eating y=251, x=142, store=80
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=70
# 4 Sheep-after moving+eating y=84, x=15, store=80
# S.........................................
# 5 Sheep-before moving+eating y=265, x=253, store=70
# 5 Sheep-after moving+eating y=266, x=252, store=80
# S.........................................
# 6 Sheep-before moving+eating y=164, x=37, store=70
# 6 Sheep-after moving+eating y=163, x=38, store=80
# S.........................................
# 7 Sheep-before moving+eating y=21, x=216, store=70
# 7 Sheep-after moving+eating y=20, x=217, store=80
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=252.734375, x=250.796875, store=50
# >>> min_dist = 13.320071936977293 Sheep 5 y=266, x=252, store=80 by Wolf 1 y=252.734375, x=250.796875, store=50
# CL+ before y=266, x=252, store=80 Wolf 1 y=252.734375, x=250.796875, store=50
# CL+ after y=266, x=252, store=80 Wolf 1 y=259.3671875, x=251.3984375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=236, x=88, store=0
# Else activate before by Wolf 3 y=236, x=88, store=0
# Else activate after by Wolf 3 y=235, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=80
# 0 Sheep-after moving+eating y=295, x=15, store=90
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=80
# 1 Sheep-after moving+eating y=294, x=8, store=90
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=80
# 2 Sheep-after moving+eating y=106, x=241, store=90
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=80
# 3 Sheep-after moving+eating y=250, x=141, store=90
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=80
# 4 Sheep-after moving+eating y=85, x=14, store=90
# S.........................................
# 5 Sheep-before moving+eating y=266, x=252, store=80
# 5 Sheep-after moving+eating y=267, x=253, store=90
# S.........................................
# 6 Sheep-before moving+eating y=163, x=38, store=80
# 6 Sheep-after moving+eating y=162, x=37, store=90
# S.........................................
# 7 Sheep-before moving+eating y=20, x=217, store=80
# 7 Sheep-after moving+eating y=19, x=218, store=90
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=259.3671875, x=251.3984375, store=50
# >>> min_dist = 7.799027445878268 Sheep 5 y=267, x=253, store=90 by Wolf 1 y=259.3671875, x=251.3984375, store=50
# CL+ before y=267, x=253, store=90 Wolf 1 y=259.3671875, x=251.3984375, store=50
# CL+ after y=267, x=253, store=90 Wolf 1 y=263.18359375, x=252.19921875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=87, store=0
# Else activate before by Wolf 3 y=235, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=90
# 0 Sheep-after moving+eating y=294, x=14, store=100
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=90
# 1 Sheep-after moving+eating y=293, x=7, store=100
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=90
# 2 Sheep-after moving+eating y=107, x=240, store=100
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=90
# 3 Sheep-after moving+eating y=249, x=142, store=100
# S.........................................
# 4 Sheep-before moving+eating y=85, x=14, store=90
# 4 Sheep-after moving+eating y=84, x=15, store=100
# S.........................................
# 5 Sheep-before moving+eating y=267, x=253, store=90
# 5 Sheep-after moving+eating y=268, x=254, store=100
# S.........................................
# 6 Sheep-before moving+eating y=162, x=37, store=90
# 6 Sheep-after moving+eating y=163, x=36, store=100
# S.........................................
# 7 Sheep-before moving+eating y=19, x=218, store=90
# 7 Sheep-after moving+eating y=20, x=217, store=100
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=69, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.18359375, x=252.19921875, store=50
# >>> min_dist = 5.142040672280863 Sheep 5 y=268, x=254, store=100 by Wolf 1 y=263.18359375, x=252.19921875, store=50
# CL+ before y=268, x=254, store=100 Wolf 1 y=263.18359375, x=252.19921875, store=50
# CL+ after y=268, x=254, store=100 Wolf 1 y=265.591796875, x=253.099609375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=294, x=14, store=100
# 0 Sheep-after moving+eating y=293, x=15, store=110
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=100
# 1 Sheep-after moving+eating y=294, x=6, store=110
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=100
# 2 Sheep-after moving+eating y=108, x=241, store=110
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=100
# 3 Sheep-after moving+eating y=248, x=143, store=110
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=100
# 4 Sheep-after moving+eating y=83, x=16, store=110
# S.........................................
# 5 Sheep-before moving+eating y=268, x=254, store=100
# 5 Sheep-after moving+eating y=269, x=255, store=110
# S.........................................
# 6 Sheep-before moving+eating y=163, x=36, store=100
# 6 Sheep-after moving+eating y=164, x=37, store=110
# S.........................................
# 7 Sheep-before moving+eating y=20, x=217, store=100
# 7 Sheep-after moving+eating y=19, x=218, store=110
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=69, x=179, store=0
# Else activate before by Wolf 0 y=69, x=179, store=0
# Else activate after by Wolf 0 y=68, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.591796875, x=253.099609375, store=50
# >>> Sheep going to be eaten 5 y=269, x=255, store=110 by Wolf 1 y=265.591796875, x=253.099609375, store=50
# >>> Sheep eaten 5 y=269, x=255, store=0 by Wolf 1 y=265.591796875, x=253.099609375, store=160
# Eaten_________________________________________
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=110
# 0 Sheep-after moving+eating y=294, x=16, store=120
# S.........................................
# 1 Sheep-before moving+eating y=294, x=6, store=110
# 1 Sheep-after moving+eating y=293, x=7, store=120
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=110
# 2 Sheep-after moving+eating y=109, x=240, store=120
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=110
# 3 Sheep-after moving+eating y=249, x=144, store=120
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=110
# 4 Sheep-after moving+eating y=82, x=15, store=120
# S.........................................
# 5 Sheep-before moving+eating y=164, x=37, store=110
# 5 Sheep-after moving+eating y=165, x=36, store=120
# S.........................................
# 6 Sheep-before moving+eating y=19, x=218, store=110
# 6 Sheep-after moving+eating y=18, x=217, store=120
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=68, x=178, store=0
# Else activate before by Wolf 0 y=68, x=178, store=0
# Else activate after by Wolf 0 y=67, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=265.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=266.591796875, x=252.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=120
# 0 Sheep-after moving+eating y=295, x=17, store=130
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=120
# 1 Sheep-after moving+eating y=292, x=8, store=130
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=120
# 2 Sheep-after moving+eating y=108, x=239, store=130
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=120
# 3 Sheep-after moving+eating y=250, x=143, store=130
# S.........................................
# 4 Sheep-before moving+eating y=82, x=15, store=120
# 4 Sheep-after moving+eating y=83, x=14, store=130
# S.........................................
# 5 Sheep-before moving+eating y=165, x=36, store=120
# 5 Sheep-after moving+eating y=166, x=35, store=130
# S.........................................
# 6 Sheep-before moving+eating y=18, x=217, store=120
# 6 Sheep-after moving+eating y=17, x=218, store=130
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=179, store=0
# Else activate before by Wolf 0 y=67, x=179, store=0
# Else activate after by Wolf 0 y=66, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.591796875, x=252.099609375, store=160
# Else activate before by Wolf 1 y=266.591796875, x=252.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=125.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=130
# 0 Sheep-after moving+eating y=296, x=16, store=140
# S.........................................
# 1 Sheep-before moving+eating y=292, x=8, store=130
# 1 Sheep-after moving+eating y=293, x=9, store=140
# S.........................................
# 2 Sheep-before moving+eating y=108, x=239, store=130
# 2 Sheep-after moving+eating y=109, x=240, store=140
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=130
# 3 Sheep-after moving+eating y=249, x=142, store=140
# S.........................................
# 4 Sheep-before moving+eating y=83, x=14, store=130
# 4 Sheep-after moving+eating y=84, x=15, store=140
# S.........................................
# 5 Sheep-before moving+eating y=166, x=35, store=130
# 5 Sheep-after moving+eating y=167, x=36, store=140
# S.........................................
# 6 Sheep-before moving+eating y=17, x=218, store=130
# 6 Sheep-after moving+eating y=16, x=217, store=140
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=178, store=0
# Else activate before by Wolf 0 y=66, x=178, store=0
# Else activate after by Wolf 0 y=65, x=177, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=181.5, store=40
# Else activate before by Wolf 4 y=125.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=140
# 0 Sheep-after moving+eating y=297, x=17, store=150
# S.........................................
# 1 Sheep-before moving+eating y=293, x=9, store=140
# 1 Sheep-after moving+eating y=294, x=10, store=150
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=140
# 2 Sheep-after moving+eating y=110, x=241, store=150
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=140
# 3 Sheep-after moving+eating y=250, x=141, store=150
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=140
# 4 Sheep-after moving+eating y=85, x=16, store=150
# S.........................................
# 5 Sheep-before moving+eating y=167, x=36, store=140
# 5 Sheep-after moving+eating y=168, x=35, store=150
# S.........................................
# 6 Sheep-before moving+eating y=16, x=217, store=140
# 6 Sheep-after moving+eating y=15, x=216, store=150
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=177, store=0
# Else activate before by Wolf 0 y=65, x=177, store=0
# Else activate after by Wolf 0 y=64, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=255.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=138, store=0
# Else activate before by Wolf 2 y=149, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=297, x=17, store=150
# 0 Sheep-after moving+eating y=298, x=18, store=160
# S.........................................
# 1 Sheep-before moving+eating y=294, x=10, store=150
# 1 Sheep-after moving+eating y=293, x=11, store=160
# S.........................................
# 2 Sheep-before moving+eating y=110, x=241, store=150
# 2 Sheep-after moving+eating y=109, x=242, store=160
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=150
# 3 Sheep-after moving+eating y=249, x=142, store=160
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=150
# 4 Sheep-after moving+eating y=86, x=15, store=160
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=150
# 5 Sheep-after moving+eating y=169, x=34, store=160
# S.........................................
# 6 Sheep-before moving+eating y=15, x=216, store=150
# 6 Sheep-after moving+eating y=16, x=215, store=160
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=64, x=176, store=0
# Else activate before by Wolf 0 y=64, x=176, store=0
# Else activate after by Wolf 0 y=65, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=255.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=255.099609375, store=160
# Else activate after by Wolf 1 y=266.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=298, x=18, store=160
# 0 Sheep-after moving+eating y=299, x=19, store=170
# S.........................................
# 1 Sheep-before moving+eating y=293, x=11, store=160
# 1 Sheep-after moving+eating y=292, x=10, store=170
# S.........................................
# 2 Sheep-before moving+eating y=109, x=242, store=160
# 2 Sheep-after moving+eating y=108, x=241, store=170
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=160
# 3 Sheep-after moving+eating y=248, x=143, store=170
# S.........................................
# 4 Sheep-before moving+eating y=86, x=15, store=160
# 4 Sheep-after moving+eating y=85, x=16, store=170
# S.........................................
# 5 Sheep-before moving+eating y=169, x=34, store=160
# 5 Sheep-after moving+eating y=168, x=35, store=170
# S.........................................
# 6 Sheep-before moving+eating y=16, x=215, store=160
# 6 Sheep-after moving+eating y=17, x=214, store=170
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=175, store=0
# Else activate before by Wolf 0 y=65, x=175, store=0
# Else activate after by Wolf 0 y=64, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=266.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=136, store=0
# Else activate before by Wolf 2 y=149, x=136, store=0
# Else activate after by Wolf 2 y=148, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=299, x=19, store=170
# 0 Sheep-after moving+eating y=0, x=18, store=180
# S.........................................
# 1 Sheep-before moving+eating y=292, x=10, store=170
# 1 Sheep-after moving+eating y=291, x=9, store=180
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=170
# 2 Sheep-after moving+eating y=107, x=242, store=180
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=170
# 3 Sheep-after moving+eating y=249, x=144, store=180
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=170
# 4 Sheep-after moving+eating y=86, x=17, store=180
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=170
# 5 Sheep-after moving+eating y=167, x=34, store=180
# S.........................................
# 6 Sheep-before moving+eating y=17, x=214, store=170
# 6 Sheep-after moving+eating y=18, x=213, store=180
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=64, x=174, store=0
# Else activate before by Wolf 0 y=64, x=174, store=0
# Else activate after by Wolf 0 y=65, x=173, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=135, store=0
# Else activate before by Wolf 2 y=148, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=124.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=0, x=18, store=180
# 0 Sheep-after moving+eating y=299, x=17, store=190
# S.........................................
# 1 Sheep-before moving+eating y=291, x=9, store=180
# 1 Sheep-after moving+eating y=290, x=8, store=190
# S.........................................
# 2 Sheep-before moving+eating y=107, x=242, store=180
# 2 Sheep-after moving+eating y=106, x=241, store=190
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=180
# 3 Sheep-after moving+eating y=250, x=143, store=190
# S.........................................
# 4 Sheep-before moving+eating y=86, x=17, store=180
# 4 Sheep-after moving+eating y=87, x=16, store=190
# S.........................................
# 5 Sheep-before moving+eating y=167, x=34, store=180
# 5 Sheep-after moving+eating y=168, x=35, store=190
# S.........................................
# 6 Sheep-before moving+eating y=18, x=213, store=180
# 6 Sheep-after moving+eating y=19, x=214, store=190
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=173, store=0
# Else activate before by Wolf 0 y=65, x=173, store=0
# Else activate after by Wolf 0 y=66, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=269.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=124.875, x=180.5, store=40
# Else activate before by Wolf 4 y=124.875, x=180.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=299, x=17, store=190
# 0 Sheep-after moving+eating y=298, x=16, store=200
# S.........................................
# 1 Sheep-before moving+eating y=290, x=8, store=190
# 1 Sheep-after moving+eating y=291, x=7, store=200
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=190
# 2 Sheep-after moving+eating y=107, x=240, store=200
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=190
# 3 Sheep-after moving+eating y=251, x=142, store=200
# S.........................................
# 4 Sheep-before moving+eating y=87, x=16, store=190
# 4 Sheep-after moving+eating y=88, x=17, store=200
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=190
# 5 Sheep-after moving+eating y=169, x=34, store=200
# S.........................................
# 6 Sheep-before moving+eating y=19, x=214, store=190
# 6 Sheep-after moving+eating y=20, x=215, store=200
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=174, store=0
# Else activate before by Wolf 0 y=66, x=174, store=0
# Else activate after by Wolf 0 y=67, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating y=269.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=269.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=252.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=123.875, x=179.5, store=40
# Else activate before by Wolf 4 y=123.875, x=179.5, store=40
# Else activate after by Wolf 4 y=122.875, x=178.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=298, x=16, store=200
# 0 Sheep-after moving+eating y=297, x=17, store=210
# S.........................................
# 1 Sheep-before moving+eating y=291, x=7, store=200
# 1 Sheep-after moving+eating y=292, x=6, store=210
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=200
# 2 Sheep-after moving+eating y=106, x=239, store=210
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=200
# 3 Sheep-after moving+eating y=250, x=143, store=210
# S.........................................
# 4 Sheep-before moving+eating y=88, x=17, store=200
# 4 Sheep-after moving+eating y=87, x=18, store=210
# S.........................................
# 5 Sheep-before moving+eating y=169, x=34, store=200
# 5 Sheep-after moving+eating y=170, x=35, store=210
# S.........................................
# 6 Sheep-before moving+eating y=20, x=215, store=200
# 6 Sheep-after moving+eating y=21, x=216, store=210
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=175, store=0
# Else activate before by Wolf 0 y=67, x=175, store=0
# Else activate after by Wolf 0 y=66, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=252.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=252.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=122.875, x=178.5, store=40
# Else activate before by Wolf 4 y=122.875, x=178.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4c13b31268e3> in <module>
#     184 model_menu.add_command(label="Run model", command=run)
#     185
# --> 186 tkinter.mainloop()
#     187
#     188 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:

# %% [markdown]
# the above works. But how about switching up. make eat the if condition. = no difference. still targets (not that it is a problem)How about in the next one, try to put continue after the eat statement.

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        print(i, 'Sheep-before moving+eating', sheep[i])
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep-after moving+eating', sheep[i])
        print('S.........................................')
    print('Sheep_________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works. still targets. but does not move. so fine!
            elif eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
                print('M.........................................')
        if eaten == True:
            #break
            continue # This works! it still targets but that's fine as long is it does not move!
        elif closest_sheep != None:
            print('CL+ before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = (wolves[i].y + closest_sheep.y)/2
            wolves[i].x = (wolves[i].x + closest_sheep.x)/2
            print('CL+ after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')           
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Ends_________________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# S.........................................
# 2 Sheep-before moving+eating y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# S.........................................
# 3 Sheep-before moving+eating y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# S.........................................
# 9 Sheep-before moving+eating y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# M.........................................
# CL+ before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# CL+ after y=218, x=246, store=10 Wolf 1 y=206.5, x=230.5, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# M.........................................
# CL+ before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# CL+ after y=126, x=183, store=10 Wolf 4 y=140.5, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 0 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# S.........................................
# 1 Sheep-before moving+eating y=218, x=246, store=10
# 1 Sheep-after moving+eating y=217, x=247, store=20
# S.........................................
# 2 Sheep-before moving+eating y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# S.........................................
# 3 Sheep-before moving+eating y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# S.........................................
# 4 Sheep-before moving+eating y=250, x=143, store=10
# 4 Sheep-after moving+eating y=251, x=142, store=20
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=10
# 5 Sheep-after moving+eating y=82, x=17, store=20
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=10
# 6 Sheep-after moving+eating y=268, x=250, store=20
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=38, store=20
# S.........................................
# 8 Sheep-before moving+eating y=126, x=183, store=10
# 8 Sheep-after moving+eating y=127, x=184, store=20
# S.........................................
# 9 Sheep-before moving+eating y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=217, store=20
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=206.5, x=230.5, store=0
# >>> min_dist = 19.557607215607945 Sheep 1 y=217, x=247, store=20 by Wolf 1 y=206.5, x=230.5, store=0
# M.........................................
# CL+ before y=217, x=247, store=20 Wolf 1 y=206.5, x=230.5, store=0
# CL+ after y=217, x=247, store=20 Wolf 1 y=211.75, x=238.75, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=140.5, x=184.0, store=0
# >>> min_dist = 13.5 Sheep 8 y=127, x=184, store=20 by Wolf 4 y=140.5, x=184.0, store=0
# M.........................................
# CL+ before y=127, x=184, store=20 Wolf 4 y=140.5, x=184.0, store=0
# CL+ after y=127, x=184, store=20 Wolf 4 y=133.75, x=184.0, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 1 ***************
# 0 Sheep-before moving+eating y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=15, store=30
# S.........................................
# 1 Sheep-before moving+eating y=217, x=247, store=20
# 1 Sheep-after moving+eating y=218, x=248, store=30
# S.........................................
# 2 Sheep-before moving+eating y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# S.........................................
# 3 Sheep-before moving+eating y=105, x=238, store=20
# 3 Sheep-after moving+eating y=104, x=239, store=30
# S.........................................
# 4 Sheep-before moving+eating y=251, x=142, store=20
# 4 Sheep-after moving+eating y=250, x=141, store=30
# S.........................................
# 5 Sheep-before moving+eating y=82, x=17, store=20
# 5 Sheep-after moving+eating y=83, x=16, store=30
# S.........................................
# 6 Sheep-before moving+eating y=268, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# S.........................................
# 7 Sheep-before moving+eating y=169, x=38, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# S.........................................
# 8 Sheep-before moving+eating y=127, x=184, store=20
# 8 Sheep-after moving+eating y=128, x=185, store=30
# S.........................................
# 9 Sheep-before moving+eating y=24, x=217, store=20
# 9 Sheep-after moving+eating y=25, x=218, store=30
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=211.75, x=238.75, store=0
# >>> min_dist = 11.163556780883054 Sheep 1 y=218, x=248, store=30 by Wolf 1 y=211.75, x=238.75, store=0
# M.........................................
# CL+ before y=218, x=248, store=30 Wolf 1 y=211.75, x=238.75, store=0
# CL+ after y=218, x=248, store=30 Wolf 1 y=214.875, x=243.375, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=133.75, x=184.0, store=0
# >>> min_dist = 5.836308764964376 Sheep 8 y=128, x=185, store=30 by Wolf 4 y=133.75, x=184.0, store=0
# M.........................................
# CL+ before y=128, x=185, store=30 Wolf 4 y=133.75, x=184.0, store=0
# CL+ after y=128, x=185, store=30 Wolf 4 y=130.875, x=184.5, store=0
# Y.........................................
# Ends_________________________________________
# ***************Iteration no 2 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=30
# 0 Sheep-after moving+eating y=294, x=16, store=40
# S.........................................
# 1 Sheep-before moving+eating y=218, x=248, store=30
# 1 Sheep-after moving+eating y=219, x=247, store=40
# S.........................................
# 2 Sheep-before moving+eating y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# S.........................................
# 3 Sheep-before moving+eating y=104, x=239, store=30
# 3 Sheep-after moving+eating y=105, x=240, store=40
# S.........................................
# 4 Sheep-before moving+eating y=250, x=141, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# S.........................................
# 5 Sheep-before moving+eating y=83, x=16, store=30
# 5 Sheep-after moving+eating y=84, x=17, store=40
# S.........................................
# 6 Sheep-before moving+eating y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# S.........................................
# 7 Sheep-before moving+eating y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# S.........................................
# 8 Sheep-before moving+eating y=128, x=185, store=30
# 8 Sheep-after moving+eating y=127, x=186, store=40
# S.........................................
# 9 Sheep-before moving+eating y=25, x=218, store=30
# 9 Sheep-after moving+eating y=24, x=217, store=40
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=214.875, x=243.375, store=0
# >>> min_dist = 5.491470659122199 Sheep 1 y=219, x=247, store=40 by Wolf 1 y=214.875, x=243.375, store=0
# M.........................................
# CL+ before y=219, x=247, store=40 Wolf 1 y=214.875, x=243.375, store=0
# CL+ after y=219, x=247, store=40 Wolf 1 y=216.9375, x=245.1875, store=0
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=145, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=0
# >>> Sheep going to be eaten 8 y=127, x=186, store=40 by Wolf 4 y=130.875, x=184.5, store=0
# >>> Sheep eaten 8 y=127, x=186, store=0 by Wolf 4 y=130.875, x=184.5, store=40
# Eaten_________________________________________
# Ends_________________________________________
# ***************Iteration no 3 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=40
# 0 Sheep-after moving+eating y=293, x=17, store=50
# S.........................................
# 1 Sheep-before moving+eating y=219, x=247, store=40
# 1 Sheep-after moving+eating y=218, x=246, store=50
# S.........................................
# 2 Sheep-before moving+eating y=295, x=11, store=40
# 2 Sheep-after moving+eating y=296, x=10, store=50
# S.........................................
# 3 Sheep-before moving+eating y=105, x=240, store=40
# 3 Sheep-after moving+eating y=104, x=239, store=50
# S.........................................
# 4 Sheep-before moving+eating y=249, x=142, store=40
# 4 Sheep-after moving+eating y=250, x=141, store=50
# S.........................................
# 5 Sheep-before moving+eating y=84, x=17, store=40
# 5 Sheep-after moving+eating y=83, x=16, store=50
# S.........................................
# 6 Sheep-before moving+eating y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=251, store=50
# S.........................................
# 7 Sheep-before moving+eating y=167, x=38, store=40
# 7 Sheep-after moving+eating y=166, x=39, store=50
# S.........................................
# 8 Sheep-before moving+eating y=24, x=217, store=40
# 8 Sheep-after moving+eating y=23, x=216, store=50
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=0
# >>> Sheep going to be eaten 1 y=218, x=246, store=50 by Wolf 1 y=216.9375, x=245.1875, store=0
# >>> Sheep eaten 1 y=218, x=246, store=0 by Wolf 1 y=216.9375, x=245.1875, store=50
# Eaten_________________________________________
# >>> min_dist = 48.41269526167697 Sheep 6 y=265, x=251, store=50 by Wolf 1 y=216.9375, x=245.1875, store=50
# M.........................................
# 2 Wolf - before moving/eating y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=130.875, x=184.5, store=40
# Else activate before by Wolf 4 y=130.875, x=184.5, store=40
# Else activate after by Wolf 4 y=129.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 4 ***************
# 0 Sheep-before moving+eating y=293, x=17, store=50
# 0 Sheep-after moving+eating y=294, x=16, store=60
# S.........................................
# 1 Sheep-before moving+eating y=296, x=10, store=50
# 1 Sheep-after moving+eating y=295, x=9, store=60
# S.........................................
# 2 Sheep-before moving+eating y=104, x=239, store=50
# 2 Sheep-after moving+eating y=105, x=238, store=60
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=50
# 3 Sheep-after moving+eating y=249, x=142, store=60
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=50
# 4 Sheep-after moving+eating y=84, x=15, store=60
# S.........................................
# 5 Sheep-before moving+eating y=265, x=251, store=50
# 5 Sheep-after moving+eating y=264, x=252, store=60
# S.........................................
# 6 Sheep-before moving+eating y=166, x=39, store=50
# 6 Sheep-after moving+eating y=165, x=38, store=60
# S.........................................
# 7 Sheep-before moving+eating y=23, x=216, store=50
# 7 Sheep-after moving+eating y=22, x=215, store=60
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating y=216.9375, x=245.1875, store=50
# >>> min_dist = 47.55301318002888 Sheep 5 y=264, x=252, store=60 by Wolf 1 y=216.9375, x=245.1875, store=50
# M.........................................
# CL+ before y=264, x=252, store=60 Wolf 1 y=216.9375, x=245.1875, store=50
# CL+ after y=264, x=252, store=60 Wolf 1 y=240.46875, x=248.59375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=129.875, x=183.5, store=40
# Else activate before by Wolf 4 y=129.875, x=183.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 5 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=60
# 0 Sheep-after moving+eating y=295, x=15, store=70
# S.........................................
# 1 Sheep-before moving+eating y=295, x=9, store=60
# 1 Sheep-after moving+eating y=294, x=8, store=70
# S.........................................
# 2 Sheep-before moving+eating y=105, x=238, store=60
# 2 Sheep-after moving+eating y=106, x=239, store=70
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=60
# 3 Sheep-after moving+eating y=250, x=141, store=70
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=60
# 4 Sheep-after moving+eating y=85, x=16, store=70
# S.........................................
# 5 Sheep-before moving+eating y=264, x=252, store=60
# 5 Sheep-after moving+eating y=265, x=253, store=70
# S.........................................
# 6 Sheep-before moving+eating y=165, x=38, store=60
# 6 Sheep-after moving+eating y=164, x=37, store=70
# S.........................................
# 7 Sheep-before moving+eating y=22, x=215, store=60
# 7 Sheep-after moving+eating y=21, x=216, store=70
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating y=240.46875, x=248.59375, store=50
# >>> min_dist = 24.92382927290668 Sheep 5 y=265, x=253, store=70 by Wolf 1 y=240.46875, x=248.59375, store=50
# M.........................................
# CL+ before y=265, x=253, store=70 Wolf 1 y=240.46875, x=248.59375, store=50
# CL+ after y=265, x=253, store=70 Wolf 1 y=252.734375, x=250.796875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=146, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=236, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=183.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 6 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=70
# 0 Sheep-after moving+eating y=296, x=16, store=80
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=70
# 1 Sheep-after moving+eating y=293, x=7, store=80
# S.........................................
# 2 Sheep-before moving+eating y=106, x=239, store=70
# 2 Sheep-after moving+eating y=107, x=240, store=80
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=70
# 3 Sheep-after moving+eating y=251, x=142, store=80
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=70
# 4 Sheep-after moving+eating y=84, x=15, store=80
# S.........................................
# 5 Sheep-before moving+eating y=265, x=253, store=70
# 5 Sheep-after moving+eating y=266, x=252, store=80
# S.........................................
# 6 Sheep-before moving+eating y=164, x=37, store=70
# 6 Sheep-after moving+eating y=163, x=38, store=80
# S.........................................
# 7 Sheep-before moving+eating y=21, x=216, store=70
# 7 Sheep-after moving+eating y=20, x=217, store=80
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=71, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating y=252.734375, x=250.796875, store=50
# >>> min_dist = 13.320071936977293 Sheep 5 y=266, x=252, store=80 by Wolf 1 y=252.734375, x=250.796875, store=50
# M.........................................
# CL+ before y=266, x=252, store=80 Wolf 1 y=252.734375, x=250.796875, store=50
# CL+ after y=266, x=252, store=80 Wolf 1 y=259.3671875, x=251.3984375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=146, x=135, store=0
# Else activate before by Wolf 2 y=146, x=135, store=0
# Else activate after by Wolf 2 y=147, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=236, x=88, store=0
# Else activate before by Wolf 3 y=236, x=88, store=0
# Else activate after by Wolf 3 y=235, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=183.5, store=40
# Else activate before by Wolf 4 y=127.875, x=183.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 7 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=80
# 0 Sheep-after moving+eating y=295, x=15, store=90
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=80
# 1 Sheep-after moving+eating y=294, x=8, store=90
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=80
# 2 Sheep-after moving+eating y=106, x=241, store=90
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=80
# 3 Sheep-after moving+eating y=250, x=141, store=90
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=80
# 4 Sheep-after moving+eating y=85, x=14, store=90
# S.........................................
# 5 Sheep-before moving+eating y=266, x=252, store=80
# 5 Sheep-after moving+eating y=267, x=253, store=90
# S.........................................
# 6 Sheep-before moving+eating y=163, x=38, store=80
# 6 Sheep-after moving+eating y=162, x=37, store=90
# S.........................................
# 7 Sheep-before moving+eating y=20, x=217, store=80
# 7 Sheep-after moving+eating y=19, x=218, store=90
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=70, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating y=259.3671875, x=251.3984375, store=50
# >>> min_dist = 7.799027445878268 Sheep 5 y=267, x=253, store=90 by Wolf 1 y=259.3671875, x=251.3984375, store=50
# M.........................................
# CL+ before y=267, x=253, store=90 Wolf 1 y=259.3671875, x=251.3984375, store=50
# CL+ after y=267, x=253, store=90 Wolf 1 y=263.18359375, x=252.19921875, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=147, x=136, store=0
# Else activate before by Wolf 2 y=147, x=136, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=87, store=0
# Else activate before by Wolf 3 y=235, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 8 ***************
# 0 Sheep-before moving+eating y=295, x=15, store=90
# 0 Sheep-after moving+eating y=294, x=14, store=100
# S.........................................
# 1 Sheep-before moving+eating y=294, x=8, store=90
# 1 Sheep-after moving+eating y=293, x=7, store=100
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=90
# 2 Sheep-after moving+eating y=107, x=240, store=100
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=90
# 3 Sheep-after moving+eating y=249, x=142, store=100
# S.........................................
# 4 Sheep-before moving+eating y=85, x=14, store=90
# 4 Sheep-after moving+eating y=84, x=15, store=100
# S.........................................
# 5 Sheep-before moving+eating y=267, x=253, store=90
# 5 Sheep-after moving+eating y=268, x=254, store=100
# S.........................................
# 6 Sheep-before moving+eating y=162, x=37, store=90
# 6 Sheep-after moving+eating y=163, x=36, store=100
# S.........................................
# 7 Sheep-before moving+eating y=19, x=218, store=90
# 7 Sheep-after moving+eating y=20, x=217, store=100
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=70, x=180, store=0
# Else activate before by Wolf 0 y=70, x=180, store=0
# Else activate after by Wolf 0 y=69, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=263.18359375, x=252.19921875, store=50
# >>> min_dist = 5.142040672280863 Sheep 5 y=268, x=254, store=100 by Wolf 1 y=263.18359375, x=252.19921875, store=50
# M.........................................
# CL+ before y=268, x=254, store=100 Wolf 1 y=263.18359375, x=252.19921875, store=50
# CL+ after y=268, x=254, store=100 Wolf 1 y=265.591796875, x=253.099609375, store=50
# Y.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=128.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 9 ***************
# 0 Sheep-before moving+eating y=294, x=14, store=100
# 0 Sheep-after moving+eating y=293, x=15, store=110
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=100
# 1 Sheep-after moving+eating y=294, x=6, store=110
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=100
# 2 Sheep-after moving+eating y=108, x=241, store=110
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=100
# 3 Sheep-after moving+eating y=248, x=143, store=110
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=100
# 4 Sheep-after moving+eating y=83, x=16, store=110
# S.........................................
# 5 Sheep-before moving+eating y=268, x=254, store=100
# 5 Sheep-after moving+eating y=269, x=255, store=110
# S.........................................
# 6 Sheep-before moving+eating y=163, x=36, store=100
# 6 Sheep-after moving+eating y=164, x=37, store=110
# S.........................................
# 7 Sheep-before moving+eating y=20, x=217, store=100
# 7 Sheep-after moving+eating y=19, x=218, store=110
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=69, x=179, store=0
# Else activate before by Wolf 0 y=69, x=179, store=0
# Else activate after by Wolf 0 y=68, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.591796875, x=253.099609375, store=50
# >>> Sheep going to be eaten 5 y=269, x=255, store=110 by Wolf 1 y=265.591796875, x=253.099609375, store=50
# >>> Sheep eaten 5 y=269, x=255, store=0 by Wolf 1 y=265.591796875, x=253.099609375, store=160
# Eaten_________________________________________
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=128.875, x=182.5, store=40
# Else activate before by Wolf 4 y=128.875, x=182.5, store=40
# Else activate after by Wolf 4 y=127.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 10 ***************
# 0 Sheep-before moving+eating y=293, x=15, store=110
# 0 Sheep-after moving+eating y=294, x=16, store=120
# S.........................................
# 1 Sheep-before moving+eating y=294, x=6, store=110
# 1 Sheep-after moving+eating y=293, x=7, store=120
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=110
# 2 Sheep-after moving+eating y=109, x=240, store=120
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=110
# 3 Sheep-after moving+eating y=249, x=144, store=120
# S.........................................
# 4 Sheep-before moving+eating y=83, x=16, store=110
# 4 Sheep-after moving+eating y=82, x=15, store=120
# S.........................................
# 5 Sheep-before moving+eating y=164, x=37, store=110
# 5 Sheep-after moving+eating y=165, x=36, store=120
# S.........................................
# 6 Sheep-before moving+eating y=19, x=218, store=110
# 6 Sheep-after moving+eating y=18, x=217, store=120
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=68, x=178, store=0
# Else activate before by Wolf 0 y=68, x=178, store=0
# Else activate after by Wolf 0 y=67, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating y=265.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=265.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=266.591796875, x=252.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=147, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=127.875, x=181.5, store=40
# Else activate before by Wolf 4 y=127.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=182.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 11 ***************
# 0 Sheep-before moving+eating y=294, x=16, store=120
# 0 Sheep-after moving+eating y=295, x=17, store=130
# S.........................................
# 1 Sheep-before moving+eating y=293, x=7, store=120
# 1 Sheep-after moving+eating y=292, x=8, store=130
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=120
# 2 Sheep-after moving+eating y=108, x=239, store=130
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=120
# 3 Sheep-after moving+eating y=250, x=143, store=130
# S.........................................
# 4 Sheep-before moving+eating y=82, x=15, store=120
# 4 Sheep-after moving+eating y=83, x=14, store=130
# S.........................................
# 5 Sheep-before moving+eating y=165, x=36, store=120
# 5 Sheep-after moving+eating y=166, x=35, store=130
# S.........................................
# 6 Sheep-before moving+eating y=18, x=217, store=120
# 6 Sheep-after moving+eating y=17, x=218, store=130
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=179, store=0
# Else activate before by Wolf 0 y=67, x=179, store=0
# Else activate after by Wolf 0 y=66, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.591796875, x=252.099609375, store=160
# Else activate before by Wolf 1 y=266.591796875, x=252.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=147, x=138, store=0
# Else activate before by Wolf 2 y=147, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=182.5, store=40
# Else activate before by Wolf 4 y=126.875, x=182.5, store=40
# Else activate after by Wolf 4 y=125.875, x=181.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 12 ***************
# 0 Sheep-before moving+eating y=295, x=17, store=130
# 0 Sheep-after moving+eating y=296, x=16, store=140
# S.........................................
# 1 Sheep-before moving+eating y=292, x=8, store=130
# 1 Sheep-after moving+eating y=293, x=9, store=140
# S.........................................
# 2 Sheep-before moving+eating y=108, x=239, store=130
# 2 Sheep-after moving+eating y=109, x=240, store=140
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=130
# 3 Sheep-after moving+eating y=249, x=142, store=140
# S.........................................
# 4 Sheep-before moving+eating y=83, x=14, store=130
# 4 Sheep-after moving+eating y=84, x=15, store=140
# S.........................................
# 5 Sheep-before moving+eating y=166, x=35, store=130
# 5 Sheep-after moving+eating y=167, x=36, store=140
# S.........................................
# 6 Sheep-before moving+eating y=17, x=218, store=130
# 6 Sheep-after moving+eating y=16, x=217, store=140
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=178, store=0
# Else activate before by Wolf 0 y=66, x=178, store=0
# Else activate after by Wolf 0 y=65, x=177, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=138, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=181.5, store=40
# Else activate before by Wolf 4 y=125.875, x=181.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 13 ***************
# 0 Sheep-before moving+eating y=296, x=16, store=140
# 0 Sheep-after moving+eating y=297, x=17, store=150
# S.........................................
# 1 Sheep-before moving+eating y=293, x=9, store=140
# 1 Sheep-after moving+eating y=294, x=10, store=150
# S.........................................
# 2 Sheep-before moving+eating y=109, x=240, store=140
# 2 Sheep-after moving+eating y=110, x=241, store=150
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=140
# 3 Sheep-after moving+eating y=250, x=141, store=150
# S.........................................
# 4 Sheep-before moving+eating y=84, x=15, store=140
# 4 Sheep-after moving+eating y=85, x=16, store=150
# S.........................................
# 5 Sheep-before moving+eating y=167, x=36, store=140
# 5 Sheep-after moving+eating y=168, x=35, store=150
# S.........................................
# 6 Sheep-before moving+eating y=16, x=217, store=140
# 6 Sheep-after moving+eating y=15, x=216, store=150
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=177, store=0
# Else activate before by Wolf 0 y=65, x=177, store=0
# Else activate after by Wolf 0 y=64, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=255.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=138, store=0
# Else activate before by Wolf 2 y=149, x=138, store=0
# Else activate after by Wolf 2 y=148, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 14 ***************
# 0 Sheep-before moving+eating y=297, x=17, store=150
# 0 Sheep-after moving+eating y=298, x=18, store=160
# S.........................................
# 1 Sheep-before moving+eating y=294, x=10, store=150
# 1 Sheep-after moving+eating y=293, x=11, store=160
# S.........................................
# 2 Sheep-before moving+eating y=110, x=241, store=150
# 2 Sheep-after moving+eating y=109, x=242, store=160
# S.........................................
# 3 Sheep-before moving+eating y=250, x=141, store=150
# 3 Sheep-after moving+eating y=249, x=142, store=160
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=150
# 4 Sheep-after moving+eating y=86, x=15, store=160
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=150
# 5 Sheep-after moving+eating y=169, x=34, store=160
# S.........................................
# 6 Sheep-before moving+eating y=15, x=216, store=150
# 6 Sheep-after moving+eating y=16, x=215, store=160
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=64, x=176, store=0
# Else activate before by Wolf 0 y=64, x=176, store=0
# Else activate after by Wolf 0 y=65, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=255.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=255.099609375, store=160
# Else activate after by Wolf 1 y=266.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=137, store=0
# Else activate before by Wolf 2 y=148, x=137, store=0
# Else activate after by Wolf 2 y=149, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=126.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 15 ***************
# 0 Sheep-before moving+eating y=298, x=18, store=160
# 0 Sheep-after moving+eating y=299, x=19, store=170
# S.........................................
# 1 Sheep-before moving+eating y=293, x=11, store=160
# 1 Sheep-after moving+eating y=292, x=10, store=170
# S.........................................
# 2 Sheep-before moving+eating y=109, x=242, store=160
# 2 Sheep-after moving+eating y=108, x=241, store=170
# S.........................................
# 3 Sheep-before moving+eating y=249, x=142, store=160
# 3 Sheep-after moving+eating y=248, x=143, store=170
# S.........................................
# 4 Sheep-before moving+eating y=86, x=15, store=160
# 4 Sheep-after moving+eating y=85, x=16, store=170
# S.........................................
# 5 Sheep-before moving+eating y=169, x=34, store=160
# 5 Sheep-after moving+eating y=168, x=35, store=170
# S.........................................
# 6 Sheep-before moving+eating y=16, x=215, store=160
# 6 Sheep-after moving+eating y=17, x=214, store=170
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=175, store=0
# Else activate before by Wolf 0 y=65, x=175, store=0
# Else activate after by Wolf 0 y=64, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=266.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=266.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=136, store=0
# Else activate before by Wolf 2 y=149, x=136, store=0
# Else activate after by Wolf 2 y=148, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=126.875, x=180.5, store=40
# Else activate before by Wolf 4 y=126.875, x=180.5, store=40
# Else activate after by Wolf 4 y=125.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 16 ***************
# 0 Sheep-before moving+eating y=299, x=19, store=170
# 0 Sheep-after moving+eating y=0, x=18, store=180
# S.........................................
# 1 Sheep-before moving+eating y=292, x=10, store=170
# 1 Sheep-after moving+eating y=291, x=9, store=180
# S.........................................
# 2 Sheep-before moving+eating y=108, x=241, store=170
# 2 Sheep-after moving+eating y=107, x=242, store=180
# S.........................................
# 3 Sheep-before moving+eating y=248, x=143, store=170
# 3 Sheep-after moving+eating y=249, x=144, store=180
# S.........................................
# 4 Sheep-before moving+eating y=85, x=16, store=170
# 4 Sheep-after moving+eating y=86, x=17, store=180
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=170
# 5 Sheep-after moving+eating y=167, x=34, store=180
# S.........................................
# 6 Sheep-before moving+eating y=17, x=214, store=170
# 6 Sheep-after moving+eating y=18, x=213, store=180
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=64, x=174, store=0
# Else activate before by Wolf 0 y=64, x=174, store=0
# Else activate after by Wolf 0 y=65, x=173, store=0
# E.........................................
# 1 Wolf - before moving/eating y=267.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=267.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=254.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=148, x=135, store=0
# Else activate before by Wolf 2 y=148, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=125.875, x=179.5, store=40
# Else activate before by Wolf 4 y=125.875, x=179.5, store=40
# Else activate after by Wolf 4 y=124.875, x=180.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 17 ***************
# 0 Sheep-before moving+eating y=0, x=18, store=180
# 0 Sheep-after moving+eating y=299, x=17, store=190
# S.........................................
# 1 Sheep-before moving+eating y=291, x=9, store=180
# 1 Sheep-after moving+eating y=290, x=8, store=190
# S.........................................
# 2 Sheep-before moving+eating y=107, x=242, store=180
# 2 Sheep-after moving+eating y=106, x=241, store=190
# S.........................................
# 3 Sheep-before moving+eating y=249, x=144, store=180
# 3 Sheep-after moving+eating y=250, x=143, store=190
# S.........................................
# 4 Sheep-before moving+eating y=86, x=17, store=180
# 4 Sheep-after moving+eating y=87, x=16, store=190
# S.........................................
# 5 Sheep-before moving+eating y=167, x=34, store=180
# 5 Sheep-after moving+eating y=168, x=35, store=190
# S.........................................
# 6 Sheep-before moving+eating y=18, x=213, store=180
# 6 Sheep-after moving+eating y=19, x=214, store=190
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=65, x=173, store=0
# Else activate before by Wolf 0 y=65, x=173, store=0
# Else activate after by Wolf 0 y=66, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=254.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=254.099609375, store=160
# Else activate after by Wolf 1 y=269.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=124.875, x=180.5, store=40
# Else activate before by Wolf 4 y=124.875, x=180.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 18 ***************
# 0 Sheep-before moving+eating y=299, x=17, store=190
# 0 Sheep-after moving+eating y=298, x=16, store=200
# S.........................................
# 1 Sheep-before moving+eating y=290, x=8, store=190
# 1 Sheep-after moving+eating y=291, x=7, store=200
# S.........................................
# 2 Sheep-before moving+eating y=106, x=241, store=190
# 2 Sheep-after moving+eating y=107, x=240, store=200
# S.........................................
# 3 Sheep-before moving+eating y=250, x=143, store=190
# 3 Sheep-after moving+eating y=251, x=142, store=200
# S.........................................
# 4 Sheep-before moving+eating y=87, x=16, store=190
# 4 Sheep-after moving+eating y=88, x=17, store=200
# S.........................................
# 5 Sheep-before moving+eating y=168, x=35, store=190
# 5 Sheep-after moving+eating y=169, x=34, store=200
# S.........................................
# 6 Sheep-before moving+eating y=19, x=214, store=190
# 6 Sheep-after moving+eating y=20, x=215, store=200
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=66, x=174, store=0
# Else activate before by Wolf 0 y=66, x=174, store=0
# Else activate after by Wolf 0 y=67, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating y=269.591796875, x=253.099609375, store=160
# Else activate before by Wolf 1 y=269.591796875, x=253.099609375, store=160
# Else activate after by Wolf 1 y=268.591796875, x=252.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating y=123.875, x=179.5, store=40
# Else activate before by Wolf 4 y=123.875, x=179.5, store=40
# Else activate after by Wolf 4 y=122.875, x=178.5, store=40
# E.........................................
# Ends_________________________________________
# ***************Iteration no 19 ***************
# 0 Sheep-before moving+eating y=298, x=16, store=200
# 0 Sheep-after moving+eating y=297, x=17, store=210
# S.........................................
# 1 Sheep-before moving+eating y=291, x=7, store=200
# 1 Sheep-after moving+eating y=292, x=6, store=210
# S.........................................
# 2 Sheep-before moving+eating y=107, x=240, store=200
# 2 Sheep-after moving+eating y=106, x=239, store=210
# S.........................................
# 3 Sheep-before moving+eating y=251, x=142, store=200
# 3 Sheep-after moving+eating y=250, x=143, store=210
# S.........................................
# 4 Sheep-before moving+eating y=88, x=17, store=200
# 4 Sheep-after moving+eating y=87, x=18, store=210
# S.........................................
# 5 Sheep-before moving+eating y=169, x=34, store=200
# 5 Sheep-after moving+eating y=170, x=35, store=210
# S.........................................
# 6 Sheep-before moving+eating y=20, x=215, store=200
# 6 Sheep-after moving+eating y=21, x=216, store=210
# S.........................................
# Sheep_________________________________________
# 0 Wolf - before moving/eating y=67, x=175, store=0
# Else activate before by Wolf 0 y=67, x=175, store=0
# Else activate after by Wolf 0 y=66, x=174, store=0
# E.........................................
# 1 Wolf - before moving/eating y=268.591796875, x=252.099609375, store=160
# Else activate before by Wolf 1 y=268.591796875, x=252.099609375, store=160
# Else activate after by Wolf 1 y=267.591796875, x=253.099609375, store=160
# E.........................................
# 2 Wolf - before moving/eating y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating y=122.875, x=178.5, store=40
# Else activate before by Wolf 4 y=122.875, x=178.5, store=40
# Else activate after by Wolf 4 y=123.875, x=179.5, store=40
# E.........................................
# Ends_________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-36d1432ce0c5> in <module>
#     185 model_menu.add_command(label="Run model", command=run)
#     186
# --> 187 tkinter.mainloop()
#     188
#     189 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:

# %% [markdown]
# # Testing out sheep moving away|

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    # for i in range(len(sheep)):
    #     print(i, 'Sheep-before moving+eating', sheep[i])
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep-after moving+eating', sheep[i])
    #     print('S.........................................')
    # print('Sheep_________________________________________')
### NEED TO ADJUST THE PRINT TAGS LATER   
    for i in range(len(sheep)):
        print(i, 'Sheep - before moving+eating -', sheep[i])
        # sheep[i].move()
        min_dist = 0.5*proximity # coz sheep is a prey! wolves should have higer perimeter
        closest_wolf = None 
        for j in range(len(wolves)):                      
            distance = af.Animal.dist_animals(sheep[i], wolves[j])
            if distance < min_dist:
                min_dist = distance
                closest_wolf = wolves[j]
                print(f"Sheep {i} {sheep[i]} detected Wolf {j} {wolves[j]}, c{closest_wolf} within distance {min_dist}")
                print(f"...........Sheep {i} noticed closest wolf {j}...........")
        if closest_wolf != None:
                print('CW+ before', 'Wolf:', closest_wolf, 'Sheep:', i, sheep[i])
                sheep[i].y = int(sheep[i].y + (closest_wolf.y/2))
                sheep[i].x = int(sheep[i].x + (closest_wolf.x/2))
                print('CW+ after', 'Wolf:', closest_wolf, 'Sheep:', i, sheep[i])
                print('...........Sheep tried to move away...........')  
        else:
            sheep[i].move()
            sheep[i].eat()
            print(i, 'Sheep-after moving+eating', sheep[i])
            print('...........Sheep moved normally and ate...........')
    print('Sheep Cycle Ends________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating -', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works. still targets. but does not move. so fine!
            elif eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
                print('M.........................................')
        if eaten == True:
            #break
            continue # This works! it still targets but that's fine as long is it does not move!
        elif closest_sheep != None:
            print('CS+ before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = int((wolves[i].y + closest_sheep.y)/2) #why? i know!
            wolves[i].x = int((wolves[i].x + closest_sheep.x)/2)
            print('CS+ after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')           
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Wolf Cycle Ends___________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('')
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
#
# ***************Iteration no 0 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# M.........................................
# CS+ before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# CS+ after y=218, x=246, store=10 Wolf 1 y=206, x=230, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# M.........................................
# CS+ before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# CS+ after y=126, x=183, store=10 Wolf 4 y=140, x=184, store=0
# Y.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 0 ***************
# 0 Sheep - before moving+eating - y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=218, x=246, store=10
# Sheep 1 y=218, x=246, store=10 detected Wolf 1 y=206, x=230, store=0, cy=206, x=230, store=0 within distance 20.0
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=206, x=230, store=0 Sheep: 1 y=218, x=246, store=10
# CW+ after Wolf: y=206, x=230, store=0 Sheep: 1 y=321, x=361, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=250, x=143, store=10
# 4 Sheep-after moving+eating y=249, x=144, store=20
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=83, x=16, store=10
# 5 Sheep-after moving+eating y=84, x=15, store=20
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=249, store=10
# 6 Sheep-after moving+eating y=266, x=250, store=20
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=40, store=20
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=126, x=183, store=10
# Sheep 8 y=126, x=183, store=10 detected Wolf 4 y=140, x=184, store=0, cy=140, x=184, store=0 within distance 14.035668847618199
# ...........Sheep 8 noticed closest wolf 4...........
# CW+ before Wolf: y=140, x=184, store=0 Sheep: 8 y=126, x=183, store=10
# CW+ after Wolf: y=140, x=184, store=0 Sheep: 8 y=196, x=275, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=215, store=20
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=72, x=182, store=0
# Else activate before by Wolf 0 y=72, x=182, store=0
# Else activate after by Wolf 0 y=73, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=206, x=230, store=0
# >>> min_dist = 46.09772228646444 Sheep 8 y=196, x=275, store=10 by Wolf 1 y=206, x=230, store=0
# M.........................................
# CS+ before y=196, x=275, store=10 Wolf 1 y=206, x=230, store=0
# CS+ after y=196, x=275, store=10 Wolf 1 y=201, x=252, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=147, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=231, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=140, x=184, store=0
# Else activate before by Wolf 4 y=140, x=184, store=0
# Else activate after by Wolf 4 y=139, x=185, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 1 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=20
# 0 Sheep-after moving+eating y=293, x=17, store=30
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=321, x=361, store=10
# 1 Sheep-after moving+eating y=22, x=60, store=20
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=293, x=9, store=20
# 2 Sheep-after moving+eating y=294, x=10, store=30
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=238, store=20
# 3 Sheep-after moving+eating y=106, x=239, store=30
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=144, store=20
# 4 Sheep-after moving+eating y=248, x=145, store=30
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=15, store=20
# 5 Sheep-after moving+eating y=83, x=14, store=30
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=249, store=30
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=169, x=40, store=20
# 7 Sheep-after moving+eating y=168, x=39, store=30
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=196, x=275, store=10
# Sheep 8 y=196, x=275, store=10 detected Wolf 1 y=201, x=252, store=0, cy=201, x=252, store=0 within distance 23.53720459187964
# ...........Sheep 8 noticed closest wolf 1...........
# CW+ before Wolf: y=201, x=252, store=0 Sheep: 8 y=196, x=275, store=10
# CW+ after Wolf: y=201, x=252, store=0 Sheep: 8 y=296, x=401, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=24, x=215, store=20
# 9 Sheep-after moving+eating y=23, x=216, store=30
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=73, x=183, store=0
# Else activate before by Wolf 0 y=73, x=183, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=201, x=252, store=0
# Else activate before by Wolf 1 y=201, x=252, store=0
# Else activate after by Wolf 1 y=202, x=253, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=147, x=134, store=0
# Else activate before by Wolf 2 y=147, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=231, x=87, store=0
# Else activate before by Wolf 3 y=231, x=87, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=139, x=185, store=0
# Else activate before by Wolf 4 y=139, x=185, store=0
# Else activate after by Wolf 4 y=140, x=184, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 2 ***************
# 0 Sheep - before moving+eating - y=293, x=17, store=30
# 0 Sheep-after moving+eating y=294, x=18, store=40
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=22, x=60, store=20
# 1 Sheep-after moving+eating y=23, x=59, store=30
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=294, x=10, store=30
# 2 Sheep-after moving+eating y=295, x=11, store=40
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=239, store=30
# 3 Sheep-after moving+eating y=107, x=240, store=40
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=248, x=145, store=30
# 4 Sheep-after moving+eating y=247, x=146, store=40
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=83, x=14, store=30
# 5 Sheep-after moving+eating y=84, x=15, store=40
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=249, store=30
# 6 Sheep-after moving+eating y=266, x=250, store=40
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=30
# 7 Sheep-after moving+eating y=167, x=38, store=40
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=296, x=401, store=10
# 8 Sheep-after moving+eating y=295, x=102, store=20
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=23, x=216, store=30
# 9 Sheep-after moving+eating y=22, x=215, store=40
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=75, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=202, x=253, store=0
# Else activate before by Wolf 1 y=202, x=253, store=0
# Else activate after by Wolf 1 y=201, x=252, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=145, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=231, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=140, x=184, store=0
# Else activate before by Wolf 4 y=140, x=184, store=0
# Else activate after by Wolf 4 y=139, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 3 ***************
# 0 Sheep - before moving+eating - y=294, x=18, store=40
# 0 Sheep-after moving+eating y=295, x=17, store=50
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=23, x=59, store=30
# 1 Sheep-after moving+eating y=22, x=58, store=40
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=11, store=40
# 2 Sheep-after moving+eating y=296, x=10, store=50
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=240, store=40
# 3 Sheep-after moving+eating y=106, x=239, store=50
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=247, x=146, store=40
# 4 Sheep-after moving+eating y=246, x=147, store=50
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=15, store=40
# 5 Sheep-after moving+eating y=83, x=16, store=50
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=40
# 6 Sheep-after moving+eating y=265, x=249, store=50
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=40
# 7 Sheep-after moving+eating y=168, x=39, store=50
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=295, x=102, store=20
# 8 Sheep-after moving+eating y=296, x=103, store=30
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=22, x=215, store=40
# 9 Sheep-after moving+eating y=23, x=216, store=50
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=75, x=185, store=0
# Else activate before by Wolf 0 y=75, x=185, store=0
# Else activate after by Wolf 0 y=74, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=201, x=252, store=0
# Else activate before by Wolf 1 y=201, x=252, store=0
# Else activate after by Wolf 1 y=202, x=251, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=145, x=132, store=0
# Else activate before by Wolf 2 y=145, x=132, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=231, x=89, store=0
# Else activate before by Wolf 3 y=231, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=139, x=183, store=0
# Else activate before by Wolf 4 y=139, x=183, store=0
# Else activate after by Wolf 4 y=138, x=184, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 4 ***************
# 0 Sheep - before moving+eating - y=295, x=17, store=50
# 0 Sheep-after moving+eating y=296, x=16, store=60
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=22, x=58, store=40
# 1 Sheep-after moving+eating y=21, x=59, store=50
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=296, x=10, store=50
# 2 Sheep-after moving+eating y=295, x=9, store=60
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=239, store=50
# 3 Sheep-after moving+eating y=105, x=238, store=60
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=246, x=147, store=50
# 4 Sheep-after moving+eating y=247, x=148, store=60
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=83, x=16, store=50
# 5 Sheep-after moving+eating y=84, x=17, store=60
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=50
# 6 Sheep-after moving+eating y=266, x=250, store=60
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=50
# 7 Sheep-after moving+eating y=167, x=38, store=60
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=296, x=103, store=30
# 8 Sheep-after moving+eating y=297, x=102, store=40
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=23, x=216, store=50
# 9 Sheep-after moving+eating y=22, x=215, store=60
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=74, x=184, store=0
# Else activate before by Wolf 0 y=74, x=184, store=0
# Else activate after by Wolf 0 y=75, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=202, x=251, store=0
# Else activate before by Wolf 1 y=202, x=251, store=0
# Else activate after by Wolf 1 y=203, x=250, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=144, x=131, store=0
# Else activate before by Wolf 2 y=144, x=131, store=0
# Else activate after by Wolf 2 y=145, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=138, x=184, store=0
# Else activate before by Wolf 4 y=138, x=184, store=0
# Else activate after by Wolf 4 y=137, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 5 ***************
# 0 Sheep - before moving+eating - y=296, x=16, store=60
# 0 Sheep-after moving+eating y=295, x=17, store=70
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=21, x=59, store=50
# 1 Sheep-after moving+eating y=20, x=58, store=60
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=9, store=60
# 2 Sheep-after moving+eating y=294, x=8, store=70
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=238, store=60
# 3 Sheep-after moving+eating y=106, x=237, store=70
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=247, x=148, store=60
# 4 Sheep-after moving+eating y=246, x=149, store=70
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=17, store=60
# 5 Sheep-after moving+eating y=85, x=18, store=70
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=60
# 6 Sheep-after moving+eating y=265, x=249, store=70
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=60
# 7 Sheep-after moving+eating y=168, x=39, store=70
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=297, x=102, store=40
# 8 Sheep-after moving+eating y=298, x=103, store=50
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=22, x=215, store=60
# 9 Sheep-after moving+eating y=21, x=214, store=70
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=75, x=185, store=0
# Else activate before by Wolf 0 y=75, x=185, store=0
# Else activate after by Wolf 0 y=76, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=203, x=250, store=0
# Else activate before by Wolf 1 y=203, x=250, store=0
# Else activate after by Wolf 1 y=202, x=251, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=145, x=132, store=0
# Else activate before by Wolf 2 y=145, x=132, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=183, store=0
# Else activate before by Wolf 4 y=137, x=183, store=0
# Else activate after by Wolf 4 y=138, x=184, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 6 ***************
# 0 Sheep - before moving+eating - y=295, x=17, store=70
# 0 Sheep-after moving+eating y=294, x=16, store=80
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=20, x=58, store=60
# 1 Sheep-after moving+eating y=19, x=57, store=70
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=294, x=8, store=70
# 2 Sheep-after moving+eating y=293, x=7, store=80
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=237, store=70
# 3 Sheep-after moving+eating y=107, x=238, store=80
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=246, x=149, store=70
# 4 Sheep-after moving+eating y=245, x=150, store=80
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=18, store=70
# 5 Sheep-after moving+eating y=84, x=17, store=80
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=70
# 6 Sheep-after moving+eating y=266, x=248, store=80
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=70
# 7 Sheep-after moving+eating y=169, x=40, store=80
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=298, x=103, store=50
# 8 Sheep-after moving+eating y=297, x=102, store=60
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=21, x=214, store=70
# 9 Sheep-after moving+eating y=20, x=215, store=80
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=76, x=184, store=0
# Else activate before by Wolf 0 y=76, x=184, store=0
# Else activate after by Wolf 0 y=75, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=202, x=251, store=0
# Else activate before by Wolf 1 y=202, x=251, store=0
# Else activate after by Wolf 1 y=203, x=252, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=144, x=133, store=0
# Else activate before by Wolf 2 y=144, x=133, store=0
# Else activate after by Wolf 2 y=143, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=138, x=184, store=0
# Else activate before by Wolf 4 y=138, x=184, store=0
# Else activate after by Wolf 4 y=137, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 7 ***************
# 0 Sheep - before moving+eating - y=294, x=16, store=80
# 0 Sheep-after moving+eating y=293, x=15, store=90
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=19, x=57, store=70
# 1 Sheep-after moving+eating y=20, x=56, store=80
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=293, x=7, store=80
# 2 Sheep-after moving+eating y=292, x=8, store=90
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=238, store=80
# 3 Sheep-after moving+eating y=106, x=239, store=90
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=245, x=150, store=80
# 4 Sheep-after moving+eating y=246, x=151, store=90
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=17, store=80
# 5 Sheep-after moving+eating y=85, x=16, store=90
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=248, store=80
# 6 Sheep-after moving+eating y=267, x=247, store=90
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=169, x=40, store=80
# 7 Sheep-after moving+eating y=168, x=39, store=90
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=297, x=102, store=60
# 8 Sheep-after moving+eating y=296, x=103, store=70
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=20, x=215, store=80
# 9 Sheep-after moving+eating y=21, x=216, store=90
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=75, x=183, store=0
# Else activate before by Wolf 0 y=75, x=183, store=0
# Else activate after by Wolf 0 y=76, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=203, x=252, store=0
# Else activate before by Wolf 1 y=203, x=252, store=0
# Else activate after by Wolf 1 y=202, x=253, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=143, x=134, store=0
# Else activate before by Wolf 2 y=143, x=134, store=0
# Else activate after by Wolf 2 y=144, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=87, store=0
# Else activate before by Wolf 3 y=233, x=87, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=183, store=0
# Else activate before by Wolf 4 y=137, x=183, store=0
# Else activate after by Wolf 4 y=136, x=184, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 8 ***************
# 0 Sheep - before moving+eating - y=293, x=15, store=90
# 0 Sheep-after moving+eating y=292, x=16, store=100
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=20, x=56, store=80
# 1 Sheep-after moving+eating y=21, x=57, store=90
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=292, x=8, store=90
# 2 Sheep-after moving+eating y=293, x=9, store=100
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=239, store=90
# 3 Sheep-after moving+eating y=105, x=240, store=100
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=246, x=151, store=90
# 4 Sheep-after moving+eating y=245, x=150, store=100
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=16, store=90
# 5 Sheep-after moving+eating y=86, x=15, store=100
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=247, store=90
# 6 Sheep-after moving+eating y=266, x=248, store=100
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=90
# 7 Sheep-after moving+eating y=167, x=38, store=100
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=296, x=103, store=70
# 8 Sheep-after moving+eating y=297, x=104, store=80
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=21, x=216, store=90
# 9 Sheep-after moving+eating y=20, x=217, store=100
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=76, x=184, store=0
# Else activate before by Wolf 0 y=76, x=184, store=0
# Else activate after by Wolf 0 y=77, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=202, x=253, store=0
# Else activate before by Wolf 1 y=202, x=253, store=0
# Else activate after by Wolf 1 y=203, x=254, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=144, x=133, store=0
# Else activate before by Wolf 2 y=144, x=133, store=0
# Else activate after by Wolf 2 y=143, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=136, x=184, store=0
# Else activate before by Wolf 4 y=136, x=184, store=0
# Else activate after by Wolf 4 y=135, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 9 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=100
# 0 Sheep-after moving+eating y=291, x=17, store=110
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=21, x=57, store=90
# 1 Sheep-after moving+eating y=22, x=56, store=100
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=293, x=9, store=100
# 2 Sheep-after moving+eating y=292, x=10, store=110
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=240, store=100
# 3 Sheep-after moving+eating y=104, x=241, store=110
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=245, x=150, store=100
# 4 Sheep-after moving+eating y=244, x=151, store=110
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=15, store=100
# 5 Sheep-after moving+eating y=87, x=16, store=110
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=248, store=100
# 6 Sheep-after moving+eating y=265, x=249, store=110
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=100
# 7 Sheep-after moving+eating y=166, x=37, store=110
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=297, x=104, store=80
# 8 Sheep-after moving+eating y=298, x=103, store=90
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=20, x=217, store=100
# 9 Sheep-after moving+eating y=21, x=216, store=110
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=77, x=183, store=0
# Else activate before by Wolf 0 y=77, x=183, store=0
# Else activate after by Wolf 0 y=78, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=203, x=254, store=0
# Else activate before by Wolf 1 y=203, x=254, store=0
# Else activate after by Wolf 1 y=202, x=255, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=143, x=132, store=0
# Else activate before by Wolf 2 y=143, x=132, store=0
# Else activate after by Wolf 2 y=142, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=87, store=0
# Else activate before by Wolf 3 y=235, x=87, store=0
# Else activate after by Wolf 3 y=236, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=135, x=183, store=0
# Else activate before by Wolf 4 y=135, x=183, store=0
# Else activate after by Wolf 4 y=136, x=182, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 10 ***************
# 0 Sheep - before moving+eating - y=291, x=17, store=110
# 0 Sheep-after moving+eating y=292, x=18, store=120
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=22, x=56, store=100
# 1 Sheep-after moving+eating y=21, x=55, store=110
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=292, x=10, store=110
# 2 Sheep-after moving+eating y=293, x=9, store=120
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=104, x=241, store=110
# 3 Sheep-after moving+eating y=105, x=242, store=120
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=244, x=151, store=110
# 4 Sheep-after moving+eating y=245, x=152, store=120
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=87, x=16, store=110
# 5 Sheep-after moving+eating y=86, x=15, store=120
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=110
# 6 Sheep-after moving+eating y=266, x=250, store=120
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=37, store=110
# 7 Sheep-after moving+eating y=167, x=38, store=120
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=298, x=103, store=90
# 8 Sheep-after moving+eating y=297, x=102, store=100
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=21, x=216, store=110
# 9 Sheep-after moving+eating y=20, x=215, store=120
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=78, x=182, store=0
# Else activate before by Wolf 0 y=78, x=182, store=0
# Else activate after by Wolf 0 y=79, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=202, x=255, store=0
# Else activate before by Wolf 1 y=202, x=255, store=0
# Else activate after by Wolf 1 y=203, x=256, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=142, x=131, store=0
# Else activate before by Wolf 2 y=142, x=131, store=0
# Else activate after by Wolf 2 y=143, x=130, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=236, x=88, store=0
# Else activate before by Wolf 3 y=236, x=88, store=0
# Else activate after by Wolf 3 y=237, x=87, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=136, x=182, store=0
# Else activate before by Wolf 4 y=136, x=182, store=0
# Else activate after by Wolf 4 y=137, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 11 ***************
# 0 Sheep - before moving+eating - y=292, x=18, store=120
# 0 Sheep-after moving+eating y=293, x=19, store=130
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=21, x=55, store=110
# 1 Sheep-after moving+eating y=22, x=56, store=120
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=293, x=9, store=120
# 2 Sheep-after moving+eating y=294, x=8, store=130
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=242, store=120
# 3 Sheep-after moving+eating y=106, x=243, store=130
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=245, x=152, store=120
# 4 Sheep-after moving+eating y=246, x=151, store=130
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=15, store=120
# 5 Sheep-after moving+eating y=85, x=14, store=130
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=120
# 6 Sheep-after moving+eating y=265, x=249, store=130
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=120
# 7 Sheep-after moving+eating y=166, x=39, store=130
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=297, x=102, store=100
# 8 Sheep-after moving+eating y=296, x=101, store=110
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=20, x=215, store=120
# 9 Sheep-after moving+eating y=19, x=214, store=130
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=79, x=183, store=0
# Else activate before by Wolf 0 y=79, x=183, store=0
# Else activate after by Wolf 0 y=78, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=203, x=256, store=0
# Else activate before by Wolf 1 y=203, x=256, store=0
# Else activate after by Wolf 1 y=204, x=257, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=143, x=130, store=0
# Else activate before by Wolf 2 y=143, x=130, store=0
# Else activate after by Wolf 2 y=142, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=237, x=87, store=0
# Else activate before by Wolf 3 y=237, x=87, store=0
# Else activate after by Wolf 3 y=236, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=183, store=0
# Else activate before by Wolf 4 y=137, x=183, store=0
# Else activate after by Wolf 4 y=136, x=184, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 12 ***************
# 0 Sheep - before moving+eating - y=293, x=19, store=130
# 0 Sheep-after moving+eating y=294, x=18, store=140
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=22, x=56, store=120
# 1 Sheep-after moving+eating y=23, x=55, store=130
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=294, x=8, store=130
# 2 Sheep-after moving+eating y=295, x=7, store=140
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=243, store=130
# 3 Sheep-after moving+eating y=107, x=242, store=140
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=246, x=151, store=130
# 4 Sheep-after moving+eating y=245, x=150, store=140
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=14, store=130
# 5 Sheep-after moving+eating y=86, x=13, store=140
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=130
# 6 Sheep-after moving+eating y=266, x=250, store=140
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=39, store=130
# 7 Sheep-after moving+eating y=167, x=40, store=140
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=296, x=101, store=110
# 8 Sheep-after moving+eating y=297, x=102, store=120
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=19, x=214, store=130
# 9 Sheep-after moving+eating y=18, x=213, store=140
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=78, x=182, store=0
# Else activate before by Wolf 0 y=78, x=182, store=0
# Else activate after by Wolf 0 y=77, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=204, x=257, store=0
# Else activate before by Wolf 1 y=204, x=257, store=0
# Else activate after by Wolf 1 y=203, x=258, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=142, x=131, store=0
# Else activate before by Wolf 2 y=142, x=131, store=0
# Else activate after by Wolf 2 y=141, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=236, x=88, store=0
# Else activate before by Wolf 3 y=236, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=136, x=184, store=0
# Else activate before by Wolf 4 y=136, x=184, store=0
# Else activate after by Wolf 4 y=137, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 13 ***************
# 0 Sheep - before moving+eating - y=294, x=18, store=140
# 0 Sheep-after moving+eating y=293, x=17, store=150
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=23, x=55, store=130
# 1 Sheep-after moving+eating y=24, x=54, store=140
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=7, store=140
# 2 Sheep-after moving+eating y=294, x=6, store=150
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=242, store=140
# 3 Sheep-after moving+eating y=106, x=243, store=150
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=245, x=150, store=140
# 4 Sheep-after moving+eating y=244, x=149, store=150
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=13, store=140
# 5 Sheep-after moving+eating y=87, x=12, store=150
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=140
# 6 Sheep-after moving+eating y=265, x=249, store=150
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=40, store=140
# 7 Sheep-after moving+eating y=166, x=41, store=150
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=297, x=102, store=120
# 8 Sheep-after moving+eating y=298, x=103, store=130
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=18, x=213, store=140
# 9 Sheep-after moving+eating y=19, x=214, store=150
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=77, x=181, store=0
# Else activate before by Wolf 0 y=77, x=181, store=0
# Else activate after by Wolf 0 y=76, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=203, x=258, store=0
# Else activate before by Wolf 1 y=203, x=258, store=0
# Else activate after by Wolf 1 y=204, x=257, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=141, x=132, store=0
# Else activate before by Wolf 2 y=141, x=132, store=0
# Else activate after by Wolf 2 y=142, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=236, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=183, store=0
# Else activate before by Wolf 4 y=137, x=183, store=0
# Else activate after by Wolf 4 y=138, x=182, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 14 ***************
# 0 Sheep - before moving+eating - y=293, x=17, store=150
# 0 Sheep-after moving+eating y=292, x=16, store=160
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=24, x=54, store=140
# 1 Sheep-after moving+eating y=23, x=55, store=150
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=294, x=6, store=150
# 2 Sheep-after moving+eating y=293, x=5, store=160
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=243, store=150
# 3 Sheep-after moving+eating y=105, x=242, store=160
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=244, x=149, store=150
# 4 Sheep-after moving+eating y=243, x=148, store=160
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=87, x=12, store=150
# 5 Sheep-after moving+eating y=88, x=11, store=160
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=150
# 6 Sheep-after moving+eating y=266, x=248, store=160
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=41, store=150
# 7 Sheep-after moving+eating y=167, x=42, store=160
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=298, x=103, store=130
# 8 Sheep-after moving+eating y=299, x=104, store=140
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=19, x=214, store=150
# 9 Sheep-after moving+eating y=20, x=215, store=160
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=76, x=180, store=0
# Else activate before by Wolf 0 y=76, x=180, store=0
# Else activate after by Wolf 0 y=77, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=204, x=257, store=0
# Else activate before by Wolf 1 y=204, x=257, store=0
# Else activate after by Wolf 1 y=205, x=258, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=142, x=131, store=0
# Else activate before by Wolf 2 y=142, x=131, store=0
# Else activate after by Wolf 2 y=143, x=132, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=236, x=90, store=0
# Else activate before by Wolf 3 y=236, x=90, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=138, x=182, store=0
# Else activate before by Wolf 4 y=138, x=182, store=0
# Else activate after by Wolf 4 y=137, x=181, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 15 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=160
# 0 Sheep-after moving+eating y=293, x=15, store=170
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=23, x=55, store=150
# 1 Sheep-after moving+eating y=24, x=54, store=160
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=293, x=5, store=160
# 2 Sheep-after moving+eating y=294, x=4, store=170
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=242, store=160
# 3 Sheep-after moving+eating y=106, x=243, store=170
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=243, x=148, store=160
# 4 Sheep-after moving+eating y=244, x=147, store=170
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=88, x=11, store=160
# 5 Sheep-after moving+eating y=89, x=12, store=170
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=248, store=160
# 6 Sheep-after moving+eating y=267, x=249, store=170
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=42, store=160
# 7 Sheep-after moving+eating y=166, x=41, store=170
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=299, x=104, store=140
# 8 Sheep-after moving+eating y=298, x=103, store=150
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=20, x=215, store=160
# 9 Sheep-after moving+eating y=21, x=214, store=170
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=77, x=179, store=0
# Else activate before by Wolf 0 y=77, x=179, store=0
# Else activate after by Wolf 0 y=76, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=205, x=258, store=0
# Else activate before by Wolf 1 y=205, x=258, store=0
# Else activate after by Wolf 1 y=204, x=259, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=143, x=132, store=0
# Else activate before by Wolf 2 y=143, x=132, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=181, store=0
# Else activate before by Wolf 4 y=137, x=181, store=0
# Else activate after by Wolf 4 y=136, x=182, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 16 ***************
# 0 Sheep - before moving+eating - y=293, x=15, store=170
# 0 Sheep-after moving+eating y=292, x=16, store=180
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=24, x=54, store=160
# 1 Sheep-after moving+eating y=25, x=55, store=170
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=294, x=4, store=170
# 2 Sheep-after moving+eating y=295, x=5, store=180
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=243, store=170
# 3 Sheep-after moving+eating y=105, x=242, store=180
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=244, x=147, store=170
# 4 Sheep-after moving+eating y=243, x=148, store=180
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=89, x=12, store=170
# 5 Sheep-after moving+eating y=88, x=11, store=180
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=249, store=170
# 6 Sheep-after moving+eating y=266, x=250, store=180
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=41, store=170
# 7 Sheep-after moving+eating y=167, x=42, store=180
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=298, x=103, store=150
# 8 Sheep-after moving+eating y=299, x=102, store=160
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=21, x=214, store=170
# 9 Sheep-after moving+eating y=22, x=213, store=180
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=76, x=178, store=0
# Else activate before by Wolf 0 y=76, x=178, store=0
# Else activate after by Wolf 0 y=75, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=204, x=259, store=0
# Else activate before by Wolf 1 y=204, x=259, store=0
# Else activate after by Wolf 1 y=205, x=258, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=144, x=131, store=0
# Else activate before by Wolf 2 y=144, x=131, store=0
# Else activate after by Wolf 2 y=145, x=130, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=88, store=0
# Else activate before by Wolf 3 y=234, x=88, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=136, x=182, store=0
# Else activate before by Wolf 4 y=136, x=182, store=0
# Else activate after by Wolf 4 y=137, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 17 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=180
# 0 Sheep-after moving+eating y=293, x=15, store=190
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=25, x=55, store=170
# 1 Sheep-after moving+eating y=26, x=56, store=180
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=5, store=180
# 2 Sheep-after moving+eating y=296, x=4, store=190
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=242, store=180
# 3 Sheep-after moving+eating y=106, x=243, store=190
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=243, x=148, store=180
# 4 Sheep-after moving+eating y=244, x=147, store=190
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=88, x=11, store=180
# 5 Sheep-after moving+eating y=87, x=12, store=190
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=180
# 6 Sheep-after moving+eating y=265, x=249, store=190
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=42, store=180
# 7 Sheep-after moving+eating y=168, x=41, store=190
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=299, x=102, store=160
# 8 Sheep-after moving+eating y=0, x=101, store=170
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=22, x=213, store=180
# 9 Sheep-after moving+eating y=21, x=212, store=190
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=75, x=179, store=0
# Else activate before by Wolf 0 y=75, x=179, store=0
# Else activate after by Wolf 0 y=74, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=205, x=258, store=0
# Else activate before by Wolf 1 y=205, x=258, store=0
# Else activate after by Wolf 1 y=206, x=259, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=145, x=130, store=0
# Else activate before by Wolf 2 y=145, x=130, store=0
# Else activate after by Wolf 2 y=144, x=131, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=137, x=183, store=0
# Else activate before by Wolf 4 y=137, x=183, store=0
# Else activate after by Wolf 4 y=138, x=182, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 18 ***************
# 0 Sheep - before moving+eating - y=293, x=15, store=190
# 0 Sheep-after moving+eating y=292, x=16, store=200
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=26, x=56, store=180
# 1 Sheep-after moving+eating y=27, x=55, store=190
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=296, x=4, store=190
# 2 Sheep-after moving+eating y=295, x=3, store=200
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=243, store=190
# 3 Sheep-after moving+eating y=107, x=242, store=200
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=244, x=147, store=190
# 4 Sheep-after moving+eating y=245, x=148, store=200
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=87, x=12, store=190
# 5 Sheep-after moving+eating y=88, x=13, store=200
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=249, store=190
# 6 Sheep-after moving+eating y=264, x=250, store=200
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=41, store=190
# 7 Sheep-after moving+eating y=167, x=40, store=200
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=0, x=101, store=170
# 8 Sheep-after moving+eating y=1, x=100, store=180
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=21, x=212, store=190
# 9 Sheep-after moving+eating y=20, x=211, store=200
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=74, x=180, store=0
# Else activate before by Wolf 0 y=74, x=180, store=0
# Else activate after by Wolf 0 y=75, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=206, x=259, store=0
# Else activate before by Wolf 1 y=206, x=259, store=0
# Else activate after by Wolf 1 y=205, x=258, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=144, x=131, store=0
# Else activate before by Wolf 2 y=144, x=131, store=0
# Else activate after by Wolf 2 y=143, x=130, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=235, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=138, x=182, store=0
# Else activate before by Wolf 4 y=138, x=182, store=0
# Else activate after by Wolf 4 y=139, x=183, store=0
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 19 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=200
# 0 Sheep-after moving+eating y=291, x=17, store=210
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=27, x=55, store=190
# 1 Sheep-after moving+eating y=28, x=56, store=200
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=3, store=200
# 2 Sheep-after moving+eating y=296, x=4, store=210
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=242, store=200
# 3 Sheep-after moving+eating y=106, x=241, store=210
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=245, x=148, store=200
# 4 Sheep-after moving+eating y=246, x=147, store=210
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=88, x=13, store=200
# 5 Sheep-after moving+eating y=87, x=12, store=210
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=264, x=250, store=200
# 6 Sheep-after moving+eating y=263, x=249, store=210
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=40, store=200
# 7 Sheep-after moving+eating y=166, x=39, store=210
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=1, x=100, store=180
# 8 Sheep-after moving+eating y=0, x=99, store=190
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=20, x=211, store=200
# 9 Sheep-after moving+eating y=21, x=210, store=210
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=75, x=179, store=0
# Else activate before by Wolf 0 y=75, x=179, store=0
# Else activate after by Wolf 0 y=74, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=205, x=258, store=0
# Else activate before by Wolf 1 y=205, x=258, store=0
# Else activate after by Wolf 1 y=204, x=257, store=0
# E.........................................
# 2 Wolf - before moving/eating - y=143, x=130, store=0
# Else activate before by Wolf 2 y=143, x=130, store=0
# Else activate after by Wolf 2 y=142, x=129, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=89, store=0
# Else activate before by Wolf 3 y=235, x=89, store=0
# Else activate after by Wolf 3 y=234, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=139, x=183, store=0
# Else activate before by Wolf 4 y=139, x=183, store=0
# Else activate after by Wolf 4 y=140, x=182, store=0
# E.........................................
# Wolf Cycle Ends___________________________________

# %% [markdown]
# improving running away without store

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 20
proximity = 50
eat_dist = 5
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    # for i in range(len(wolves)):
    #     wolves[i].move()
    #     print(i, 'Wolves', wolves[i])
        
    # for i in range(len(sheep)):
    #     print(i, 'Sheep-before moving+eating', sheep[i])
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep-after moving+eating', sheep[i])
    #     print('S.........................................')
    # print('Sheep_________________________________________')
### NEED TO ADJUST THE PRINT TAGS LATER   
    for i in range(len(sheep)):
        print(i, 'Sheep - before moving+eating -', sheep[i])
        # sheep[i].move()
        min_dist = 0.5*proximity # coz sheep is a prey! wolves should have higer perimeter
        closest_wolf = None 
        for j in range(len(wolves)):                      
            distance = af.Animal.dist_animals(sheep[i], wolves[j])
            if distance < min_dist:
                min_dist = distance
                closest_wolf = wolves[j]
                print(f"Sheep {i} {sheep[i]} detected Wolf {j} {wolves[j]}, c{closest_wolf} within distance {min_dist}")
                print(f"...........Sheep {i} noticed closest wolf {j}...........")
        if closest_wolf != None:
                print('CW+ before', 'Wolf:', closest_wolf, 'Sheep:', i, sheep[i])
                sheep[i].y += (sheep[i].y - int((sheep[i].y + closest_wolf.y)/2)) 
                sheep[i].x += (sheep[i].x - int((sheep[i].x + closest_wolf.x)/2))
                print('CW+ after', 'Wolf:', closest_wolf, 'Sheep:', i, sheep[i])
                print('...........Sheep tried to move away...........')  
        else:
            sheep[i].move()
            sheep[i].eat()
            print(i, 'Sheep-after moving+eating', sheep[i])
            print('...........Sheep moved normally and ate...........')
    print('Sheep Cycle Ends________________________________________')
    
    for i in range(len(wolves)):
        print(i, 'Wolf - before moving/eating -', wolves[i])
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        min_dist = proximity
        eaten = False
        for j in sheep[:]:
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            # if eat_dist < distance < min_dist:
            if distance <= eat_dist:
                print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                wolves[i].store += j.store
                j.store = 0
                print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
                sheep.remove(j)
                print('Eaten_________________________________________')
                # break # activates else after eating.
                # continue # no good. targets immediately another sheep. and activates else.
                eaten = True # works. still targets. but does not move. so fine!
            elif eat_dist < distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
                print('M.........................................')
        if eaten == True:
            #break
            continue # This works! it still targets but that's fine as long is it does not move!
        elif closest_sheep != None:
            print('CS+ before', closest_sheep, 'Wolf', i, wolves[i])
            wolves[i].y = int((wolves[i].y + closest_sheep.y)/2)
            wolves[i].x = int((wolves[i].x + closest_sheep.x)/2)
            print('CS+ after', closest_sheep, 'Wolf', i, wolves[i])
            print('Y.........................................')           
        else:
            print('Else activate before', 'by Wolf', i, wolves[i])
            wolves[i].move()
            print('Else activate after', 'by Wolf', i, wolves[i])
            print('E.........................................')
    print('Wolf Cycle Ends___________________________________')
            # if random.random() < 0.5:
            #     wolves[i].y = (wolves[i].y + 1) % (len(environment))
            # else:
            #     wolves[i].y = (wolves[i].y - 1) % (len(environment))
            # if random.random() < 0.5:
            #     wolves[i].x = (wolves[i].x + 1) % (len(environment[0]))
            # else:
            #     wolves[i].x = (wolves[i].x - 1) % (len(environment[0]))
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print('')
        print('***************Iteration no', a, '***************')
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
#
# ***************Iteration no 0 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=0
# 0 Sheep-after moving+eating y=293, x=15, store=10
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=219, x=247, store=0
# 1 Sheep-after moving+eating y=218, x=246, store=10
# ...........Sheep moved normally and ate...........
# 2 Sheep - before moving+eating - y=295, x=7, store=0
# 2 Sheep-after moving+eating y=294, x=8, store=10
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=236, store=0
# 3 Sheep-after moving+eating y=106, x=237, store=10
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=251, x=142, store=0
# 4 Sheep-after moving+eating y=250, x=143, store=10
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=82, x=17, store=0
# 5 Sheep-after moving+eating y=83, x=16, store=10
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=0
# 6 Sheep-after moving+eating y=267, x=249, store=10
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=38, store=0
# 7 Sheep-after moving+eating y=168, x=39, store=10
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=127, x=184, store=0
# 8 Sheep-after moving+eating y=126, x=183, store=10
# ...........Sheep moved normally and ate...........
# 9 Sheep - before moving+eating - y=22, x=215, store=0
# 9 Sheep-after moving+eating y=23, x=216, store=10
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=71, x=181, store=0
# Else activate before by Wolf 0 y=71, x=181, store=0
# Else activate after by Wolf 0 y=72, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=195, x=215, store=0
# >>> min_dist = 38.600518131237564 Sheep 1 y=218, x=246, store=10 by Wolf 1 y=195, x=215, store=0
# M.........................................
# CS+ before y=218, x=246, store=10 Wolf 1 y=195, x=215, store=0
# CS+ after y=218, x=246, store=10 Wolf 1 y=206, x=230, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=145, x=134, store=0
# Else activate before by Wolf 2 y=145, x=134, store=0
# Else activate after by Wolf 2 y=146, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=155, x=185, store=0
# >>> min_dist = 29.068883707497267 Sheep 8 y=126, x=183, store=10 by Wolf 4 y=155, x=185, store=0
# M.........................................
# CS+ before y=126, x=183, store=10 Wolf 4 y=155, x=185, store=0
# CS+ after y=126, x=183, store=10 Wolf 4 y=140, x=184, store=0
# Y.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 0 ***************
# 0 Sheep - before moving+eating - y=293, x=15, store=10
# 0 Sheep-after moving+eating y=292, x=16, store=20
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=218, x=246, store=10
# Sheep 1 y=218, x=246, store=10 detected Wolf 1 y=206, x=230, store=0, cy=206, x=230, store=0 within distance 20.0
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=206, x=230, store=0 Sheep: 1 y=218, x=246, store=10
# CW+ after Wolf: y=206, x=230, store=0 Sheep: 1 y=224, x=254, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=294, x=8, store=10
# 2 Sheep-after moving+eating y=293, x=9, store=20
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=237, store=10
# 3 Sheep-after moving+eating y=105, x=238, store=20
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=250, x=143, store=10
# 4 Sheep-after moving+eating y=249, x=144, store=20
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=83, x=16, store=10
# 5 Sheep-after moving+eating y=84, x=15, store=20
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=249, store=10
# 6 Sheep-after moving+eating y=266, x=250, store=20
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=39, store=10
# 7 Sheep-after moving+eating y=169, x=40, store=20
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=126, x=183, store=10
# Sheep 8 y=126, x=183, store=10 detected Wolf 4 y=140, x=184, store=0, cy=140, x=184, store=0 within distance 14.035668847618199
# ...........Sheep 8 noticed closest wolf 4...........
# CW+ before Wolf: y=140, x=184, store=0 Sheep: 8 y=126, x=183, store=10
# CW+ after Wolf: y=140, x=184, store=0 Sheep: 8 y=119, x=183, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=23, x=216, store=10
# 9 Sheep-after moving+eating y=24, x=215, store=20
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=72, x=182, store=0
# >>> min_dist = 47.01063709417264 Sheep 8 y=119, x=183, store=10 by Wolf 0 y=72, x=182, store=0
# M.........................................
# CS+ before y=119, x=183, store=10 Wolf 0 y=72, x=182, store=0
# CS+ after y=119, x=183, store=10 Wolf 0 y=95, x=182, store=0
# Y.........................................
# 1 Wolf - before moving/eating - y=206, x=230, store=0
# >>> min_dist = 30.0 Sheep 1 y=224, x=254, store=10 by Wolf 1 y=206, x=230, store=0
# M.........................................
# CS+ before y=224, x=254, store=10 Wolf 1 y=206, x=230, store=0
# CS+ after y=224, x=254, store=10 Wolf 1 y=215, x=242, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=146, x=133, store=0
# Else activate before by Wolf 2 y=146, x=133, store=0
# Else activate after by Wolf 2 y=147, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=140, x=184, store=0
# >>> min_dist = 21.02379604162864 Sheep 8 y=119, x=183, store=10 by Wolf 4 y=140, x=184, store=0
# M.........................................
# CS+ before y=119, x=183, store=10 Wolf 4 y=140, x=184, store=0
# CS+ after y=119, x=183, store=10 Wolf 4 y=129, x=183, store=0
# Y.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 1 ***************
# 0 Sheep - before moving+eating - y=292, x=16, store=20
# 0 Sheep-after moving+eating y=291, x=15, store=30
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=224, x=254, store=10
# Sheep 1 y=224, x=254, store=10 detected Wolf 1 y=215, x=242, store=0, cy=215, x=242, store=0 within distance 15.0
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=215, x=242, store=0 Sheep: 1 y=224, x=254, store=10
# CW+ after Wolf: y=215, x=242, store=0 Sheep: 1 y=229, x=260, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=9, store=20
# 2 Sheep-after moving+eating y=292, x=10, store=30
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=238, store=20
# 3 Sheep-after moving+eating y=106, x=239, store=30
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=144, store=20
# 4 Sheep-after moving+eating y=250, x=143, store=30
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=15, store=20
# 5 Sheep-after moving+eating y=85, x=16, store=30
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=20
# 6 Sheep-after moving+eating y=267, x=251, store=30
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=169, x=40, store=20
# 7 Sheep-after moving+eating y=168, x=41, store=30
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=119, x=183, store=10
# Sheep 8 y=119, x=183, store=10 detected Wolf 0 y=95, x=182, store=0, cy=95, x=182, store=0 within distance 24.020824298928627
# ...........Sheep 8 noticed closest wolf 0...........
# Sheep 8 y=119, x=183, store=10 detected Wolf 4 y=129, x=183, store=0, cy=129, x=183, store=0 within distance 10.0
# ...........Sheep 8 noticed closest wolf 4...........
# CW+ before Wolf: y=129, x=183, store=0 Sheep: 8 y=119, x=183, store=10
# CW+ after Wolf: y=129, x=183, store=0 Sheep: 8 y=114, x=183, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=24, x=215, store=20
# 9 Sheep-after moving+eating y=23, x=214, store=30
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=95, x=182, store=0
# >>> min_dist = 19.026297590440446 Sheep 8 y=114, x=183, store=10 by Wolf 0 y=95, x=182, store=0
# M.........................................
# CS+ before y=114, x=183, store=10 Wolf 0 y=95, x=182, store=0
# CS+ after y=114, x=183, store=10 Wolf 0 y=104, x=182, store=0
# Y.........................................
# 1 Wolf - before moving/eating - y=215, x=242, store=0
# >>> min_dist = 22.80350850198276 Sheep 1 y=229, x=260, store=10 by Wolf 1 y=215, x=242, store=0
# M.........................................
# CS+ before y=229, x=260, store=10 Wolf 1 y=215, x=242, store=0
# CS+ after y=229, x=260, store=10 Wolf 1 y=222, x=251, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=147, x=134, store=0
# Else activate before by Wolf 2 y=147, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=88, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=129, x=183, store=0
# >>> min_dist = 15.0 Sheep 8 y=114, x=183, store=10 by Wolf 4 y=129, x=183, store=0
# M.........................................
# CS+ before y=114, x=183, store=10 Wolf 4 y=129, x=183, store=0
# CS+ after y=114, x=183, store=10 Wolf 4 y=121, x=183, store=0
# Y.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 2 ***************
# 0 Sheep - before moving+eating - y=291, x=15, store=30
# 0 Sheep-after moving+eating y=290, x=16, store=40
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=229, x=260, store=10
# Sheep 1 y=229, x=260, store=10 detected Wolf 1 y=222, x=251, store=0, cy=222, x=251, store=0 within distance 11.40175425099138
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=222, x=251, store=0 Sheep: 1 y=229, x=260, store=10
# CW+ after Wolf: y=222, x=251, store=0 Sheep: 1 y=233, x=265, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=10, store=30
# 2 Sheep-after moving+eating y=293, x=11, store=40
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=239, store=30
# 3 Sheep-after moving+eating y=107, x=240, store=40
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=250, x=143, store=30
# 4 Sheep-after moving+eating y=249, x=142, store=40
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=16, store=30
# 5 Sheep-after moving+eating y=86, x=17, store=40
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=251, store=30
# 6 Sheep-after moving+eating y=268, x=250, store=40
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=41, store=30
# 7 Sheep-after moving+eating y=169, x=42, store=40
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=114, x=183, store=10
# Sheep 8 y=114, x=183, store=10 detected Wolf 0 y=104, x=182, store=0, cy=104, x=182, store=0 within distance 10.04987562112089
# ...........Sheep 8 noticed closest wolf 0...........
# Sheep 8 y=114, x=183, store=10 detected Wolf 4 y=121, x=183, store=0, cy=121, x=183, store=0 within distance 7.0
# ...........Sheep 8 noticed closest wolf 4...........
# CW+ before Wolf: y=121, x=183, store=0 Sheep: 8 y=114, x=183, store=10
# CW+ after Wolf: y=121, x=183, store=0 Sheep: 8 y=111, x=183, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=23, x=214, store=30
# 9 Sheep-after moving+eating y=24, x=213, store=40
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=104, x=182, store=0
# >>> min_dist = 7.0710678118654755 Sheep 8 y=111, x=183, store=10 by Wolf 0 y=104, x=182, store=0
# M.........................................
# CS+ before y=111, x=183, store=10 Wolf 0 y=104, x=182, store=0
# CS+ after y=111, x=183, store=10 Wolf 0 y=107, x=182, store=0
# Y.........................................
# 1 Wolf - before moving/eating - y=222, x=251, store=0
# >>> min_dist = 17.804493814764857 Sheep 1 y=233, x=265, store=10 by Wolf 1 y=222, x=251, store=0
# M.........................................
# CS+ before y=233, x=265, store=10 Wolf 1 y=222, x=251, store=0
# CS+ after y=233, x=265, store=10 Wolf 1 y=227, x=258, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=148, x=133, store=0
# Else activate before by Wolf 2 y=148, x=133, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=88, store=0
# Else activate before by Wolf 3 y=232, x=88, store=0
# Else activate after by Wolf 3 y=233, x=89, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=121, x=183, store=0
# >>> min_dist = 10.0 Sheep 8 y=111, x=183, store=10 by Wolf 4 y=121, x=183, store=0
# M.........................................
# CS+ before y=111, x=183, store=10 Wolf 4 y=121, x=183, store=0
# CS+ after y=111, x=183, store=10 Wolf 4 y=116, x=183, store=0
# Y.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 3 ***************
# 0 Sheep - before moving+eating - y=290, x=16, store=40
# 0 Sheep-after moving+eating y=289, x=17, store=50
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=233, x=265, store=10
# Sheep 1 y=233, x=265, store=10 detected Wolf 1 y=227, x=258, store=0, cy=227, x=258, store=0 within distance 9.219544457292887
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=227, x=258, store=0 Sheep: 1 y=233, x=265, store=10
# CW+ after Wolf: y=227, x=258, store=0 Sheep: 1 y=236, x=269, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=11, store=40
# 2 Sheep-after moving+eating y=294, x=12, store=50
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=240, store=40
# 3 Sheep-after moving+eating y=106, x=241, store=50
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=142, store=40
# 4 Sheep-after moving+eating y=248, x=141, store=50
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=17, store=40
# 5 Sheep-after moving+eating y=85, x=18, store=50
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=268, x=250, store=40
# 6 Sheep-after moving+eating y=267, x=249, store=50
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=169, x=42, store=40
# 7 Sheep-after moving+eating y=170, x=43, store=50
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=111, x=183, store=10
# Sheep 8 y=111, x=183, store=10 detected Wolf 0 y=107, x=182, store=0, cy=107, x=182, store=0 within distance 4.123105625617661
# ...........Sheep 8 noticed closest wolf 0...........
# CW+ before Wolf: y=107, x=182, store=0 Sheep: 8 y=111, x=183, store=10
# CW+ after Wolf: y=107, x=182, store=0 Sheep: 8 y=113, x=184, store=10
# ...........Sheep tried to move away...........
# 9 Sheep - before moving+eating - y=24, x=213, store=40
# 9 Sheep-after moving+eating y=23, x=212, store=50
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=107, x=182, store=0
# >>> min_dist = 6.324555320336759 Sheep 8 y=113, x=184, store=10 by Wolf 0 y=107, x=182, store=0
# M.........................................
# CS+ before y=113, x=184, store=10 Wolf 0 y=107, x=182, store=0
# CS+ after y=113, x=184, store=10 Wolf 0 y=110, x=183, store=0
# Y.........................................
# 1 Wolf - before moving/eating - y=227, x=258, store=0
# >>> min_dist = 14.212670403551895 Sheep 1 y=236, x=269, store=10 by Wolf 1 y=227, x=258, store=0
# M.........................................
# CS+ before y=236, x=269, store=10 Wolf 1 y=227, x=258, store=0
# CS+ after y=236, x=269, store=10 Wolf 1 y=231, x=263, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=148, x=133, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=89, store=0
# Else activate before by Wolf 3 y=233, x=89, store=0
# Else activate after by Wolf 3 y=232, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=116, x=183, store=0
# >>> Sheep going to be eaten 8 y=113, x=184, store=10 by Wolf 4 y=116, x=183, store=0
# >>> Sheep eaten 8 y=113, x=184, store=0 by Wolf 4 y=116, x=183, store=10
# Eaten_________________________________________
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 4 ***************
# 0 Sheep - before moving+eating - y=289, x=17, store=50
# 0 Sheep-after moving+eating y=288, x=16, store=60
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=236, x=269, store=10
# Sheep 1 y=236, x=269, store=10 detected Wolf 1 y=231, x=263, store=0, cy=231, x=263, store=0 within distance 7.810249675906654
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=231, x=263, store=0 Sheep: 1 y=236, x=269, store=10
# CW+ after Wolf: y=231, x=263, store=0 Sheep: 1 y=239, x=272, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=294, x=12, store=50
# 2 Sheep-after moving+eating y=295, x=11, store=60
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=241, store=50
# 3 Sheep-after moving+eating y=105, x=240, store=60
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=248, x=141, store=50
# 4 Sheep-after moving+eating y=249, x=140, store=60
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=18, store=50
# 5 Sheep-after moving+eating y=84, x=17, store=60
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=249, store=50
# 6 Sheep-after moving+eating y=266, x=250, store=60
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=170, x=43, store=50
# 7 Sheep-after moving+eating y=169, x=44, store=60
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=23, x=212, store=50
# 8 Sheep-after moving+eating y=22, x=211, store=60
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=110, x=183, store=0
# Else activate before by Wolf 0 y=110, x=183, store=0
# Else activate after by Wolf 0 y=111, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=231, x=263, store=0
# >>> min_dist = 12.041594578792296 Sheep 1 y=239, x=272, store=10 by Wolf 1 y=231, x=263, store=0
# M.........................................
# CS+ before y=239, x=272, store=10 Wolf 1 y=231, x=263, store=0
# CS+ after y=239, x=272, store=10 Wolf 1 y=235, x=267, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=148, x=133, store=0
# Else activate before by Wolf 2 y=148, x=133, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=90, store=0
# Else activate before by Wolf 3 y=232, x=90, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=116, x=183, store=10
# Else activate before by Wolf 4 y=116, x=183, store=10
# Else activate after by Wolf 4 y=115, x=182, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 5 ***************
# 0 Sheep - before moving+eating - y=288, x=16, store=60
# 0 Sheep-after moving+eating y=289, x=15, store=70
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=239, x=272, store=10
# Sheep 1 y=239, x=272, store=10 detected Wolf 1 y=235, x=267, store=0, cy=235, x=267, store=0 within distance 6.4031242374328485
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=235, x=267, store=0 Sheep: 1 y=239, x=272, store=10
# CW+ after Wolf: y=235, x=267, store=0 Sheep: 1 y=241, x=275, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=295, x=11, store=60
# 2 Sheep-after moving+eating y=294, x=10, store=70
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=105, x=240, store=60
# 3 Sheep-after moving+eating y=106, x=239, store=70
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=140, store=60
# 4 Sheep-after moving+eating y=248, x=141, store=70
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=17, store=60
# 5 Sheep-after moving+eating y=85, x=16, store=70
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=250, store=60
# 6 Sheep-after moving+eating y=265, x=251, store=70
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=169, x=44, store=60
# 7 Sheep-after moving+eating y=168, x=43, store=70
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=22, x=211, store=60
# 8 Sheep-after moving+eating y=21, x=210, store=70
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=111, x=184, store=0
# Else activate before by Wolf 0 y=111, x=184, store=0
# Else activate after by Wolf 0 y=112, x=185, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=235, x=267, store=0
# >>> min_dist = 10.0 Sheep 1 y=241, x=275, store=10 by Wolf 1 y=235, x=267, store=0
# M.........................................
# CS+ before y=241, x=275, store=10 Wolf 1 y=235, x=267, store=0
# CS+ after y=241, x=275, store=10 Wolf 1 y=238, x=271, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=115, x=182, store=10
# Else activate before by Wolf 4 y=115, x=182, store=10
# Else activate after by Wolf 4 y=114, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 6 ***************
# 0 Sheep - before moving+eating - y=289, x=15, store=70
# 0 Sheep-after moving+eating y=290, x=14, store=80
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=241, x=275, store=10
# Sheep 1 y=241, x=275, store=10 detected Wolf 1 y=238, x=271, store=0, cy=238, x=271, store=0 within distance 5.0
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=238, x=271, store=0 Sheep: 1 y=241, x=275, store=10
# CW+ after Wolf: y=238, x=271, store=0 Sheep: 1 y=243, x=277, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=294, x=10, store=70
# 2 Sheep-after moving+eating y=293, x=9, store=80
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=106, x=239, store=70
# 3 Sheep-after moving+eating y=107, x=240, store=80
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=248, x=141, store=70
# 4 Sheep-after moving+eating y=249, x=140, store=80
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=16, store=70
# 5 Sheep-after moving+eating y=86, x=17, store=80
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=265, x=251, store=70
# 6 Sheep-after moving+eating y=266, x=252, store=80
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=168, x=43, store=70
# 7 Sheep-after moving+eating y=167, x=42, store=80
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=21, x=210, store=70
# 8 Sheep-after moving+eating y=20, x=211, store=80
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=112, x=185, store=0
# Else activate before by Wolf 0 y=112, x=185, store=0
# Else activate after by Wolf 0 y=111, x=184, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=238, x=271, store=0
# >>> min_dist = 7.810249675906654 Sheep 1 y=243, x=277, store=10 by Wolf 1 y=238, x=271, store=0
# M.........................................
# CS+ before y=243, x=277, store=10 Wolf 1 y=238, x=271, store=0
# CS+ after y=243, x=277, store=10 Wolf 1 y=240, x=274, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=149, x=134, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=235, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=114, x=181, store=10
# Else activate before by Wolf 4 y=114, x=181, store=10
# Else activate after by Wolf 4 y=113, x=182, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 7 ***************
# 0 Sheep - before moving+eating - y=290, x=14, store=80
# 0 Sheep-after moving+eating y=291, x=15, store=90
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=243, x=277, store=10
# Sheep 1 y=243, x=277, store=10 detected Wolf 1 y=240, x=274, store=0, cy=240, x=274, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=240, x=274, store=0 Sheep: 1 y=243, x=277, store=10
# CW+ after Wolf: y=240, x=274, store=0 Sheep: 1 y=245, x=279, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=9, store=80
# 2 Sheep-after moving+eating y=292, x=8, store=90
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=240, store=80
# 3 Sheep-after moving+eating y=108, x=241, store=90
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=140, store=80
# 4 Sheep-after moving+eating y=250, x=141, store=90
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=17, store=80
# 5 Sheep-after moving+eating y=85, x=16, store=90
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=266, x=252, store=80
# 6 Sheep-after moving+eating y=267, x=251, store=90
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=42, store=80
# 7 Sheep-after moving+eating y=166, x=43, store=90
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=20, x=211, store=80
# 8 Sheep-after moving+eating y=19, x=212, store=90
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=111, x=184, store=0
# Else activate before by Wolf 0 y=111, x=184, store=0
# Else activate after by Wolf 0 y=110, x=183, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=240, x=274, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=245, x=279, store=10 by Wolf 1 y=240, x=274, store=0
# M.........................................
# CS+ before y=245, x=279, store=10 Wolf 1 y=240, x=274, store=0
# CS+ after y=245, x=279, store=10 Wolf 1 y=242, x=276, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=149, x=134, store=0
# Else activate before by Wolf 2 y=149, x=134, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=235, x=91, store=0
# Else activate before by Wolf 3 y=235, x=91, store=0
# Else activate after by Wolf 3 y=234, x=90, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=113, x=182, store=10
# Else activate before by Wolf 4 y=113, x=182, store=10
# Else activate after by Wolf 4 y=112, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 8 ***************
# 0 Sheep - before moving+eating - y=291, x=15, store=90
# 0 Sheep-after moving+eating y=290, x=14, store=100
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=245, x=279, store=10
# Sheep 1 y=245, x=279, store=10 detected Wolf 1 y=242, x=276, store=0, cy=242, x=276, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=242, x=276, store=0 Sheep: 1 y=245, x=279, store=10
# CW+ after Wolf: y=242, x=276, store=0 Sheep: 1 y=247, x=281, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=8, store=90
# 2 Sheep-after moving+eating y=293, x=9, store=100
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=108, x=241, store=90
# 3 Sheep-after moving+eating y=107, x=242, store=100
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=250, x=141, store=90
# 4 Sheep-after moving+eating y=249, x=140, store=100
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=16, store=90
# 5 Sheep-after moving+eating y=86, x=15, store=100
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=267, x=251, store=90
# 6 Sheep-after moving+eating y=268, x=252, store=100
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=43, store=90
# 7 Sheep-after moving+eating y=165, x=42, store=100
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=19, x=212, store=90
# 8 Sheep-after moving+eating y=18, x=213, store=100
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=110, x=183, store=0
# Else activate before by Wolf 0 y=110, x=183, store=0
# Else activate after by Wolf 0 y=109, x=182, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=242, x=276, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=247, x=281, store=10 by Wolf 1 y=242, x=276, store=0
# M.........................................
# CS+ before y=247, x=281, store=10 Wolf 1 y=242, x=276, store=0
# CS+ after y=247, x=281, store=10 Wolf 1 y=244, x=278, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=151, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=90, store=0
# Else activate before by Wolf 3 y=234, x=90, store=0
# Else activate after by Wolf 3 y=233, x=91, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=112, x=181, store=10
# Else activate before by Wolf 4 y=112, x=181, store=10
# Else activate after by Wolf 4 y=113, x=180, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 9 ***************
# 0 Sheep - before moving+eating - y=290, x=14, store=100
# 0 Sheep-after moving+eating y=289, x=13, store=110
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=247, x=281, store=10
# Sheep 1 y=247, x=281, store=10 detected Wolf 1 y=244, x=278, store=0, cy=244, x=278, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=244, x=278, store=0 Sheep: 1 y=247, x=281, store=10
# CW+ after Wolf: y=244, x=278, store=0 Sheep: 1 y=249, x=283, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=9, store=100
# 2 Sheep-after moving+eating y=292, x=8, store=110
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=107, x=242, store=100
# 3 Sheep-after moving+eating y=108, x=241, store=110
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=140, store=100
# 4 Sheep-after moving+eating y=248, x=141, store=110
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=86, x=15, store=100
# 5 Sheep-after moving+eating y=85, x=16, store=110
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=268, x=252, store=100
# 6 Sheep-after moving+eating y=269, x=253, store=110
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=165, x=42, store=100
# 7 Sheep-after moving+eating y=166, x=41, store=110
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=18, x=213, store=100
# 8 Sheep-after moving+eating y=19, x=212, store=110
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=109, x=182, store=0
# Else activate before by Wolf 0 y=109, x=182, store=0
# Else activate after by Wolf 0 y=108, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=244, x=278, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=249, x=283, store=10 by Wolf 1 y=244, x=278, store=0
# M.........................................
# CS+ before y=249, x=283, store=10 Wolf 1 y=244, x=278, store=0
# CS+ after y=249, x=283, store=10 Wolf 1 y=246, x=280, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=151, x=136, store=0
# Else activate before by Wolf 2 y=151, x=136, store=0
# Else activate after by Wolf 2 y=150, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=91, store=0
# Else activate before by Wolf 3 y=233, x=91, store=0
# Else activate after by Wolf 3 y=234, x=92, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=113, x=180, store=10
# Else activate before by Wolf 4 y=113, x=180, store=10
# Else activate after by Wolf 4 y=114, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 10 ***************
# 0 Sheep - before moving+eating - y=289, x=13, store=110
# 0 Sheep-after moving+eating y=288, x=14, store=120
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=249, x=283, store=10
# Sheep 1 y=249, x=283, store=10 detected Wolf 1 y=246, x=280, store=0, cy=246, x=280, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=246, x=280, store=0 Sheep: 1 y=249, x=283, store=10
# CW+ after Wolf: y=246, x=280, store=0 Sheep: 1 y=251, x=285, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=8, store=110
# 2 Sheep-after moving+eating y=293, x=7, store=120
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=108, x=241, store=110
# 3 Sheep-after moving+eating y=109, x=242, store=120
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=248, x=141, store=110
# 4 Sheep-after moving+eating y=247, x=142, store=120
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=85, x=16, store=110
# 5 Sheep-after moving+eating y=84, x=17, store=120
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=269, x=253, store=110
# 6 Sheep-after moving+eating y=270, x=254, store=120
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=41, store=110
# 7 Sheep-after moving+eating y=167, x=42, store=120
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=19, x=212, store=110
# 8 Sheep-after moving+eating y=18, x=213, store=120
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=108, x=181, store=0
# Else activate before by Wolf 0 y=108, x=181, store=0
# Else activate after by Wolf 0 y=107, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=246, x=280, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=251, x=285, store=10 by Wolf 1 y=246, x=280, store=0
# M.........................................
# CS+ before y=251, x=285, store=10 Wolf 1 y=246, x=280, store=0
# CS+ after y=251, x=285, store=10 Wolf 1 y=248, x=282, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=150, x=137, store=0
# Else activate before by Wolf 2 y=150, x=137, store=0
# Else activate after by Wolf 2 y=151, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=234, x=92, store=0
# Else activate before by Wolf 3 y=234, x=92, store=0
# Else activate after by Wolf 3 y=233, x=93, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=114, x=181, store=10
# Else activate before by Wolf 4 y=114, x=181, store=10
# Else activate after by Wolf 4 y=113, x=180, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 11 ***************
# 0 Sheep - before moving+eating - y=288, x=14, store=120
# 0 Sheep-after moving+eating y=289, x=15, store=130
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=251, x=285, store=10
# Sheep 1 y=251, x=285, store=10 detected Wolf 1 y=248, x=282, store=0, cy=248, x=282, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=248, x=282, store=0 Sheep: 1 y=251, x=285, store=10
# CW+ after Wolf: y=248, x=282, store=0 Sheep: 1 y=253, x=287, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=7, store=120
# 2 Sheep-after moving+eating y=292, x=8, store=130
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=109, x=242, store=120
# 3 Sheep-after moving+eating y=110, x=241, store=130
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=247, x=142, store=120
# 4 Sheep-after moving+eating y=248, x=143, store=130
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=17, store=120
# 5 Sheep-after moving+eating y=83, x=16, store=130
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=270, x=254, store=120
# 6 Sheep-after moving+eating y=271, x=253, store=130
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=167, x=42, store=120
# 7 Sheep-after moving+eating y=166, x=41, store=130
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=18, x=213, store=120
# 8 Sheep-after moving+eating y=17, x=214, store=130
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=107, x=180, store=0
# Else activate before by Wolf 0 y=107, x=180, store=0
# Else activate after by Wolf 0 y=108, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=248, x=282, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=253, x=287, store=10 by Wolf 1 y=248, x=282, store=0
# M.........................................
# CS+ before y=253, x=287, store=10 Wolf 1 y=248, x=282, store=0
# CS+ after y=253, x=287, store=10 Wolf 1 y=250, x=284, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=151, x=136, store=0
# Else activate before by Wolf 2 y=151, x=136, store=0
# Else activate after by Wolf 2 y=150, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=93, store=0
# Else activate before by Wolf 3 y=233, x=93, store=0
# Else activate after by Wolf 3 y=232, x=94, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=113, x=180, store=10
# Else activate before by Wolf 4 y=113, x=180, store=10
# Else activate after by Wolf 4 y=112, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 12 ***************
# 0 Sheep - before moving+eating - y=289, x=15, store=130
# 0 Sheep-after moving+eating y=290, x=16, store=140
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=253, x=287, store=10
# Sheep 1 y=253, x=287, store=10 detected Wolf 1 y=250, x=284, store=0, cy=250, x=284, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=250, x=284, store=0 Sheep: 1 y=253, x=287, store=10
# CW+ after Wolf: y=250, x=284, store=0 Sheep: 1 y=255, x=289, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=8, store=130
# 2 Sheep-after moving+eating y=291, x=9, store=140
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=110, x=241, store=130
# 3 Sheep-after moving+eating y=109, x=240, store=140
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=248, x=143, store=130
# 4 Sheep-after moving+eating y=249, x=142, store=140
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=83, x=16, store=130
# 5 Sheep-after moving+eating y=84, x=15, store=140
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=271, x=253, store=130
# 6 Sheep-after moving+eating y=272, x=252, store=140
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=166, x=41, store=130
# 7 Sheep-after moving+eating y=165, x=42, store=140
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=17, x=214, store=130
# 8 Sheep-after moving+eating y=16, x=213, store=140
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=108, x=179, store=0
# Else activate before by Wolf 0 y=108, x=179, store=0
# Else activate after by Wolf 0 y=109, x=180, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=250, x=284, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=255, x=289, store=10 by Wolf 1 y=250, x=284, store=0
# M.........................................
# CS+ before y=255, x=289, store=10 Wolf 1 y=250, x=284, store=0
# CS+ after y=255, x=289, store=10 Wolf 1 y=252, x=286, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=150, x=137, store=0
# Else activate before by Wolf 2 y=150, x=137, store=0
# Else activate after by Wolf 2 y=151, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=232, x=94, store=0
# Else activate before by Wolf 3 y=232, x=94, store=0
# Else activate after by Wolf 3 y=233, x=95, store=0
# E.........................................
# 4 Wolf - before moving/eating - y=112, x=181, store=10
# Else activate before by Wolf 4 y=112, x=181, store=10
# Else activate after by Wolf 4 y=111, x=180, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 13 ***************
# 0 Sheep - before moving+eating - y=290, x=16, store=140
# 0 Sheep-after moving+eating y=291, x=15, store=150
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=255, x=289, store=10
# Sheep 1 y=255, x=289, store=10 detected Wolf 1 y=252, x=286, store=0, cy=252, x=286, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=252, x=286, store=0 Sheep: 1 y=255, x=289, store=10
# CW+ after Wolf: y=252, x=286, store=0 Sheep: 1 y=257, x=291, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=291, x=9, store=140
# 2 Sheep-after moving+eating y=292, x=10, store=150
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=109, x=240, store=140
# 3 Sheep-after moving+eating y=110, x=241, store=150
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=249, x=142, store=140
# 4 Sheep-after moving+eating y=248, x=141, store=150
# ...........Sheep moved normally and ate...........
# 5 Sheep - before moving+eating - y=84, x=15, store=140
# 5 Sheep-after moving+eating y=85, x=16, store=150
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=272, x=252, store=140
# 6 Sheep-after moving+eating y=273, x=253, store=150
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=165, x=42, store=140
# 7 Sheep-after moving+eating y=164, x=41, store=150
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=16, x=213, store=140
# 8 Sheep-after moving+eating y=15, x=212, store=150
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=109, x=180, store=0
# Else activate before by Wolf 0 y=109, x=180, store=0
# Else activate after by Wolf 0 y=110, x=181, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=252, x=286, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=257, x=291, store=10 by Wolf 1 y=252, x=286, store=0
# M.........................................
# CS+ before y=257, x=291, store=10 Wolf 1 y=252, x=286, store=0
# CS+ after y=257, x=291, store=10 Wolf 1 y=254, x=288, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=151, x=136, store=0
# Else activate before by Wolf 2 y=151, x=136, store=0
# Else activate after by Wolf 2 y=152, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=233, x=95, store=0
# >>> min_dist = 48.38388161361178 Sheep 4 y=248, x=141, store=150 by Wolf 3 y=233, x=95, store=0
# M.........................................
# ...
# CW+ after Wolf: y=246, x=135, store=0 Sheep: 4 y=255, x=162, store=150
# ...........Sheep tried to move away...........
# 5 Sheep - before moving+eating - y=86, x=17, store=160
# 5 Sheep-after moving+eating y=87, x=18, store=170
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=274, x=252, store=160
# 6 Sheep-after moving+eating y=273, x=253, store=170
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=165, x=42, store=160
# 7 Sheep-after moving+eating y=164, x=43, store=170
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=16, x=211, store=160
# 8 Sheep-after moving+eating y=15, x=212, store=170
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=109, x=180, store=0
# Else activate before by Wolf 0 y=109, x=180, store=0
# Else activate after by Wolf 0 y=110, x=179, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=256, x=290, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=261, x=295, store=10 by Wolf 1 y=256, x=290, store=0
# M.........................................
# CS+ before y=261, x=295, store=10 Wolf 1 y=256, x=290, store=0
# CS+ after y=261, x=295, store=10 Wolf 1 y=258, x=292, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=151, x=136, store=0
# Else activate before by Wolf 2 y=151, x=136, store=0
# Else activate after by Wolf 2 y=152, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=246, x=135, store=0
# >>> min_dist = 28.460498941515414 Sheep 4 y=255, x=162, store=150 by Wolf 3 y=246, x=135, store=0
# M.........................................
# CS+ before y=255, x=162, store=150 Wolf 3 y=246, x=135, store=0
# CS+ after y=255, x=162, store=150 Wolf 3 y=250, x=148, store=0
# Y.........................................
# 4 Wolf - before moving/eating - y=111, x=180, store=10
# Else activate before by Wolf 4 y=111, x=180, store=10
# Else activate after by Wolf 4 y=112, x=179, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 16 ***************
# 0 Sheep - before moving+eating - y=291, x=13, store=170
# 0 Sheep-after moving+eating y=292, x=12, store=180
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=261, x=295, store=10
# Sheep 1 y=261, x=295, store=10 detected Wolf 1 y=258, x=292, store=0, cy=258, x=292, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=258, x=292, store=0 Sheep: 1 y=261, x=295, store=10
# CW+ after Wolf: y=258, x=292, store=0 Sheep: 1 y=263, x=297, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=10, store=170
# 2 Sheep-after moving+eating y=291, x=9, store=180
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=110, x=241, store=170
# 3 Sheep-after moving+eating y=111, x=240, store=180
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=255, x=162, store=150
# Sheep 4 y=255, x=162, store=150 detected Wolf 3 y=250, x=148, store=0, cy=250, x=148, store=0 within distance 14.866068747318506
# ...........Sheep 4 noticed closest wolf 3...........
# CW+ before Wolf: y=250, x=148, store=0 Sheep: 4 y=255, x=162, store=150
# CW+ after Wolf: y=250, x=148, store=0 Sheep: 4 y=258, x=169, store=150
# ...........Sheep tried to move away...........
# 5 Sheep - before moving+eating - y=87, x=18, store=170
# 5 Sheep-after moving+eating y=88, x=19, store=180
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=273, x=253, store=170
# 6 Sheep-after moving+eating y=274, x=254, store=180
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=164, x=43, store=170
# 7 Sheep-after moving+eating y=165, x=44, store=180
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=15, x=212, store=170
# 8 Sheep-after moving+eating y=14, x=211, store=180
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=110, x=179, store=0
# Else activate before by Wolf 0 y=110, x=179, store=0
# Else activate after by Wolf 0 y=109, x=178, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=258, x=292, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=263, x=297, store=10 by Wolf 1 y=258, x=292, store=0
# M.........................................
# CS+ before y=263, x=297, store=10 Wolf 1 y=258, x=292, store=0
# CS+ after y=263, x=297, store=10 Wolf 1 y=260, x=294, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=152, x=135, store=0
# Else activate before by Wolf 2 y=152, x=135, store=0
# Else activate after by Wolf 2 y=151, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=250, x=148, store=0
# >>> min_dist = 22.47220505424423 Sheep 4 y=258, x=169, store=150 by Wolf 3 y=250, x=148, store=0
# M.........................................
# CS+ before y=258, x=169, store=150 Wolf 3 y=250, x=148, store=0
# CS+ after y=258, x=169, store=150 Wolf 3 y=254, x=158, store=0
# Y.........................................
# 4 Wolf - before moving/eating - y=112, x=179, store=10
# Else activate before by Wolf 4 y=112, x=179, store=10
# Else activate after by Wolf 4 y=111, x=180, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
# ***************Iteration no 17 ***************
# 0 Sheep - before moving+eating - y=292, x=12, store=180
# 0 Sheep-after moving+eating y=291, x=13, store=190
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=263, x=297, store=10
# Sheep 1 y=263, x=297, store=10 detected Wolf 1 y=260, x=294, store=0, cy=260, x=294, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=260, x=294, store=0 Sheep: 1 y=263, x=297, store=10
# CW+ after Wolf: y=260, x=294, store=0 Sheep: 1 y=265, x=299, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=291, x=9, store=180
# 2 Sheep-after moving+eating y=292, x=8, store=190
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=111, x=240, store=180
# 3 Sheep-after moving+eating y=110, x=239, store=190
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=258, x=169, store=150
# Sheep 4 y=258, x=169, store=150 detected Wolf 3 y=254, x=158, store=0, cy=254, x=158, store=0 within distance 11.704699910719626
# ...........Sheep 4 noticed closest wolf 3...........
# CW+ before Wolf: y=254, x=158, store=0 Sheep: 4 y=258, x=169, store=150
# CW+ after Wolf: y=254, x=158, store=0 Sheep: 4 y=260, x=175, store=150
# ...........Sheep tried to move away...........
# 5 Sheep - before moving+eating - y=88, x=19, store=180
# 5 Sheep-after moving+eating y=89, x=18, store=190
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=274, x=254, store=180
# 6 Sheep-after moving+eating y=273, x=253, store=190
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=165, x=44, store=180
# 7 Sheep-after moving+eating y=164, x=45, store=190
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=14, x=211, store=180
# 8 Sheep-after moving+eating y=13, x=210, store=190
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=109, x=178, store=0
# Else activate before by Wolf 0 y=109, x=178, store=0
# Else activate after by Wolf 0 y=110, x=177, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=260, x=294, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=265, x=299, store=10 by Wolf 1 y=260, x=294, store=0
# M.........................................
# CS+ before y=265, x=299, store=10 Wolf 1 y=260, x=294, store=0
# CS+ after y=265, x=299, store=10 Wolf 1 y=262, x=296, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=151, x=136, store=0
# Else activate before by Wolf 2 y=151, x=136, store=0
# Else activate after by Wolf 2 y=150, x=135, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=254, x=158, store=0
# >>> min_dist = 18.027756377319946 Sheep 4 y=260, x=175, store=150 by Wolf 3 y=254, x=158, store=0
# M.........................................
# CS+ before y=260, x=175, store=150 Wolf 3 y=254, x=158, store=0
# CS+ after y=260, x=175, store=150 Wolf 3 y=257, x=166, store=0
# Y.........................................
# 4 Wolf - before moving/eating - y=111, x=180, store=10
# Else activate before by Wolf 4 y=111, x=180, store=10
# Else activate after by Wolf 4 y=110, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 18 ***************
# 0 Sheep - before moving+eating - y=291, x=13, store=190
# 0 Sheep-after moving+eating y=292, x=14, store=200
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=265, x=299, store=10
# Sheep 1 y=265, x=299, store=10 detected Wolf 1 y=262, x=296, store=0, cy=262, x=296, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=262, x=296, store=0 Sheep: 1 y=265, x=299, store=10
# CW+ after Wolf: y=262, x=296, store=0 Sheep: 1 y=267, x=301, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=292, x=8, store=190
# 2 Sheep-after moving+eating y=293, x=9, store=200
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=110, x=239, store=190
# 3 Sheep-after moving+eating y=109, x=238, store=200
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=260, x=175, store=150
# Sheep 4 y=260, x=175, store=150 detected Wolf 3 y=257, x=166, store=0, cy=257, x=166, store=0 within distance 9.486832980505138
# ...........Sheep 4 noticed closest wolf 3...........
# CW+ before Wolf: y=257, x=166, store=0 Sheep: 4 y=260, x=175, store=150
# CW+ after Wolf: y=257, x=166, store=0 Sheep: 4 y=262, x=180, store=150
# ...........Sheep tried to move away...........
# 5 Sheep - before moving+eating - y=89, x=18, store=190
# 5 Sheep-after moving+eating y=90, x=17, store=200
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=273, x=253, store=190
# 6 Sheep-after moving+eating y=274, x=252, store=200
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=164, x=45, store=190
# 7 Sheep-after moving+eating y=165, x=46, store=200
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=13, x=210, store=190
# 8 Sheep-after moving+eating y=14, x=209, store=200
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=110, x=177, store=0
# Else activate before by Wolf 0 y=110, x=177, store=0
# Else activate after by Wolf 0 y=109, x=176, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=262, x=296, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=267, x=301, store=10 by Wolf 1 y=262, x=296, store=0
# M.........................................
# CS+ before y=267, x=301, store=10 Wolf 1 y=262, x=296, store=0
# CS+ after y=267, x=301, store=10 Wolf 1 y=264, x=298, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=150, x=135, store=0
# Else activate before by Wolf 2 y=150, x=135, store=0
# Else activate after by Wolf 2 y=149, x=136, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=257, x=166, store=0
# >>> min_dist = 14.866068747318506 Sheep 4 y=262, x=180, store=150 by Wolf 3 y=257, x=166, store=0
# M.........................................
# CS+ before y=262, x=180, store=150 Wolf 3 y=257, x=166, store=0
# CS+ after y=262, x=180, store=150 Wolf 3 y=259, x=173, store=0
# Y.........................................
# 4 Wolf - before moving/eating - y=110, x=181, store=10
# Else activate before by Wolf 4 y=110, x=181, store=10
# Else activate after by Wolf 4 y=109, x=180, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
#
# ***************Iteration no 19 ***************
# 0 Sheep - before moving+eating - y=292, x=14, store=200
# 0 Sheep-after moving+eating y=291, x=13, store=210
# ...........Sheep moved normally and ate...........
# 1 Sheep - before moving+eating - y=267, x=301, store=10
# Sheep 1 y=267, x=301, store=10 detected Wolf 1 y=264, x=298, store=0, cy=264, x=298, store=0 within distance 4.242640687119285
# ...........Sheep 1 noticed closest wolf 1...........
# CW+ before Wolf: y=264, x=298, store=0 Sheep: 1 y=267, x=301, store=10
# CW+ after Wolf: y=264, x=298, store=0 Sheep: 1 y=269, x=303, store=10
# ...........Sheep tried to move away...........
# 2 Sheep - before moving+eating - y=293, x=9, store=200
# 2 Sheep-after moving+eating y=292, x=8, store=210
# ...........Sheep moved normally and ate...........
# 3 Sheep - before moving+eating - y=109, x=238, store=200
# 3 Sheep-after moving+eating y=110, x=237, store=210
# ...........Sheep moved normally and ate...........
# 4 Sheep - before moving+eating - y=262, x=180, store=150
# Sheep 4 y=262, x=180, store=150 detected Wolf 3 y=259, x=173, store=0, cy=259, x=173, store=0 within distance 7.615773105863909
# ...........Sheep 4 noticed closest wolf 3...........
# CW+ before Wolf: y=259, x=173, store=0 Sheep: 4 y=262, x=180, store=150
# CW+ after Wolf: y=259, x=173, store=0 Sheep: 4 y=264, x=184, store=150
# ...........Sheep tried to move away...........
# 5 Sheep - before moving+eating - y=90, x=17, store=200
# 5 Sheep-after moving+eating y=91, x=16, store=210
# ...........Sheep moved normally and ate...........
# 6 Sheep - before moving+eating - y=274, x=252, store=200
# 6 Sheep-after moving+eating y=275, x=253, store=210
# ...........Sheep moved normally and ate...........
# 7 Sheep - before moving+eating - y=165, x=46, store=200
# 7 Sheep-after moving+eating y=166, x=47, store=210
# ...........Sheep moved normally and ate...........
# 8 Sheep - before moving+eating - y=14, x=209, store=200
# 8 Sheep-after moving+eating y=15, x=210, store=210
# ...........Sheep moved normally and ate...........
# Sheep Cycle Ends________________________________________
# 0 Wolf - before moving/eating - y=109, x=176, store=0
# Else activate before by Wolf 0 y=109, x=176, store=0
# Else activate after by Wolf 0 y=110, x=175, store=0
# E.........................................
# 1 Wolf - before moving/eating - y=264, x=298, store=0
# >>> min_dist = 7.0710678118654755 Sheep 1 y=269, x=303, store=10 by Wolf 1 y=264, x=298, store=0
# M.........................................
# CS+ before y=269, x=303, store=10 Wolf 1 y=264, x=298, store=0
# CS+ after y=269, x=303, store=10 Wolf 1 y=266, x=300, store=0
# Y.........................................
# 2 Wolf - before moving/eating - y=149, x=136, store=0
# Else activate before by Wolf 2 y=149, x=136, store=0
# Else activate after by Wolf 2 y=150, x=137, store=0
# E.........................................
# 3 Wolf - before moving/eating - y=259, x=173, store=0
# >>> min_dist = 12.083045973594572 Sheep 4 y=264, x=184, store=150 by Wolf 3 y=259, x=173, store=0
# M.........................................
# CS+ before y=264, x=184, store=150 Wolf 3 y=259, x=173, store=0
# CS+ after y=264, x=184, store=150 Wolf 3 y=261, x=178, store=0
# Y.........................................
# 4 Wolf - before moving/eating - y=109, x=180, store=10
# Else activate before by Wolf 4 y=109, x=180, store=10
# Else activate after by Wolf 4 y=110, x=181, store=10
# E.........................................
# Wolf Cycle Ends___________________________________
