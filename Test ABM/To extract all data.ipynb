# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
import csv

y = None
x = None

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5
no_iterations = 5
proximity = 50
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    sheep.append(af.Sheep(animals, wolves, sheep, environment)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    wolves.append(af.Wolf(animals, wolves, sheep, environment)) 
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

def update(frame_number):
    
    fig.clear()
    # random.shuffle(wolves)
    # random.shuffle(sheep) 
    # for i in range(no_wolves):
    #     for j in range(no_sheep):
    #         distance = af.Animal.dist_animals(wolves[i], sheep[j])
    #         print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
       
    for i in range(len(wolves)):
        wolves[i].move()
        print(i, 'Wolves', wolves[i])
        
    for i in range(len(sheep)):
        sheep[i].move()
        sheep[i].eat()
        print(i, 'Sheep', sheep[i])
    
    for i in range(len(wolves)):
        sheep_count = -1
        # print(f"min_dist a = {min_dist}")
        closest_sheep = None
        for j in sheep[:]:
            min_dist = proximity
            # print(f"min_dist b = {min_dist}")
            sheep_count += 1
            distance = af.Animal.dist_animals(wolves[i], j)
            if distance < min_dist:
                min_dist = distance
                closest_sheep = j
                print(f"min_dist a = {min_dist}, sheep {sheep_count}, wolf {i}")
    
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p")
    for i in range(len(wolves)):
        plt.scatter(wolves[i].x, wolves[i].y, marker="v")

def gen_function(): 
    a = 0 
    # print(f"***Iteration no {a} ***")
    while (a < no_iterations):
        print(f"***Iteration no {a}***")
        yield a
        # print(f"***Iteration no {a} \u2191 ***")
        a = a + 1
        # print(f"***Iteration no {a} \u2191 ***")

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
# Out:
# No sheep 10
# No wolves 5
# ***Iteration no 0***
# 0 Wolves y=72, x=180, store=0
# 1 Wolves y=194, x=214, store=0
# 2 Wolves y=144, x=135, store=0
# 3 Wolves y=234, x=90, store=0
# 4 Wolves y=154, x=186, store=0
# 0 Sheep y=293, x=15, store=10
# 1 Sheep y=220, x=246, store=10
# 2 Sheep y=296, x=8, store=10
# 3 Sheep y=104, x=235, store=10
# 4 Sheep y=252, x=143, store=10
# 5 Sheep y=83, x=18, store=10
# 6 Sheep y=267, x=249, store=10
# 7 Sheep y=166, x=37, store=10
# 8 Sheep y=126, x=185, store=10
# 9 Sheep y=21, x=216, store=10
# min_dist a = 41.23105625617661, sheep 1, wolf 1
# min_dist a = 28.0178514522438, sheep 8, wolf 4
# ***Iteration no 0***
# 0 Wolves y=71, x=181, store=0
# 1 Wolves y=193, x=215, store=0
# 2 Wolves y=145, x=134, store=0
# 3 Wolves y=233, x=91, store=0
# 4 Wolves y=155, x=187, store=0
# 0 Sheep y=294, x=14, store=20
# 1 Sheep y=221, x=247, store=20
# 2 Sheep y=297, x=9, store=20
# 3 Sheep y=103, x=234, store=20
# 4 Sheep y=251, x=144, store=20
# 5 Sheep y=84, x=19, store=20
# 6 Sheep y=268, x=248, store=20
# 7 Sheep y=167, x=38, store=20
# 8 Sheep y=127, x=186, store=20
# 9 Sheep y=20, x=217, store=20
# min_dist a = 42.5205832509386, sheep 1, wolf 1
# min_dist a = 28.0178514522438, sheep 8, wolf 4
# ***Iteration no 1***
# 0 Wolves y=70, x=180, store=0
# 1 Wolves y=194, x=214, store=0
# 2 Wolves y=144, x=133, store=0
# 3 Wolves y=232, x=92, store=0
# 4 Wolves y=156, x=188, store=0
# 0 Sheep y=295, x=15, store=30
# 1 Sheep y=220, x=246, store=30
# 2 Sheep y=298, x=10, store=30
# 3 Sheep y=104, x=233, store=30
# 4 Sheep y=252, x=145, store=30
# 5 Sheep y=85, x=18, store=30
# 6 Sheep y=269, x=249, store=30
# 7 Sheep y=168, x=39, store=30
# 8 Sheep y=126, x=187, store=30
# 9 Sheep y=21, x=218, store=30
# min_dist a = 41.23105625617661, sheep 1, wolf 1
# min_dist a = 30.01666203960727, sheep 8, wolf 4
# ***Iteration no 2***
# 0 Wolves y=69, x=181, store=0
# 1 Wolves y=193, x=213, store=0
# 2 Wolves y=143, x=134, store=0
# 3 Wolves y=231, x=91, store=0
# 4 Wolves y=157, x=189, store=0
# 0 Sheep y=294, x=14, store=40
# 1 Sheep y=219, x=245, store=40
# 2 Sheep y=297, x=11, store=40
# 3 Sheep y=103, x=232, store=40
# 4 Sheep y=253, x=144, store=40
# 5 Sheep y=84, x=17, store=40
# 6 Sheep y=270, x=248, store=40
# 7 Sheep y=167, x=38, store=40
# 8 Sheep y=125, x=188, store=40
# 9 Sheep y=20, x=219, store=40
# min_dist a = 41.23105625617661, sheep 1, wolf 1
# min_dist a = 32.01562118716424, sheep 8, wolf 4
# ***Iteration no 3***
# 0 Wolves y=68, x=180, store=0
# 1 Wolves y=194, x=214, store=0
# 2 Wolves y=144, x=135, store=0
# 3 Wolves y=232, x=92, store=0
# 4 Wolves y=156, x=188, store=0
# 0 Sheep y=295, x=13, store=50
# 1 Sheep y=218, x=244, store=50
# 2 Sheep y=298, x=10, store=50
# 3 Sheep y=102, x=233, store=50
# 4 Sheep y=254, x=143, store=50
# 5 Sheep y=83, x=18, store=50
# 6 Sheep y=269, x=247, store=50
# 7 Sheep y=166, x=37, store=50
# 8 Sheep y=126, x=189, store=50
# 9 Sheep y=21, x=220, store=50
# min_dist a = 38.41874542459709, sheep 1, wolf 1
# min_dist a = 30.01666203960727, sheep 8, wolf 4
# ***Iteration no 4***
# 0 Wolves y=69, x=181, store=0
# 1 Wolves y=193, x=213, store=0
# 2 Wolves y=145, x=134, store=0
# 3 Wolves y=231, x=91, store=0
# 4 Wolves y=157, x=189, store=0
# 0 Sheep y=296, x=12, store=60
# 1 Sheep y=219, x=245, store=60
# 2 Sheep y=299, x=11, store=60
# 3 Sheep y=101, x=232, store=60
# 4 Sheep y=253, x=144, store=60
# 5 Sheep y=82, x=17, store=60
# 6 Sheep y=268, x=246, store=60
# 7 Sheep y=167, x=36, store=60
# 8 Sheep y=125, x=190, store=60
# 9 Sheep y=22, x=221, store=60
# min_dist a = 41.23105625617661, sheep 1, wolf 1
# min_dist a = 32.01562118716424, sheep 8, wolf 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-244c2d557447> in <module>
#     137 model_menu.add_command(label="Run model", command=run)
#     138
# --> 139 tkinter.mainloop()
#     140
#     141 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:
