# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 15 09:26:33 2020

@author: Mushtahid
"""
import TESTAF1 as af
import tkinter
import matplotlib 
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import matplotlib.animation
import random
random.seed(10)
import csv
import requests
import bs4

# Scrape web data to initialise model
r = requests.get('http://www.geog.leeds.ac.uk/courses/computing/practicals/python/agent-framework/part9/data.html')
content = r.text
soup = bs4.BeautifulSoup(content, 'html.parser')
td_ys = soup.find_all(attrs={"class" : "y"})
td_xs = soup.find_all(attrs={"class" : "x"})
# print(td_ys)
# print(td_xs)

environment = []
animals = []
sheep = []
wolves = []
no_sheep = 10
no_wolves = 5

no_iterations = 200
it_no = -1 # No of iterations
proximity = 50
action_dist = 5 # action refers to breeding/eating sheep...
no_animals = no_sheep + no_wolves

fig = plt.figure(figsize=(7, 7))
ax = fig.add_axes([0, 0, 1, 1])

with open('in.txt', newline='') as f:
    env_reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    for row in env_reader:
        rowlist = []
        for value in row:
            rowlist.append(value)
        environment.append(rowlist)

for i in range(no_sheep):
    y = int(td_ys[i].text)
    x = int(td_xs[i].text)
    sheep.append(af.Sheep(animals, wolves, sheep, environment, y, x)) 
print('No sheep', len(sheep))

for i in range(no_wolves):
    y = int(td_ys[-i].text) #interesting!
    x = int(td_xs[-i].text)
    wolves.append(af.Wolf(animals, wolves, sheep, environment, y, x))
print('No wolves', len(wolves))

'The problem with animals is that it is spawning different set of animals'
# for i in range(len(animals)):
#     for j in range(i+1, len(animals)):
#         distance = af.Animal.dist_animals(animals[i], animals[j])
#         print(i, j, distance)

# def gen_function(b = no_iterations):
#     a = 0
#     print('a0', a)
#     # print('')
#     # print(f"*************** ITERATION NUMBER {a} ***************")
#     while a < b:
#         print('')
#         print('a1', a)
#         print(f"*************** ITERATION NUMBER {a} ***************")
#         yield a
#         print('a2', a)
#         # print(f"*************** ITERATION NUMBER {a} ***************")
#         a += 1
#         print('a3', a)
#     # print(f"***Iteration no {a} \u2191 ***")



def gen_function(b = no_iterations):
    a = 0
    while a < b:
        yield a
        a += 1

def update(frame_number):
    fig.clear()
    global it_no
    it_no += 1
    print('')
    print(f"*************** ITERATION NUMBER {it_no} ************")
    
    # random.shuffle(wolves)
    # random.shuffle(sheep) 

### NEED TO ADJUST THE PRINT TAGS LATER   
    sheep_count = -1
    sheep_index = 0 # Prevent breeding between same sheep/same pair.
    for i in sheep[:]:
        sheep_count += 1
        sheep_index += 1
        # print(sheep_count)
        # print(sheep_index)
        print('')
        print(f"-> ------------ {sheep_count} Sheep initialised -----------")
        min_dist = proximity*0.5 # coz sheep is a prey! wolves have higer field of vision!
        closest_wolf = None
        # print(min_dist) #
        # print(closest_wolf) #
        for j in range(len(wolves)): 
            print(f"--> {sheep_count}-Sheep looping with {j}-Wolf.") # To test if looping with all wolves!             
            # Calculate the distance between itself and all wolves.
            distance = af.Animal.dist_animals(i, wolves[j])
            # print(f"--> d={distance} for {i}-Sheep ({sheep[i]}) with {j}-Wolf ({wolves[j]})") #
            # If wolf/ves detected within min_dist, find the closest wolf (CW).
            if distance < min_dist:
                print(f"---> d<md+... {sheep_count}-Sheep noticed closest {j}-Wolf ...")
                min_dist = distance
                closest_wolf = wolves[j]
                print(f"---> {sheep_count}-Sheep ({i}) detected {j}-Wolf ({wolves[j]}) within d={min_dist}.")                
        if closest_wolf != None:
            # Need to adjust here based on store count and probability!
            print("-> CW FOUND.")
            print(f"-> Before {sheep_count}-Sheep ({i}) tries to run away from CW: ({closest_wolf}).")
            i.y = i.y + (i.y - int((i.y + closest_wolf.y)/2))
            i.x = i.x + (i.x - int((i.x + closest_wolf.x)/2))
            i.boundary_conditons()
            print(f"-> After {sheep_count}-Sheep ({i}) tried to run away from CW ({closest_wolf}).")
            print(f"___________ {sheep_count} Sheep tried to run away from CW ___________ ")  
            # for j to if CW+ checked    
        elif closest_wolf == None:
            print(f"--> NO CW FOUND.")
            min_dist = proximity*0.5 # most prob not needed. will see later.
            # action = False
            breed = False
            fail_breed = False
            share = False
            closest_sheep = None
            sheep2_count = -1
            min_energy = 600
            # if e>600 tries to find CS
            if i.store > min_energy:
                print(f"->{sheep_count}-Sheep has Store > {min_energy} ({i}).")
                for j in sheep[sheep_index:]:
                    sheep2_count += 1
                    print(f"--> {sheep_count}-Sheep looping with {sheep2_count}-Sheep.") # To test if looping with i+1 sheep!             
                    # Calculate the distance between itself and other sheep.
                    distance = af.Animal.dist_animals(i, j)
                    if action_dist < distance < min_dist:
                        print('----> ---- (AD < D < MD).')
                        min_dist = distance
                        closest_sheep = j
                        print(f"----> Min distance={min_dist} for {sheep_count}-Sheep ({i}) with {sheep2_count}-Sheep ({j}).")  
                    elif distance <= action_dist:
                        print(f"----> D <=AD. Sheep Breeding/Sharing proximity of {distance}(<={action_dist}) entered by {sheep_count}-Sheep ({i}) with CS {sheep2_count}-Sheep ({j}).")
                        if j.store > min_energy: # Sheep j also has to have store >600 to have chance of breeding
                            print(f"----->{sheep_count}-Sheep ({i}) and {sheep2_count}-Sheep ({j} has MORE than {min_energy} store. So they will breed if p>0.25")
                            breeding_cost = ((i.store + j.store)/2)/2 # half of average.
                            breeding_chance = 0.50
                            if random.random() > breeding_chance:
                                print(f"------>1.A. Random >{breeding_chance}. So the sheep will mate.")
                                print(f"------> {sheep_count}-Sheep ({i}) before mating with {sheep2_count}-Sheep ({j}).")
                                i.store = breeding_cost
                                j.store = breeding_cost
                                print(f"------> {sheep_count}-Sheep ({i}) after mating with {sheep2_count}-Sheep ({j}).")
                                sheep.append(af.Sheep(animals, wolves, sheep, environment, y=(i.y+10), x=(i.x+10))) # x and y so that the new sheep appears closer!
                                breed = True
                                print(f"Breed = {breed}")
                                print(f"_____________ {sheep_count}-Sheep Mated with {sheep2_count}-Sheep ____________")
                                break
                            else:
                                print(f"------>1.B Random <{breeding_chance}. So the breeding will fail.")
                                print(f"------> {sheep_count}-Sheep ({i}) before failed breeding with {sheep2_count}-Sheep ({j})")
                                # average = (i.store + j.store)/2
                                i.store = breeding_cost # breeding attempted. just was not successful!
                                j.store = breeding_cost
                                fail_breed = True
                                print(f"Failed breeding = {fail_breed}")
                                print(f"------> {sheep_count}-Sheep ({i}) after failed breeding with {sheep2_count}-Sheep ({j}).")
                                print(f"_____________ {sheep_count}-Sheep Fail Mated with {sheep2_count}-Sheep ____________")
                                break
                        else:
                            # Print below to just show what is happening. Otherwise this else is not needed.
                            print(f"-----> {sheep_count}-Sheep ({i}) and {sheep2_count}-Sheep ({j} will not mate as {sheep2_count}-Sheep store <{min_energy}. They will share resource to become average.")
                            # print('No break here as I want it to loop through other sheep if i sheep (d<=ad) has >200 store.')
                            average = (i.store + j.store)/2
                            i.store = average
                            j.store = average
                            share = True
                            print(f"Shared resources= {share}")
                            print(f"------> {sheep_count}-Sheep ({i}) and {sheep2_count}-Sheep ({j}) after sharing resources!")
                            print(f"_____________ {sheep_count}-Sheep Fail Mated with {sheep2_count}-Sheep ____________")
                            break
                if breed or fail_breed or share == True:  
                    print(f"--->_______Breeding={breed}, Failed breeding={fail_breed}, Share={share} for {sheep_count}-Wolf__________")
                    # Should add eat and move here? No i guess because they came <ad
                    continue
                elif closest_sheep != None:
                    # Sheep like to stay in a herd. So run close and eats too!
                    print(f"->CS Found!")
                    print(f"-> {sheep_count}-Sheep ({i}) before moving closer (while eating) to CS-Sheep: ({closest_sheep}).")
                    i.y = (int((i.y + closest_sheep.y)/2))
                    i.x = (int((i.x + closest_sheep.x)/2))
                    i.boundary_conditons()
                    i.eat() # This should produce interesting results!
                    print(f"-> {sheep_count}-Wolf ({i}) after moving closer (while eating) to CS-Sheep: ({closest_sheep}).")
                    print(f"___________ {sheep_count}-Sheep moved closer CS___________" )                   
                else:
                    print(f"-> NO CW FOUND. No CS Found or Share={share}.")
                    print(f"-> {sheep_count}-Sheep ({i}) before normally moving and eating.")
                    i.move()
                    i.eat()
                    print(f"-> {sheep_count}-Sheep ({i}) after normally moving and eating.")
                    print(f"___e1________ {sheep_count}-Sheep moved normally and ate ___________")
            
            else: # if i energey < {min_energy}
                print(f"-->{sheep_count}-Sheep has Store < {min_energy} ({i}). will move normally and eat")
                print(f"-->{sheep_count}-Sheep ({i}) before normal moving and eating")
                i.move()
                i.eat()
                print(f"-->{sheep_count}-Sheep ({i}) after normal moving and eating")
                print(f"___e2________ {sheep_count}-Sheep moved normally and ate ___________")
                # wolf checked. none found. energy <600 checked.
        
        print('')        
    print('________________Sheep Cycle Ends________________')
    print('________________Wolf Cycle Begins________________')
       
    wolf_count = -1
    wolf_index = 0 #to prevent comparison between same wolves!
    for i in wolves[:]:
        wolf_count += 1  
        wolf_index += 1
        min_energy = 500
        bf_e = 0.5
        print('')
        print(f"-> -----------{wolf_count}-Wolf initialised with ({i}) -----------")
        
        if i.store <= min_energy:
            print(f"--> {wolf_count}-Wolf has <={min_energy} store ({i}). Tries to find food (sheep).")
            sheep_count = -1
            closest_sheep = None
            min_dist = proximity
            eaten = False
            for j in sheep[:]:
                sheep_count += 1
                print(f"---> {wolf_count}-Wolf looping with {sheep_count}-Sheep")              
                distance = af.Animal.dist_animals(i, j)
                # print(f"distance={distance} between {i}-Wolf ({wolves[i]}) and {sheep_count}-Sheep ({j})")
                # if eat_dist < distance < min_dist:
                if distance <= action_dist:
                    # eats the first sheep at action distance. so should not loop through the other ones.
                    print(f"----> d<=action_dist found")
                    print(f"----> {wolf_count}-Wolf ({i}) before eating {sheep_count}-Sheep ({j})")
                    # This works!
                    i.store += (j.store*(2/3)) # 2/3 eaten! 1/3 returned to env as can't eat everything!
                    env_rcv = (j.store*(1/3)) # env receives 1/3 store!
                    i.environment[i.y][i.x] += env_rcv 
                    j.store = 0
                    print(f"----> {wolf_count}-Wolf ({i}) after eating {sheep_count}-Sheep ({j}). Env received ({env_rcv})")
                    sheep.remove(j)
                    eaten = True # works. still targets. but does not move. so fine!
                    break # works! goes to eaten true!
                    # continue # no good. targets immediately another sheep. and activates else.
                elif action_dist < distance < min_dist:
                    print(f"----> action_dist < distance < min_dist")
                    min_dist = distance
                    closest_sheep = j
                    print(f"----> Min Distance = {min_dist} for {wolf_count}-Wolf ({i}) with {sheep_count}-Sheep ({j})")
                    print('....elif adm ends....')
            if eaten == True:
                #break
                print(f"---> ___________Eaten={eaten}. {wolf_count}-Wolf one ate CS {sheep_count}__________")
                continue # This works!    
            elif closest_sheep != None:
                print(f"-> CS Found!")
                print(f"--> {wolf_count}-Wolf ({i}) before moving closer to  CS-Sheep ({closest_sheep })")
                i.y = (int((i.y + closest_sheep.y)/2))
                i.x = (int((i.x + closest_sheep.x)/2))
                i.boundary_conditons()
                print(f"--> {wolf_count}-Wolf ({i}) after moving closer to Sheep ({closest_sheep })")
                print(f"___________{wolf_count}-Wolf moved closer to CS+___________")           
            else: #no sheep and store <500. need to adjust move speed.
                print(f"-> No CS found and store <500!")
                print(f"-->else1 begins: {wolf_count}-Wolf ({i}) before normal moving")
                i.move()
                print(f"-->else1 ends: {wolf_count}-Wolf ({i}) after normal moving")
                print(f"....el1___________{wolf_count}-Wolf moved normally___________")
                
        elif i.store > min_energy and random.random() > bf_e: 
            print(f"--> {wolf_count}-Wolf has > {min_energy} store ({i}) and p > {bf_e}. so will try to find CW to move closer or breed/fight.")                     
            min_dist = proximity
            # action = False
            fight = False
            breed = False
            fail_breed = False
            closest_wolf = None
            wolf2_count = -1
            for j in wolves[wolf_index:]: # so that action is not duplicated for same wolf or same pair.
                wolf2_count += 1
                print(f"---> {wolf_count}-Wolf looping with {wolf2_count}-Wolf")
                distance =  af.Animal.dist_animals(i, j)
                if action_dist < distance < min_dist: 
                    print('----> (AD2 < D < MD).')
                    min_dist = distance
                    closest_wolf = j
                    print(f"----> Min distance={min_dist} for {wolf_count}-Wolf ({i}) with {wolf2_count}-Wolf ({j})")  
                elif distance <= action_dist:
                    print(f"----> d<=ad. breeding/fight roximity of {distance}(<={action_dist}) entered by {wolf_count}-Wolf ({i}) with CW {wolf2_count}-Wolf ({j}).")
                    if j.store > min_energy:
                        print(f"----->{wolf2_count}-Wolf ({j} has > {min_energy} store. So they will try breeding. {bf_e} probability breeding successfully.")
                        breeding_cost = ((i.store + j.store)/2)/2 # half of average.
                        if random.random() > bf_e:
                            print(f"------>1.A. Random >{bf_e}. So the wolves will mate.")
                            print(f"------> {wolf_count}-Wolf ({i}) before mating with {wolf2_count}-Wolf ({j})")
                            i.store = breeding_cost
                            j.store = breeding_cost
                            print(f"------> {wolf_count}-Wolf ({i}) after mating with {wolf2_count}-Wolf ({j})")
                            wolves.append(af.Wolf(animals, wolves, sheep, environment, y=(i.y+5), x=(i.x+5)))
                            breed = True
                            print(f"------> Breed = {breed}")
                            print(f"_____________{wolf_count}-Wolf Mated with {wolf2_count}-Wolf____________")
                        else:
                            print(f"----->1.B. Random <{bf_e}. So breeding will not be successful.")
                            print(f"----->{wolf_count}-Wolf ({i}) before fail breeding with {wolf2_count}-Wolf ({j})")
                            i.store = breeding_cost
                            j.store = breeding_cost  
                            fail_breed = True
                            print(f"------> Fail Breeding = {fail_breed}")
                            print(f"----->{wolf_count}-Wolf ({i}) after fail breeding with {wolf2_count}-Wolf ({j})")
                        break
                    else:
                        print(f"----->2.A. {wolf2_count}-Wolf has < than {min_energy} store")
                        print(f"----->{wolf_count}-Wolf ({i}) and {wolf2_count}-Wolf ({j} will fight")
                        # This works! 
                        if random.random() > bf_e:
                            # print(f"------>2.A.i. Random > 0.25. So {wolf_count}-Wolf will win 75% of {wolf2_count}-Wolf store.")
                            print(f"------>2.A.i. Random > {bf_e}. So {wolf_count}-Wolf will win {bf_e*100}% of {wolf2_count}-Wolf store.")
                            gain = (j.store*bf_e)
                            i.store += gain
                            j.store -= gain
                            i.move() # MOVE ADDED
                            print(f"------> {wolf_count}-Wolf ({i}) won+moved after fighting with {wolf2_count}-Wolf ({j})")
                        else:
                            # print(f"------>2.A.ii. Random < 0.25. So {wolf_count}-Wolf will loose 25% store to {wolf2_count}-Wolf")
                            print(f"------>2.A.ii. Random < bf_e. So {wolf_count}-Wolf will loose {bf_e*100}% store to {wolf2_count}-Wolf")
                            lose = (i.store*bf_e)
                            i.store -= lose
                            j.store += lose
                            i.move() # MOVE ADDED
                            print(f"------> {wolf_count}-Wolf ({i}) lost+moved after fighting with {wolf2_count}-Wolf ({j})")
                            # action = True
                        fight = True
                        print(f"Fight 2 = {fight}")
                        print(f"_____________{wolf_count}-Wolf Fought-(2) with {wolf2_count}-Wolf____________")
                        break
            if breed or fail_breed or fight == True:   
                print(f"--->_______Breed={breed}, Failed Breed={fail_breed}, Fought={fight} for {wolf_count}-Wolf__________")
                continue
            elif closest_wolf != None:
                print(f"->CW Found!")
                print(f"-> {wolf_count}-Wolf ({i}) before moving closer to CW-Wolf: ({closest_wolf}).")
                i.y = (int((i.y + closest_wolf.y)/2))
                i.x = (int((i.x + closest_wolf.x)/2))
                i.boundary_conditons()
                print(f"-> {wolf_count}-Wolf ({i}) after moving closer to CW-Wolf: ({closest_wolf}).")
                print(f"..........{wolf_count}-Wolf moved closer CW+..........")   
            else: # No CW. E>min_energy and p>bf_e
                print(f"-> No CW found. although store >{min_energy} and p>{bf_e}!")
                print(f"--->else2 begins: {wolf_count}-Wolf ({i}) before normal moving.")
                i.move()
                print(f"--->else2 begins: {wolf_count}-Wolf ({i}) after normal moving.")
                print(f"....el2...... {wolf_count}-Wolf moved normally")
        else: # if elif not satisfied
            print(f"--> elif not satisfied")
            print(f"--->else3 begins: {wolf_count}-Wolf ({i}) before normal moving.")
            i.move()
            print(f"--->else3 begins: {wolf_count}-Wolf ({i}) after normal moving.")
            print(f"....el3...... {wolf_count}-Wolf moved normally")
    
    
    print('________________Wolf Cycle Ends_________________')
        
    # for i in range(len(sheep)):
    #     sheep[i].move()
    #     sheep[i].eat()
    #     print(i, 'Sheep', sheep[i])
        
            
    # for i in range(len(wolves)):
    #     wolves[i].eat(proximity, i)
        
    # for i in range(len(wolves)):
    #     sheep_count = -1
    #     for j in sheep[:]:
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # print(f"wolf{i}: {wolves[i].y},{wolves[i].x}, sheep{j}: {sheep[j].y},{sheep[j].x}, d={distance}")
    #         print(f"wolf {i}: {wolves[i].y},{wolves[i].x}, sheep: {sheep_count} {j.y},{j.x}, d={distance}")
    #         if distance < proximity:
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('Sheep eaten', sheep_count, j, 'by Wolf', i)
    #             sheep.remove(j)
    #             break


    
    plt.ylim(0, len(environment))
    plt.xlim(0, len(environment[0])) 
    plt.imshow(environment)
    for i in range(len(sheep)):
        plt.scatter(sheep[i].x, sheep[i].y, marker="p", color='white')
    for j in range(len(wolves)):
        plt.scatter(wolves[j].x, wolves[j].y, marker="v", color='black')
    

def run():
    animation = matplotlib.animation.FuncAnimation(fig, update, frames=gen_function, repeat=False)
    canvas.draw()
   

root = tkinter.Tk()
root.wm_title("Model")
canvas = matplotlib.backends.backend_tkagg.FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
menu_bar = tkinter.Menu(root)
root.config(menu=menu_bar)
model_menu = tkinter.Menu(menu_bar)
menu_bar.add_cascade(label="Model", menu=model_menu)
model_menu.add_command(label="Run model", command=run)

tkinter.mainloop()

# print((((146 - 214)**2) + ((139 - 244)**2))**0.5)

    
    # for i in range(len(wolves)):
    #     print(i, 'Wolf - before moving/eating -', wolves[i])
    #     sheep_count = -1
    #     # print(f"min_dist a = {min_dist}")
    #     closest_sheep = None
    #     min_dist = proximity
    #     eaten = False
    #     for j in sheep[:]:
    #         # print(f"min_dist b = {min_dist}")
    #         sheep_count += 1
    #         distance = af.Animal.dist_animals(wolves[i], j)
    #         # if eat_dist < distance < min_dist:
    #         if distance <= eat_dist:
    #             print('>>> Sheep going to be eaten', sheep_count, j, 'by Wolf', i, wolves[i])
    #             wolves[i].store += j.store
    #             j.store = 0
    #             print('>>> Sheep eaten', sheep_count, j, 'by Wolf', i, wolves[i])
    #             sheep.remove(j)
    #             print('Eaten_________________________________________')
    #             # break # activates else after eating.
    #             # continue # no good. targets immediately another sheep. and activates else.
    #             eaten = True # works. still targets. but does not move. so fine!
    #         elif eat_dist < distance < min_dist:
    #             min_dist = distance
    #             closest_sheep = j
    #             print('>>> min_dist =', min_dist, 'Sheep', sheep_count, j, 'by Wolf', i, wolves[i])
    #             print('M.........................................')
    #     if eaten == True:
    #         #break
    #         continue # This works! it still targets but that's fine as long is it does not move!
    #     elif closest_sheep != None:
    #         print('CS+ before', closest_sheep, 'Wolf', i, wolves[i])
    #         wolves[i].y = (int((wolves[i].y + closest_sheep.y)/2)) % (len(environment))
    #         wolves[i].x = (int((wolves[i].x + closest_sheep.x)/2)) % (len(environment[0]))
    #         print('CS+ after', closest_sheep, 'Wolf', i, wolves[i])
    #         print('Y.........................................')           
    #     else:
    #         print('Else activate before', 'by Wolf', i, wolves[i])
    #         wolves[i].move()
    #         print('Else activate after', 'by Wolf', i, wolves[i])
    #         print('E.........................................')
    # print('Wolf Cycle Ends___________________________________')

    # for i in range(len(wolves)):
    #     print('')
    #     print(f"-> -----------{i}-Wolf initialised with ({wolves[i]}) -----------")
    #     #print(i, 'Wolf - before eating/moving or breeding -', wolves[i])
    #     if wolves[i].store <= 500:
    #         print(f"--> {i}-Wolf has <=500 store ({wolves[i]})")
    #         sheep_count = -1
    #         closest_sheep = None
    #         min_dist = proximity
    #         eaten = False
    #         for j in sheep[:]:
    #             sheep_count += 1
    #             print(f"---> {i}-Wolf looping with {sheep_count}-Sheep")              
    #             distance = af.Animal.dist_animals(wolves[i], j)
    #             # print(f"distance={distance} between {i}-Wolf ({wolves[i]}) and {sheep_count}-Sheep ({j})")
    #             # if eat_dist < distance < min_dist:
    #             if distance <= action_dist:
    #                 print(f"----> d<=action_dist found")
    #                 print(f"----> {i}-Wolf ({wolves[i]}) before eating {sheep_count}-Sheep ({j})")
    #                 wolves[i].store += j.store
    #                 j.store = 0
    #                 print(f"----> {i}-Wolf ({wolves[i]}) after eating {sheep_count}-Sheep ({j})")
    #                 sheep.remove(j)
    #                 eaten = True # works. still targets. but does not move. so fine!
    #                 # break # activates else after eating.
    #                 # continue # no good. targets immediately another sheep. and activates else.
    #             elif action_dist < distance < min_dist:
    #                 print(f"----> action_dist < distance < min_dist")
    #                 min_dist = distance
    #                 closest_sheep = j
    #                 print(f"----> min_dist = {min_dist} for {i}-Wolf ({wolves[i]}) with {sheep_count}-Sheep ({j})")
    #                 print('....elif adm ends. CS+...')
    #         if eaten == True:
    #             #break
    #             print(f"---> ..........eaten==True {i}-Wolf one ate CS..........")
    #             continue # This works! it still targets but that's fine as long is it does not move!
    #         elif closest_sheep != None:
    #             print(f"---> {i}-Wolf ({wolves[i]}) before moving closer to  CS-Sheep ({closest_sheep })")
    #             wolves[i].y = (int((wolves[i].y + closest_sheep.y)/2)) % (len(environment))
    #             wolves[i].x = (int((wolves[i].x + closest_sheep.x)/2)) % (len(environment[0]))
    #             print(f"---> {i}-Wolf ({wolves[i]}) after moving closer to Sheep ({closest_sheep })")
    #             print(f"..........{i}-Wolf moved closer to CS+..........")           
    #         else: #no sheep store <500
    #             print(f"--->else1 begins: {i}-Wolf ({wolves[i]}) before normal moving")
    #             wolves[i].move()
    #             print(f"--->else1 ends: {i}-Wolf ({wolves[i]}) after normal moving")
    #             print(f"....el1......{i}-Wolf moved normally..........")
    #     elif wolves[i].store > 500:
    #         print(f"--> {i}-Wolf has >500 store ({wolves[i]})")
    #         min_breed_dist = proximity
    #         bred = False
    #         closest_wolf = None
    #         for j in range(i+1, len(wolves)):
    #             print(f"---> {i}-Wolf looping with {j}-Wolf")
    #             # Why i+1: to prevent comparison? but what about second wolf?
    #             distance =  af.Animal.dist_animals(wolves[i], wolves[j])
    #             if action_dist < distance < min_breed_dist:
    #                 print('----> CW+ (ad<d<md)')
    #                 min_breed_dist = distance
    #                 closest_wolf = wolves[j]
    #                 print(f"----> min_breed_dist={min_breed_dist} for {i}-Wolf ({wolves[i]}) with CW {j}-Wolf ({wolves[j]})")
    #                 # print('>>> min_breed_dist=', min_breed_dist, 'Wolf', j, wolves[j], 'by Wolf', i, wolves[i])
    #             elif distance <= action_dist:
    #                 print(f"----> d<=ad. breeding/fight distance entered for {i}-Wolf ({wolves[i]}) with CW {j}-Wolf ({wolves[j]}")
    #                 if random.random() < 0.5:
    #                     print(f"-----> Random <0.5")
    #                     print(f"-----> {i}-Wolf ({wolves[i]}) before mating with {j}-Wolf ({wolves[j]})")
    #                     # print('>>> Wolf', j, wolves[j], 'will be mated by Wolf', i, wolves[i])
    #                     print('------> Breed code goes here')
    #                     print(f"-----> {i}-Wolf ({wolves[i]}) after mating with {j}-Wolf ({wolves[j]})")
    #                     print('_____________{i}-Wolf Mated____________')
    #                     # break # activates else after eating.
    #                     # continue # no good. targets immediately another sheep. and activates else.
    #                     bred = True # works. still targets. but does not move. so fine!
    #                 else:
    #                     print(f"-----> Random >0.5")
    #                     print(f"----->Wolf {i} {wolves[i]} does something else with Wolf {j} {wolves[j]}")
    #                     print('----->..........Something else, maybe steal food based on probability..........')
    #                     # Need to add a boolean condition
    #         if bred == True:
    #             #break
    #             print("---> bred==True {i}-Wolf")
    #             continue #( This works! it still targets but that's fine as long is it does not move!)
    #         elif closest_wolf != None:
    #             print(f"---> {i}Wolf ({wolves[i]}) before moving closer to CW-Wolf ({closest_wolf })")
    #             # print('CW+ detected (before)', closest_wolf, 'by Wolf', i, wolves[i])
    #             wolves[i].y = (int((wolves[i].y + closest_wolf.y)/2)) % (len(environment))
    #             wolves[i].x = (int((wolves[i].x + closest_wolf.x)/2)) % (len(environment[0]))
    #             print(f"---> {i}Wolf ({wolves[i]}) after moving closer to CW-Wolf ({closest_wolf })")
    #             # print('CW+ (after)', closest_wolf, 'being approached by Wolf', i, wolves[i])
    #             print('..........{i}-Wolf moved closer CW+..........')   
    #         else: # No wolf. store >700
    #             print(f"--->else2 begins: {i}-Wolf ({wolves[i]}) before normal moving")
    #             # print('Else 2 activate by Wolf', i, wolves[i])
    #             wolves[i].move()
    #             print(f"--->else2 begins: {i}-Wolf ({wolves[i]}) after normal moving")
    #             print(f"....el2...... {i}-Wolf moved normally")
    # print('__________Wolf Cycle Ends___________')
    
    
    
    
    
    
    
    #     elif i.store > 500: # Wolf tries to breed / fight. Can also just write else.
    #         print(f"--> {wolf_count}-Wolf has >500 store ({i})")
    #         min_dist = proximity
    #         # action = False
    #         fight = False
    #         breed = False
    #         closest_wolf = None
    #         wolf2_count = -1
    #         for j in wolves[wolf_index:]: # so that action is not duplicated for same wolf or same pair.
    #             wolf2_count += 1
    #             print(f"---> {wolf_count}-Wolf looping with {wolf2_count}-Wolf")
    #             distance =  af.Animal.dist_animals(i, j)
    #             if action_dist < distance < min_dist: 
    #                 print('----> (AD2 < D < MD).')
    #                 min_dist = distance
    #                 closest_sheep = j
    #                 print(f"----> Min distance={min_dist} for {wolf_count}-Wolf ({i}) with {wolf2_count}-Wolf ({j})")  
    #             elif distance <= action_dist:
    #                 print(f"----> d<=ad. breeding/fight proximity of {distance}(<={action_dist}) entered by {wolf_count}-Wolf ({i}) with CW {wolf2_count}-Wolf ({j}).")
    #                 if j.store > 500:
    #                     print(f"----->{wolf2_count}-Wolf ({j} has MORE than 500 store. So they will either breed or fight. 50% probability each.")
    #                     if random.random() < 0.5: #50% chance of meeting a female!
    #                         print(f"------>1.A. Random <0.5. So the wolves will mate.")
    #                         print(f"------> {wolf_count}-Wolf ({i}) before mating with {wolf2_count}-Wolf ({j})")
    #                         # This works!
    #                         breeding_cost = ((i.store + j.store)/2)/2 # half of average.
    #                         # i.store = average - 200 # 200 is energy for mating.
    #                         # j.store = average - 200 # They will share average energy - 200 energy for mating.
    #                         i.store = breeding_cost
    #                         j.store = breeding_cost
    #                         print(f"------> {wolf_count}-Wolf ({i}) after mating with {wolf2_count}-Wolf ({j})")
    #                         # wolves.append(j) # Added new wolf to the list.
    #                         wolves.append(af.Wolf(animals, wolves, sheep, environment, y=(i.y+10), x=(i.x+10))) # need to add x and y to set the value!
    #                         breed = True
    #                         print(f"Breed = {breed}")
    #                         print(f"_____________{wolf_count}-Wolf Mated with {wolf2_count}-Wolf____________")
    #                         # action = True # works. still targets. but does not move. so fine!
    #                         break # ?activates else after eating.
    #                         #continue # no good. targets immediately another sheep. and activates else.
    #                     else:
    #                         print(f"----->1.B. Random >0.5. So they will fight. 50% probability of winning for both")
    #                         print(f"----->Stat: {wolf_count}-Wolf ({i}) before fighting with {wolf2_count}-Wolf ({j})")
    #                         if random.random() > 0.5:
    #                             print(f"------>1.B.i. Random > 0.5. So {wolf_count}-Wolf will win 50% store of {wolf2_count}-Wolf.")
    #                             gain = (j.store/2)
    #                             print('gain', gain)
    #                             i.store += gain
    #                             print('i.store', i.store)
    #                             j.store -= gain
    #                             print('j.store', j.store)
    #                             print(f"------> {wolf_count}-Wolf ({i}) won after fighting with {wolf2_count}-Wolf ({j})")
    #                         else:
    #                             print(f"------>1.B.ii. Random < 0.5. So {wolf_count}-Wolf ({i}) will loose 50% store to {wolf2_count}-Wolf.")
    #                             lose = (i.store/2)
    #                             print('lose', lose)
    #                             i.store -= lose
    #                             print('i.store', i.store)
    #                             j.store += lose
    #                             print('j.store', j.store)
    #                             print(f"------> {wolf_count}-Wolf ({i}) lost after fighting with {wolf2_count}-Wolf ({j})")
    #                             # action = True
    #                         fight = True
    #                         print(f"Fight 1= {fight}")
    #                         print(f"_____________{wolf_count}-Wolf Fought-(1) with {wolf2_count}-Wolf____________")
    #                         break
    #                 else:
    #                     print(f"----->2.A. {wolf2_count}-Wolf has LESS than 500 store")
    #                     print(f"----->{wolf_count}-Wolf ({i}) and {wolf2_count}-Wolf ({j} will fight")
    #                     # This works! 
    #                     if random.random() > 0.50:
    #                         # print(f"------>2.A.i. Random > 0.25. So {wolf_count}-Wolf will win 75% of {wolf2_count}-Wolf store.")
    #                         print(f"------>2.A.i. Random > 0.50. So {wolf_count}-Wolf will win 50% of {wolf2_count}-Wolf store.")
    #                         gain = (j.store*0.50)
    #                         i.store += gain
    #                         j.store -= gain
    #                         print(f"------> {wolf_count}-Wolf ({i}) won after fighting with {wolf2_count}-Wolf ({j})")
    #                     else:
    #                         # print(f"------>2.A.ii. Random < 0.25. So {wolf_count}-Wolf will loose 25% store to {wolf2_count}-Wolf")
    #                         print(f"------>2.A.ii. Random < 0.50. So {wolf_count}-Wolf will loose 50% store to {wolf2_count}-Wolf")
    #                         lose = (i.store*0.50)
    #                         i.store -= lose
    #                         j.store += lose
    #                         print(f"------> {wolf_count}-Wolf ({i}) lost after fighting with {wolf2_count}-Wolf ({j})")
    #                         # action = True
    #                     fight = True
    #                     print(f"Fight 2 = {fight}")
    #                     print(f"_____________{wolf_count}-Wolf Fought-(2) with {wolf2_count}-Wolf____________")
    #                     break
                        
    #         if breed or fight == True:   
    #             # action = True
    #             print(f"--->_______Mated={breed}, Fought={fight} for {wolf_count}-Wolf__________")
    #             continue
            
    #         # if action == True:
    #         #     #break
    #         #     print(f"---> action={action}, mated={breed}, fough={fight} for {wolf_count}-Wolf............")
    #         #     continue #( This works! it still targets but that's fine as long is it does not move!)
    #         elif closest_wolf != None:
    #             print(f"->CW Found!")
    #             print(f"-> {wolf_count}-Wolf ({i}) before moving closer to CW-Wolf: ({closest_wolf}).")
    #             i.y = (int((i.y + closest_wolf.y)/2))
    #             i.x = (int((i.x + closest_wolf.x)/2))
    #             i.boundary_conditons()
    #             print(f"-> {wolf_count}-Wolf ({i}) after moving closer to CW-Wolf: ({closest_wolf}).")
    #             print(f"..........{wolf_count}-Wolf moved closer CW+..........")   
    #         else: # No wolf. store >700
    #             print(f"--->else2 begins: {wolf_count}-Wolf ({i}) before normal moving.")
    #             i.move()
    #             print(f"--->else2 begins: {wolf_count}-Wolf ({i}) after normal moving.")
    #             print(f"....el2...... {wolf_count}-Wolf moved normally")
    # print('________________Wolf Cycle Ends_________________')
# Out:
# No sheep 10
# No wolves 5
#
# *************** ITERATION NUMBER 0 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# ---> d<md+... 0-Sheep noticed closest 0-Wolf ...
# ---> 0-Sheep (y=73, x=20, store=200) detected 0-Wolf (y=73, x=20, store=400) within d=0.0.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 0-Sheep (y=73, x=20, store=200) tries to run away from CW: (y=73, x=20, store=400).
# -> After 0-Sheep (y=73, x=20, store=200) tried to run away from CW (y=73, x=20, store=400).
# ___________ 0 Sheep tried to run away from CW ___________
#
#
# -> ------------ 1 Sheep initialised -----------
# --> 1-Sheep looping with 0-Wolf.
# --> 1-Sheep looping with 1-Wolf.
# --> 1-Sheep looping with 2-Wolf.
# --> 1-Sheep looping with 3-Wolf.
# --> 1-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->1-Sheep has Store < 600 (y=91, x=52, store=400). will move normally and eat
# -->1-Sheep (y=91, x=52, store=400) before normal moving and eating
# -->1-Sheep (y=92, x=51, store=410) after normal moving and eating
# ___e2________ 1-Sheep moved normally and ate ___________
#
#
# -> ------------ 2 Sheep initialised -----------
# --> 2-Sheep looping with 0-Wolf.
# --> 2-Sheep looping with 1-Wolf.
# --> 2-Sheep looping with 2-Wolf.
# ---> d<md+... 2-Sheep noticed closest 2-Wolf ...
# ---> 2-Sheep (y=52, x=40, store=400) detected 2-Wolf (y=70, x=38, store=200) within d=18.110770276274835.
# --> 2-Sheep looping with 3-Wolf.
# --> 2-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 2-Sheep (y=52, x=40, store=400) tries to run away from CW: (y=70, x=38, store=200).
# -> After 2-Sheep (y=43, x=41, store=400) tried to run away from CW (y=70, x=38, store=200).
# ___________ 2 Sheep tried to run away from CW ___________
#
#
# -> ------------ 3 Sheep initialised -----------
# --> 3-Sheep looping with 0-Wolf.
# ---> d<md+... 3-Sheep noticed closest 0-Wolf ...
# ---> 3-Sheep (y=93, x=14, store=200) detected 0-Wolf (y=73, x=20, store=400) within d=20.8806130178211.
# --> 3-Sheep looping with 1-Wolf.
# --> 3-Sheep looping with 2-Wolf.
# --> 3-Sheep looping with 3-Wolf.
# --> 3-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 3-Sheep (y=93, x=14, store=200) tries to run away from CW: (y=73, x=20, store=400).
# -> After 3-Sheep (y=103, x=11, store=200) tried to run away from CW (y=73, x=20, store=400).
# ___________ 3 Sheep tried to run away from CW ___________
#
#
# -> ------------ 4 Sheep initialised -----------
# --> 4-Sheep looping with 0-Wolf.
# --> 4-Sheep looping with 1-Wolf.
# --> 4-Sheep looping with 2-Wolf.
# ---> d<md+... 4-Sheep noticed closest 2-Wolf ...
# ---> 4-Sheep (y=48, x=35, store=100) detected 2-Wolf (y=70, x=38, store=200) within d=22.20360331117452.
# --> 4-Sheep looping with 3-Wolf.
# --> 4-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 4-Sheep (y=48, x=35, store=100) tries to run away from CW: (y=70, x=38, store=200).
# -> After 4-Sheep (y=37, x=34, store=100) tried to run away from CW (y=70, x=38, store=200).
# ___________ 4 Sheep tried to run away from CW ___________
#
#
# -> ------------ 5 Sheep initialised -----------
# --> 5-Sheep looping with 0-Wolf.
# --> 5-Sheep looping with 1-Wolf.
# --> 5-Sheep looping with 2-Wolf.
# --> 5-Sheep looping with 3-Wolf.
# ---> d<md+... 5-Sheep noticed closest 3-Wolf ...
# ---> 5-Sheep (y=11, x=63, store=400) detected 3-Wolf (y=8, x=52, store=400) within d=11.40175425099138.
# --> 5-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 5-Sheep (y=11, x=63, store=400) tries to run away from CW: (y=8, x=52, store=400).
# -> After 5-Sheep (y=13, x=69, store=400) tried to run away from CW (y=8, x=52, store=400).
# ___________ 5 Sheep tried to run away from CW ___________
#
#
# -> ------------ 6 Sheep initialised -----------
# --> 6-Sheep looping with 0-Wolf.
# --> 6-Sheep looping with 1-Wolf.
# --> 6-Sheep looping with 2-Wolf.
# --> 6-Sheep looping with 3-Wolf.
# --> 6-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->6-Sheep has Store < 600 (y=70, x=63, store=400). will move normally and eat
# -->6-Sheep (y=70, x=63, store=400) before normal moving and eating
# -->6-Sheep (y=69, x=64, store=410) after normal moving and eating
# ___e2________ 6-Sheep moved normally and ate ___________
#
#
# -> ------------ 7 Sheep initialised -----------
# --> 7-Sheep looping with 0-Wolf.
# --> 7-Sheep looping with 1-Wolf.
# --> 7-Sheep looping with 2-Wolf.
# --> 7-Sheep looping with 3-Wolf.
# ---> d<md+... 7-Sheep noticed closest 3-Wolf ...
# ---> 7-Sheep (y=19, x=30, store=400) detected 3-Wolf (y=8, x=52, store=400) within d=24.596747752497688.
# --> 7-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 7-Sheep (y=19, x=30, store=400) tries to run away from CW: (y=8, x=52, store=400).
# -> After 7-Sheep (y=25, x=19, store=400) tried to run away from CW (y=8, x=52, store=400).
# ___________ 7 Sheep tried to run away from CW ___________
#
#
# -> ------------ 8 Sheep initialised -----------
# --> 8-Sheep looping with 0-Wolf.
# --> 8-Sheep looping with 1-Wolf.
# ---> d<md+... 8-Sheep noticed closest 1-Wolf ...
# ---> 8-Sheep (y=42, x=80, store=400) detected 1-Wolf (y=38, x=93, store=100) within d=13.601470508735444.
# --> 8-Sheep looping with 2-Wolf.
# --> 8-Sheep looping with 3-Wolf.
# --> 8-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 8-Sheep (y=42, x=80, store=400) tries to run away from CW: (y=38, x=93, store=100).
# -> After 8-Sheep (y=44, x=74, store=400) tried to run away from CW (y=38, x=93, store=100).
# ___________ 8 Sheep tried to run away from CW ___________
#
#
# -> ------------ 9 Sheep initialised -----------
# --> 9-Sheep looping with 0-Wolf.
# --> 9-Sheep looping with 1-Wolf.
# --> 9-Sheep looping with 2-Wolf.
# --> 9-Sheep looping with 3-Wolf.
# ---> d<md+... 9-Sheep noticed closest 3-Wolf ...
# ---> 9-Sheep (y=20, x=46, store=400) detected 3-Wolf (y=8, x=52, store=400) within d=13.416407864998739.
# --> 9-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 9-Sheep (y=20, x=46, store=400) tries to run away from CW: (y=8, x=52, store=400).
# -> After 9-Sheep (y=26, x=43, store=400) tried to run away from CW (y=8, x=52, store=400).
# ___________ 9 Sheep tried to run away from CW ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=73, x=20, store=400) -----------
# --> 0-Wolf has <=500 store (y=73, x=20, store=400). Tries to find food (sheep).
# ---> 0-Wolf looping with 0-Sheep
# ----> d<=action_dist found
# ----> 0-Wolf (y=73, x=20, store=400) before eating 0-Sheep (y=73, x=20, store=200)
# ----> 0-Wolf (y=73, x=20, store=533.3333333333333) after eating 0-Sheep (y=73, x=20, store=0). Env received (66.66666666666666)
# ---> ___________Eaten=True. 0-Wolf one ate CS 0__________
#
# -> -----------1-Wolf initialised with (y=38, x=93, store=100) -----------
# --> 1-Wolf has <=500 store (y=38, x=93, store=100). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# ---> 1-Wolf looping with 1-Sheep
# ---> 1-Wolf looping with 2-Sheep
# ---> 1-Wolf looping with 3-Sheep
# ---> 1-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 34.655446902326915 for 1-Wolf (y=38, x=93, store=100) with 4-Sheep (y=13, x=69, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 5-Sheep
# ---> 1-Wolf looping with 6-Sheep
# ---> 1-Wolf looping with 7-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 19.924858845171276 for 1-Wolf (y=38, x=93, store=100) with 7-Sheep (y=44, x=74, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 8-Sheep
# -> CS Found!
# --> 1-Wolf (y=38, x=93, store=100) before moving closer to  CS-Sheep (y=44, x=74, store=400)
# --> 1-Wolf (y=41, x=83, store=100) after moving closer to Sheep (y=44, x=74, store=400)
# ___________1-Wolf moved closer to CS+___________
#
# -> -----------2-Wolf initialised with (y=70, x=38, store=200) -----------
# --> 2-Wolf has <=500 store (y=70, x=38, store=200). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 25.553864678361276 for 2-Wolf (y=70, x=38, store=200) with 0-Sheep (y=92, x=51, store=410)
# ....elif adm ends....
# ---> 2-Wolf looping with 1-Sheep
# ---> 2-Wolf looping with 2-Sheep
# ---> 2-Wolf looping with 3-Sheep
# ---> 2-Wolf looping with 4-Sheep
# ---> 2-Wolf looping with 5-Sheep
# ---> 2-Wolf looping with 6-Sheep
# ---> 2-Wolf looping with 7-Sheep
# ---> 2-Wolf looping with 8-Sheep
# -> CS Found!
# --> 2-Wolf (y=70, x=38, store=200) before moving closer to  CS-Sheep (y=92, x=51, store=410)
# --> 2-Wolf (y=81, x=44, store=200) after moving closer to Sheep (y=92, x=51, store=410)
# ___________2-Wolf moved closer to CS+___________
#
# -> -----------3-Wolf initialised with (y=8, x=52, store=400) -----------
# --> 3-Wolf has <=500 store (y=8, x=52, store=400). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# ---> 3-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 36.68787265568828 for 3-Wolf (y=8, x=52, store=400) with 1-Sheep (y=43, x=41, store=400)
# ....elif adm ends....
# ---> 3-Wolf looping with 2-Sheep
# ---> 3-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 34.132096331752024 for 3-Wolf (y=8, x=52, store=400) with 3-Sheep (y=37, x=34, store=100)
# ....elif adm ends....
# ---> 3-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 17.72004514666935 for 3-Wolf (y=8, x=52, store=400) with 4-Sheep (y=13, x=69, store=400)
# ....elif adm ends....
# ---> 3-Wolf looping with 5-Sheep
# ---> 3-Wolf looping with 6-Sheep
# ---> 3-Wolf looping with 7-Sheep
# ---> 3-Wolf looping with 8-Sheep
# -> CS Found!
# --> 3-Wolf (y=8, x=52, store=400) before moving closer to  CS-Sheep (y=13, x=69, store=400)
# --> 3-Wolf (y=10, x=60, store=400) after moving closer to Sheep (y=13, x=69, store=400)
# ___________3-Wolf moved closer to CS+___________
#
# -> -----------4-Wolf initialised with (y=44, x=8, store=200) -----------
# --> 4-Wolf has <=500 store (y=44, x=8, store=200). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# ---> 4-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 33.015148038438355 for 4-Wolf (y=44, x=8, store=200) with 1-Sheep (y=43, x=41, store=400)
# ....elif adm ends....
# ---> 4-Wolf looping with 2-Sheep
# ---> 4-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 26.92582403567252 for 4-Wolf (y=44, x=8, store=200) with 3-Sheep (y=37, x=34, store=100)
# ....elif adm ends....
# ---> 4-Wolf looping with 4-Sheep
# ---> 4-Wolf looping with 5-Sheep
# ---> 4-Wolf looping with 6-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 21.95449840010015 for 4-Wolf (y=44, x=8, store=200) with 6-Sheep (y=25, x=19, store=400)
# ....elif adm ends....
# ---> 4-Wolf looping with 7-Sheep
# ---> 4-Wolf looping with 8-Sheep
# -> CS Found!
# --> 4-Wolf (y=44, x=8, store=200) before moving closer to  CS-Sheep (y=25, x=19, store=400)
# --> 4-Wolf (y=34, x=13, store=200) after moving closer to Sheep (y=25, x=19, store=400)
# ___________4-Wolf moved closer to CS+___________
# ________________Wolf Cycle Ends_________________
# *************** ITERATION NUMBER 1 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# ---> d<md+... 0-Sheep noticed closest 2-Wolf ...
# ---> 0-Sheep (y=92, x=51, store=410) detected 2-Wolf (y=81, x=44, store=200) within d=13.038404810405298.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 0-Sheep (y=92, x=51, store=410) tries to run away from CW: (y=81, x=44, store=200).
# -> After 0-Sheep (y=98, x=55, store=410) tried to run away from CW (y=81, x=44, store=200).
# ___________ 0 Sheep tried to run away from CW ___________
#
#
# -> ------------ 1 Sheep initialised -----------
# --> 1-Sheep looping with 0-Wolf.
# --> 1-Sheep looping with 1-Wolf.
# --> 1-Sheep looping with 2-Wolf.
# --> 1-Sheep looping with 3-Wolf.
# --> 1-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->1-Sheep has Store < 600 (y=43, x=41, store=400). will move normally and eat
# -->1-Sheep (y=43, x=41, store=400) before normal moving and eating
# -->1-Sheep (y=44, x=42, store=410) after normal moving and eating
# ___e2________ 1-Sheep moved normally and ate ___________
#
#
# -> ------------ 2 Sheep initialised -----------
# --> 2-Sheep looping with 0-Wolf.
# --> 2-Sheep looping with 1-Wolf.
# --> 2-Sheep looping with 2-Wolf.
# --> 2-Sheep looping with 3-Wolf.
# --> 2-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->2-Sheep has Store < 600 (y=103, x=11, store=200). will move normally and eat
# -->2-Sheep (y=103, x=11, store=200) before normal moving and eating
# -->2-Sheep (y=104, x=12, store=210) after normal moving and eating
# ___e2________ 2-Sheep moved normally and ate ___________
#
#
# -> ------------ 3 Sheep initialised -----------
# --> 3-Sheep looping with 0-Wolf.
# --> 3-Sheep looping with 1-Wolf.
# --> 3-Sheep looping with 2-Wolf.
# --> 3-Sheep looping with 3-Wolf.
# --> 3-Sheep looping with 4-Wolf.
# ---> d<md+... 3-Sheep noticed closest 4-Wolf ...
# ---> 3-Sheep (y=37, x=34, store=100) detected 4-Wolf (y=34, x=13, store=200) within d=21.213203435596427.
# -> CW FOUND.
# -> Before 3-Sheep (y=37, x=34, store=100) tries to run away from CW: (y=34, x=13, store=200).
# -> After 3-Sheep (y=39, x=45, store=100) tried to run away from CW (y=34, x=13, store=200).
# ___________ 3 Sheep tried to run away from CW ___________
#
#
# -> ------------ 4 Sheep initialised -----------
# --> 4-Sheep looping with 0-Wolf.
# --> 4-Sheep looping with 1-Wolf.
# --> 4-Sheep looping with 2-Wolf.
# --> 4-Sheep looping with 3-Wolf.
# ---> d<md+... 4-Sheep noticed closest 3-Wolf ...
# ---> 4-Sheep (y=13, x=69, store=400) detected 3-Wolf (y=10, x=60, store=400) within d=9.486832980505138.
# --> 4-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 4-Sheep (y=13, x=69, store=400) tries to run away from CW: (y=10, x=60, store=400).
# -> After 4-Sheep (y=15, x=74, store=400) tried to run away from CW (y=10, x=60, store=400).
# ___________ 4 Sheep tried to run away from CW ___________
#
#
# -> ------------ 5 Sheep initialised -----------
# --> 5-Sheep looping with 0-Wolf.
# --> 5-Sheep looping with 1-Wolf.
# --> 5-Sheep looping with 2-Wolf.
# ---> d<md+... 5-Sheep noticed closest 2-Wolf ...
# ---> 5-Sheep (y=69, x=64, store=410) detected 2-Wolf (y=81, x=44, store=200) within d=23.323807579381203.
# --> 5-Sheep looping with 3-Wolf.
# --> 5-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 5-Sheep (y=69, x=64, store=410) tries to run away from CW: (y=81, x=44, store=200).
# -> After 5-Sheep (y=63, x=74, store=410) tried to run away from CW (y=81, x=44, store=200).
# ___________ 5 Sheep tried to run away from CW ___________
#
#
# -> ------------ 6 Sheep initialised -----------
# --> 6-Sheep looping with 0-Wolf.
# --> 6-Sheep looping with 1-Wolf.
# --> 6-Sheep looping with 2-Wolf.
# --> 6-Sheep looping with 3-Wolf.
# --> 6-Sheep looping with 4-Wolf.
# ---> d<md+... 6-Sheep noticed closest 4-Wolf ...
# ---> 6-Sheep (y=25, x=19, store=400) detected 4-Wolf (y=34, x=13, store=200) within d=10.816653826391969.
# -> CW FOUND.
# -> Before 6-Sheep (y=25, x=19, store=400) tries to run away from CW: (y=34, x=13, store=200).
# -> After 6-Sheep (y=21, x=22, store=400) tried to run away from CW (y=34, x=13, store=200).
# ___________ 6 Sheep tried to run away from CW ___________
#
#
# -> ------------ 7 Sheep initialised -----------
# --> 7-Sheep looping with 0-Wolf.
# --> 7-Sheep looping with 1-Wolf.
# ---> d<md+... 7-Sheep noticed closest 1-Wolf ...
# ---> 7-Sheep (y=44, x=74, store=400) detected 1-Wolf (y=41, x=83, store=100) within d=9.486832980505138.
# --> 7-Sheep looping with 2-Wolf.
# --> 7-Sheep looping with 3-Wolf.
# --> 7-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 7-Sheep (y=44, x=74, store=400) tries to run away from CW: (y=41, x=83, store=100).
# -> After 7-Sheep (y=46, x=70, store=400) tried to run away from CW (y=41, x=83, store=100).
# ___________ 7 Sheep tried to run away from CW ___________
#
#
# -> ------------ 8 Sheep initialised -----------
# --> 8-Sheep looping with 0-Wolf.
# --> 8-Sheep looping with 1-Wolf.
# --> 8-Sheep looping with 2-Wolf.
# --> 8-Sheep looping with 3-Wolf.
# ---> d<md+... 8-Sheep noticed closest 3-Wolf ...
# ---> 8-Sheep (y=26, x=43, store=400) detected 3-Wolf (y=10, x=60, store=400) within d=23.345235059857504.
# --> 8-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 8-Sheep (y=26, x=43, store=400) tries to run away from CW: (y=10, x=60, store=400).
# -> After 8-Sheep (y=34, x=35, store=400) tried to run away from CW (y=10, x=60, store=400).
# ___________ 8 Sheep tried to run away from CW ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=73, x=20, store=533.3333333333333) -----------
# --> 0-Wolf has > 500 store (y=73, x=20, store=533.3333333333333) and p > 0.5. so will try to find CW to move closer or breed/fight.
# ---> 0-Wolf looping with 0-Wolf
# ---> 0-Wolf looping with 1-Wolf
# ----> (AD2 < D < MD).
# ----> Min distance=25.298221281347036 for 0-Wolf (y=73, x=20, store=533.3333333333333) with 1-Wolf (y=81, x=44, store=200)
# ---> 0-Wolf looping with 2-Wolf
# ---> 0-Wolf looping with 3-Wolf
# ->CW Found!
# -> 0-Wolf (y=73, x=20, store=533.3333333333333) before moving closer to CW-Wolf: (y=81, x=44, store=200).
# -> 0-Wolf (y=77, x=32, store=533.3333333333333) after moving closer to CW-Wolf: (y=81, x=44, store=200).
# ..........0-Wolf moved closer CW+..........
#
# -> -----------1-Wolf initialised with (y=41, x=83, store=100) -----------
# --> 1-Wolf has <=500 store (y=41, x=83, store=100). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# ---> 1-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 41.10960958218893 for 1-Wolf (y=41, x=83, store=100) with 1-Sheep (y=44, x=42, store=410)
# ....elif adm ends....
# ---> 1-Wolf looping with 2-Sheep
# ---> 1-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 38.05259518088089 for 1-Wolf (y=41, x=83, store=100) with 3-Sheep (y=39, x=45, store=100)
# ....elif adm ends....
# ---> 1-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 27.51363298439521 for 1-Wolf (y=41, x=83, store=100) with 4-Sheep (y=15, x=74, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 5-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 23.769728648009426 for 1-Wolf (y=41, x=83, store=100) with 5-Sheep (y=63, x=74, store=410)
# ....elif adm ends....
# ---> 1-Wolf looping with 6-Sheep
# ---> 1-Wolf looping with 7-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 13.92838827718412 for 1-Wolf (y=41, x=83, store=100) with 7-Sheep (y=46, x=70, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 8-Sheep
# -> CS Found!
# --> 1-Wolf (y=41, x=83, store=100) before moving closer to  CS-Sheep (y=46, x=70, store=400)
# --> 1-Wolf (y=43, x=76, store=100) after moving closer to Sheep (y=46, x=70, store=400)
# ___________1-Wolf moved closer to CS+___________
#
# -> -----------2-Wolf initialised with (y=81, x=44, store=200) -----------
# --> 2-Wolf has <=500 store (y=81, x=44, store=200). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 20.248456731316587 for 2-Wolf (y=81, x=44, store=200) with 0-Sheep (y=98, x=55, store=410)
# ....elif adm ends....
# ---> 2-Wolf looping with 1-Sheep
# ---> 2-Wolf looping with 2-Sheep
# ---> 2-Wolf looping with 3-Sheep
# ---> 2-Wolf looping with 4-Sheep
# ---> 2-Wolf looping with 5-Sheep
# ---> 2-Wolf looping with 6-Sheep
# ---> 2-Wolf looping with 7-Sheep
# ---> 2-Wolf looping with 8-Sheep
# -> CS Found!
# --> 2-Wolf (y=81, x=44, store=200) before moving closer to  CS-Sheep (y=98, x=55, store=410)
# --> 2-Wolf (y=89, x=49, store=200) after moving closer to Sheep (y=98, x=55, store=410)
# ___________2-Wolf moved closer to CS+___________
#
# -> -----------3-Wolf initialised with (y=10, x=60, store=400) -----------
# --> 3-Wolf has <=500 store (y=10, x=60, store=400). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# ---> 3-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 38.47076812334269 for 3-Wolf (y=10, x=60, store=400) with 1-Sheep (y=44, x=42, store=410)
# ....elif adm ends....
# ---> 3-Wolf looping with 2-Sheep
# ---> 3-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 32.64965543462902 for 3-Wolf (y=10, x=60, store=400) with 3-Sheep (y=39, x=45, store=100)
# ....elif adm ends....
# ---> 3-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 14.866068747318506 for 3-Wolf (y=10, x=60, store=400) with 4-Sheep (y=15, x=74, store=400)
# ....elif adm ends....
# ---> 3-Wolf looping with 5-Sheep
# ---> 3-Wolf looping with 6-Sheep
# ---> 3-Wolf looping with 7-Sheep
# ---> 3-Wolf looping with 8-Sheep
# -> CS Found!
# --> 3-Wolf (y=10, x=60, store=400) before moving closer to  CS-Sheep (y=15, x=74, store=400)
# --> 3-Wolf (y=12, x=67, store=400) after moving closer to Sheep (y=15, x=74, store=400)
# ___________3-Wolf moved closer to CS+___________
#
# -> -----------4-Wolf initialised with (y=34, x=13, store=200) -----------
# --> 4-Wolf has <=500 store (y=34, x=13, store=200). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# ---> 4-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 30.675723300355934 for 4-Wolf (y=34, x=13, store=200) with 1-Sheep (y=44, x=42, store=410)
# ....elif adm ends....
# ---> 4-Wolf looping with 2-Sheep
# ---> 4-Wolf looping with 3-Sheep
# ---> 4-Wolf looping with 4-Sheep
# ---> 4-Wolf looping with 5-Sheep
# ---> 4-Wolf looping with 6-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 15.811388300841896 for 4-Wolf (y=34, x=13, store=200) with 6-Sheep (y=21, x=22, store=400)
# ....elif adm ends....
# ---> 4-Wolf looping with 7-Sheep
# ---> 4-Wolf looping with 8-Sheep
# -> CS Found!
# --> 4-Wolf (y=34, x=13, store=200) before moving closer to  CS-Sheep (y=21, x=22, store=400)
# --> 4-Wolf (y=27, x=17, store=200) after moving closer to Sheep (y=21, x=22, store=400)
# ___________4-Wolf moved closer to CS+___________
# ________________Wolf Cycle Ends_________________
# *************** ITERATION NUMBER 2 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# ---> d<md+... 0-Sheep noticed closest 2-Wolf ...
# ---> 0-Sheep (y=98, x=55, store=410) detected 2-Wolf (y=89, x=49, store=200) within d=10.816653826391969.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 0-Sheep (y=98, x=55, store=410) tries to run away from CW: (y=89, x=49, store=200).
# -> After 0-Sheep (y=103, x=58, store=410) tried to run away from CW (y=89, x=49, store=200).
# ___________ 0 Sheep tried to run away from CW ___________
#
#
# -> ------------ 1 Sheep initialised -----------
# --> 1-Sheep looping with 0-Wolf.
# --> 1-Sheep looping with 1-Wolf.
# --> 1-Sheep looping with 2-Wolf.
# --> 1-Sheep looping with 3-Wolf.
# --> 1-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->1-Sheep has Store < 600 (y=44, x=42, store=410). will move normally and eat
# -->1-Sheep (y=44, x=42, store=410) before normal moving and eating
# -->1-Sheep (y=43, x=41, store=420) after normal moving and eating
# ___e2________ 1-Sheep moved normally and ate ___________
#
#
# -> ------------ 2 Sheep initialised -----------
# --> 2-Sheep looping with 0-Wolf.
# --> 2-Sheep looping with 1-Wolf.
# --> 2-Sheep looping with 2-Wolf.
# --> 2-Sheep looping with 3-Wolf.
# --> 2-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->2-Sheep has Store < 600 (y=104, x=12, store=210). will move normally and eat
# -->2-Sheep (y=104, x=12, store=210) before normal moving and eating
# -->2-Sheep (y=103, x=13, store=220) after normal moving and eating
# ___e2________ 2-Sheep moved normally and ate ___________
#
#
# -> ------------ 3 Sheep initialised -----------
# --> 3-Sheep looping with 0-Wolf.
# --> 3-Sheep looping with 1-Wolf.
# --> 3-Sheep looping with 2-Wolf.
# --> 3-Sheep looping with 3-Wolf.
# --> 3-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->3-Sheep has Store < 600 (y=39, x=45, store=100). will move normally and eat
# -->3-Sheep (y=39, x=45, store=100) before normal moving and eating
# -->3-Sheep (y=38, x=46, store=110) after normal moving and eating
# ___e2________ 3-Sheep moved normally and ate ___________
#
#
# -> ------------ 4 Sheep initialised -----------
# --> 4-Sheep looping with 0-Wolf.
# --> 4-Sheep looping with 1-Wolf.
# --> 4-Sheep looping with 2-Wolf.
# --> 4-Sheep looping with 3-Wolf.
# ---> d<md+... 4-Sheep noticed closest 3-Wolf ...
# ---> 4-Sheep (y=15, x=74, store=400) detected 3-Wolf (y=12, x=67, store=400) within d=7.615773105863909.
# --> 4-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 4-Sheep (y=15, x=74, store=400) tries to run away from CW: (y=12, x=67, store=400).
# -> After 4-Sheep (y=17, x=78, store=400) tried to run away from CW (y=12, x=67, store=400).
# ___________ 4 Sheep tried to run away from CW ___________
#
#
# -> ------------ 5 Sheep initialised -----------
# --> 5-Sheep looping with 0-Wolf.
# --> 5-Sheep looping with 1-Wolf.
# ---> d<md+... 5-Sheep noticed closest 1-Wolf ...
# ---> 5-Sheep (y=63, x=74, store=410) detected 1-Wolf (y=43, x=76, store=100) within d=20.09975124224178.
# --> 5-Sheep looping with 2-Wolf.
# --> 5-Sheep looping with 3-Wolf.
# --> 5-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 5-Sheep (y=63, x=74, store=410) tries to run away from CW: (y=43, x=76, store=100).
# -> After 5-Sheep (y=73, x=73, store=410) tried to run away from CW (y=43, x=76, store=100).
# ___________ 5 Sheep tried to run away from CW ___________
#
#
# -> ------------ 6 Sheep initialised -----------
# --> 6-Sheep looping with 0-Wolf.
# --> 6-Sheep looping with 1-Wolf.
# --> 6-Sheep looping with 2-Wolf.
# --> 6-Sheep looping with 3-Wolf.
# --> 6-Sheep looping with 4-Wolf.
# ---> d<md+... 6-Sheep noticed closest 4-Wolf ...
# ---> 6-Sheep (y=21, x=22, store=400) detected 4-Wolf (y=27, x=17, store=200) within d=7.810249675906654.
# -> CW FOUND.
# -> Before 6-Sheep (y=21, x=22, store=400) tries to run away from CW: (y=27, x=17, store=200).
# -> After 6-Sheep (y=18, x=25, store=400) tried to run away from CW (y=27, x=17, store=200).
# ___________ 6 Sheep tried to run away from CW ___________
#
#
# -> ------------ 7 Sheep initialised -----------
# --> 7-Sheep looping with 0-Wolf.
# --> 7-Sheep looping with 1-Wolf.
# ---> d<md+... 7-Sheep noticed closest 1-Wolf ...
# ---> 7-Sheep (y=46, x=70, store=400) detected 1-Wolf (y=43, x=76, store=100) within d=6.708203932499369.
# --> 7-Sheep looping with 2-Wolf.
# --> 7-Sheep looping with 3-Wolf.
# --> 7-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 7-Sheep (y=46, x=70, store=400) tries to run away from CW: (y=43, x=76, store=100).
# -> After 7-Sheep (y=48, x=67, store=400) tried to run away from CW (y=43, x=76, store=100).
# ___________ 7 Sheep tried to run away from CW ___________
#
#
# -> ------------ 8 Sheep initialised -----------
# --> 8-Sheep looping with 0-Wolf.
# --> 8-Sheep looping with 1-Wolf.
# --> 8-Sheep looping with 2-Wolf.
# --> 8-Sheep looping with 3-Wolf.
# --> 8-Sheep looping with 4-Wolf.
# ---> d<md+... 8-Sheep noticed closest 4-Wolf ...
# ---> 8-Sheep (y=34, x=35, store=400) detected 4-Wolf (y=27, x=17, store=200) within d=19.313207915827967.
# -> CW FOUND.
# -> Before 8-Sheep (y=34, x=35, store=400) tries to run away from CW: (y=27, x=17, store=200).
# -> After 8-Sheep (y=38, x=44, store=400) tried to run away from CW (y=27, x=17, store=200).
# ___________ 8 Sheep tried to run away from CW ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=77, x=32, store=533.3333333333333) -----------
# --> 0-Wolf has > 500 store (y=77, x=32, store=533.3333333333333) and p > 0.5. so will try to find CW to move closer or breed/fight.
# ---> 0-Wolf looping with 0-Wolf
# ---> 0-Wolf looping with 1-Wolf
# ----> (AD2 < D < MD).
# ----> Min distance=20.808652046684813 for 0-Wolf (y=77, x=32, store=533.3333333333333) with 1-Wolf (y=89, x=49, store=200)
# ---> 0-Wolf looping with 2-Wolf
# ---> 0-Wolf looping with 3-Wolf
# ->CW Found!
# -> 0-Wolf (y=77, x=32, store=533.3333333333333) before moving closer to CW-Wolf: (y=89, x=49, store=200).
# -> 0-Wolf (y=83, x=40, store=533.3333333333333) after moving closer to CW-Wolf: (y=89, x=49, store=200).
# ..........0-Wolf moved closer CW+..........
#
# -> -----------1-Wolf initialised with (y=43, x=76, store=100) -----------
# --> 1-Wolf has <=500 store (y=43, x=76, store=100). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# ---> 1-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 35.0 for 1-Wolf (y=43, x=76, store=100) with 1-Sheep (y=43, x=41, store=420)
# ....elif adm ends....
# ---> 1-Wolf looping with 2-Sheep
# ---> 1-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 30.4138126514911 for 1-Wolf (y=43, x=76, store=100) with 3-Sheep (y=38, x=46, store=110)
# ....elif adm ends....
# ---> 1-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 26.076809620810597 for 1-Wolf (y=43, x=76, store=100) with 4-Sheep (y=17, x=78, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 5-Sheep
# ---> 1-Wolf looping with 6-Sheep
# ---> 1-Wolf looping with 7-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 10.295630140987 for 1-Wolf (y=43, x=76, store=100) with 7-Sheep (y=48, x=67, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 8-Sheep
# -> CS Found!
# --> 1-Wolf (y=43, x=76, store=100) before moving closer to  CS-Sheep (y=48, x=67, store=400)
# --> 1-Wolf (y=45, x=71, store=100) after moving closer to Sheep (y=48, x=67, store=400)
# ___________1-Wolf moved closer to CS+___________
#
# -> -----------2-Wolf initialised with (y=89, x=49, store=200) -----------
# --> 2-Wolf has <=500 store (y=89, x=49, store=200). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 16.64331697709324 for 2-Wolf (y=89, x=49, store=200) with 0-Sheep (y=103, x=58, store=410)
# ....elif adm ends....
# ---> 2-Wolf looping with 1-Sheep
# ---> 2-Wolf looping with 2-Sheep
# ---> 2-Wolf looping with 3-Sheep
# ---> 2-Wolf looping with 4-Sheep
# ---> 2-Wolf looping with 5-Sheep
# ---> 2-Wolf looping with 6-Sheep
# ---> 2-Wolf looping with 7-Sheep
# ---> 2-Wolf looping with 8-Sheep
# -> CS Found!
# --> 2-Wolf (y=89, x=49, store=200) before moving closer to  CS-Sheep (y=103, x=58, store=410)
# --> 2-Wolf (y=96, x=53, store=200) after moving closer to Sheep (y=103, x=58, store=410)
# ___________2-Wolf moved closer to CS+___________
#
# -> -----------3-Wolf initialised with (y=12, x=67, store=400) -----------
# --> 3-Wolf has <=500 store (y=12, x=67, store=400). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# ---> 3-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 40.45985664828782 for 3-Wolf (y=12, x=67, store=400) with 1-Sheep (y=43, x=41, store=420)
# ....elif adm ends....
# ---> 3-Wolf looping with 2-Sheep
# ---> 3-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 33.421549934136806 for 3-Wolf (y=12, x=67, store=400) with 3-Sheep (y=38, x=46, store=110)
# ....elif adm ends....
# ---> 3-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 12.083045973594572 for 3-Wolf (y=12, x=67, store=400) with 4-Sheep (y=17, x=78, store=400)
# ....elif adm ends....
# ---> 3-Wolf looping with 5-Sheep
# ---> 3-Wolf looping with 6-Sheep
# ---> 3-Wolf looping with 7-Sheep
# ---> 3-Wolf looping with 8-Sheep
# -> CS Found!
# --> 3-Wolf (y=12, x=67, store=400) before moving closer to  CS-Sheep (y=17, x=78, store=400)
# --> 3-Wolf (y=14, x=72, store=400) after moving closer to Sheep (y=17, x=78, store=400)
# ___________3-Wolf moved closer to CS+___________
#
# -> -----------4-Wolf initialised with (y=27, x=17, store=200) -----------
# --> 4-Wolf has <=500 store (y=27, x=17, store=200). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# ---> 4-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 28.844410203711913 for 4-Wolf (y=27, x=17, store=200) with 1-Sheep (y=43, x=41, store=420)
# ....elif adm ends....
# ---> 4-Wolf looping with 2-Sheep
# ---> 4-Wolf looping with 3-Sheep
# ---> 4-Wolf looping with 4-Sheep
# ---> 4-Wolf looping with 5-Sheep
# ---> 4-Wolf looping with 6-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 12.041594578792296 for 4-Wolf (y=27, x=17, store=200) with 6-Sheep (y=18, x=25, store=400)
# ....elif adm ends....
# ---> 4-Wolf looping with 7-Sheep
# ---> 4-Wolf looping with 8-Sheep
# -> CS Found!
# --> 4-Wolf (y=27, x=17, store=200) before moving closer to  CS-Sheep (y=18, x=25, store=400)
# --> 4-Wolf (y=22, x=21, store=200) after moving closer to Sheep (y=18, x=25, store=400)
# ___________4-Wolf moved closer to CS+___________
# ________________Wolf Cycle Ends_________________
# *************** ITERATION NUMBER 3 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# ---> d<md+... 0-Sheep noticed closest 2-Wolf ...
# ---> 0-Sheep (y=103, x=58, store=410) detected 2-Wolf (y=96, x=53, store=200) within d=8.602325267042627.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 0-Sheep (y=103, x=58, store=410) tries to run away from CW: (y=96, x=53, store=200).
# -> After 0-Sheep (y=107, x=61, store=410) tried to run away from CW (y=96, x=53, store=200).
# ___________ 0 Sheep tried to run away from CW ___________
#
#
# -> ------------ 1 Sheep initialised -----------
# --> 1-Sheep looping with 0-Wolf.
# --> 1-Sheep looping with 1-Wolf.
# --> 1-Sheep looping with 2-Wolf.
# --> 1-Sheep looping with 3-Wolf.
# --> 1-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->1-Sheep has Store < 600 (y=43, x=41, store=420). will move normally and eat
# -->1-Sheep (y=43, x=41, store=420) before normal moving and eating
# -->1-Sheep (y=44, x=40, store=430) after normal moving and eating
# ___e2________ 1-Sheep moved normally and ate ___________
#
#
# -> ------------ 2 Sheep initialised -----------
# --> 2-Sheep looping with 0-Wolf.
# --> 2-Sheep looping with 1-Wolf.
# --> 2-Sheep looping with 2-Wolf.
# --> 2-Sheep looping with 3-Wolf.
# --> 2-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->2-Sheep has Store < 600 (y=103, x=13, store=220). will move normally and eat
# -->2-Sheep (y=103, x=13, store=220) before normal moving and eating
# -->2-Sheep (y=104, x=14, store=230) after normal moving and eating
# ___e2________ 2-Sheep moved normally and ate ___________
#
#
# -> ------------ 3 Sheep initialised -----------
# --> 3-Sheep looping with 0-Wolf.
# --> 3-Sheep looping with 1-Wolf.
# --> 3-Sheep looping with 2-Wolf.
# --> 3-Sheep looping with 3-Wolf.
# --> 3-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->3-Sheep has Store < 600 (y=38, x=46, store=110). will move normally and eat
# -->3-Sheep (y=38, x=46, store=110) before normal moving and eating
# -->3-Sheep (y=37, x=45, store=120) after normal moving and eating
# ___e2________ 3-Sheep moved normally and ate ___________
#
#
# -> ------------ 4 Sheep initialised -----------
# --> 4-Sheep looping with 0-Wolf.
# --> 4-Sheep looping with 1-Wolf.
# --> 4-Sheep looping with 2-Wolf.
# --> 4-Sheep looping with 3-Wolf.
# ---> d<md+... 4-Sheep noticed closest 3-Wolf ...
# ---> 4-Sheep (y=17, x=78, store=400) detected 3-Wolf (y=14, x=72, store=400) within d=6.708203932499369.
# --> 4-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 4-Sheep (y=17, x=78, store=400) tries to run away from CW: (y=14, x=72, store=400).
# -> After 4-Sheep (y=19, x=81, store=400) tried to run away from CW (y=14, x=72, store=400).
# ___________ 4 Sheep tried to run away from CW ___________
#
#
# -> ------------ 5 Sheep initialised -----------
# --> 5-Sheep looping with 0-Wolf.
# --> 5-Sheep looping with 1-Wolf.
# --> 5-Sheep looping with 2-Wolf.
# --> 5-Sheep looping with 3-Wolf.
# --> 5-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->5-Sheep has Store < 600 (y=73, x=73, store=410). will move normally and eat
# -->5-Sheep (y=73, x=73, store=410) before normal moving and eating
# -->5-Sheep (y=74, x=74, store=420) after normal moving and eating
# ___e2________ 5-Sheep moved normally and ate ___________
#
#
# -> ------------ 6 Sheep initialised -----------
# --> 6-Sheep looping with 0-Wolf.
# --> 6-Sheep looping with 1-Wolf.
# --> 6-Sheep looping with 2-Wolf.
# --> 6-Sheep looping with 3-Wolf.
# --> 6-Sheep looping with 4-Wolf.
# ---> d<md+... 6-Sheep noticed closest 4-Wolf ...
# ---> 6-Sheep (y=18, x=25, store=400) detected 4-Wolf (y=22, x=21, store=200) within d=5.656854249492381.
# -> CW FOUND.
# -> Before 6-Sheep (y=18, x=25, store=400) tries to run away from CW: (y=22, x=21, store=200).
# -> After 6-Sheep (y=16, x=27, store=400) tried to run away from CW (y=22, x=21, store=200).
# ___________ 6 Sheep tried to run away from CW ___________
#
#
# -> ------------ 7 Sheep initialised -----------
# --> 7-Sheep looping with 0-Wolf.
# --> 7-Sheep looping with 1-Wolf.
# ---> d<md+... 7-Sheep noticed closest 1-Wolf ...
# ---> 7-Sheep (y=48, x=67, store=400) detected 1-Wolf (y=45, x=71, store=100) within d=5.0.
# --> 7-Sheep looping with 2-Wolf.
# --> 7-Sheep looping with 3-Wolf.
# --> 7-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 7-Sheep (y=48, x=67, store=400) tries to run away from CW: (y=45, x=71, store=100).
# -> After 7-Sheep (y=50, x=65, store=400) tried to run away from CW (y=45, x=71, store=100).
# ___________ 7 Sheep tried to run away from CW ___________
#
#
# -> ------------ 8 Sheep initialised -----------
# --> 8-Sheep looping with 0-Wolf.
# --> 8-Sheep looping with 1-Wolf.
# --> 8-Sheep looping with 2-Wolf.
# --> 8-Sheep looping with 3-Wolf.
# --> 8-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->8-Sheep has Store < 600 (y=38, x=44, store=400). will move normally and eat
# -->8-Sheep (y=38, x=44, store=400) before normal moving and eating
# -->8-Sheep (y=39, x=45, store=410) after normal moving and eating
# ___e2________ 8-Sheep moved normally and ate ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=83, x=40, store=533.3333333333333) -----------
# --> 0-Wolf has > 500 store (y=83, x=40, store=533.3333333333333) and p > 0.5. so will try to find CW to move closer or breed/fight.
# ---> 0-Wolf looping with 0-Wolf
# ----> (AD2 < D < MD).
# ----> Min distance=49.040799340956916 for 0-Wolf (y=83, x=40, store=533.3333333333333) with 0-Wolf (y=45, x=71, store=100)
# ---> 0-Wolf looping with 1-Wolf
# ----> (AD2 < D < MD).
# ----> Min distance=18.384776310850235 for 0-Wolf (y=83, x=40, store=533.3333333333333) with 1-Wolf (y=96, x=53, store=200)
# ---> 0-Wolf looping with 2-Wolf
# ---> 0-Wolf looping with 3-Wolf
# ->CW Found!
# -> 0-Wolf (y=83, x=40, store=533.3333333333333) before moving closer to CW-Wolf: (y=96, x=53, store=200).
# -> 0-Wolf (y=89, x=46, store=533.3333333333333) after moving closer to CW-Wolf: (y=96, x=53, store=200).
# ..........0-Wolf moved closer CW+..........
#
# -> -----------1-Wolf initialised with (y=45, x=71, store=100) -----------
# --> 1-Wolf has <=500 store (y=45, x=71, store=100). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# ---> 1-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 31.016124838541646 for 1-Wolf (y=45, x=71, store=100) with 1-Sheep (y=44, x=40, store=430)
# ....elif adm ends....
# ---> 1-Wolf looping with 2-Sheep
# ---> 1-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 27.202941017470888 for 1-Wolf (y=45, x=71, store=100) with 3-Sheep (y=37, x=45, store=120)
# ....elif adm ends....
# ---> 1-Wolf looping with 4-Sheep
# ---> 1-Wolf looping with 5-Sheep
# ---> 1-Wolf looping with 6-Sheep
# ---> 1-Wolf looping with 7-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 7.810249675906654 for 1-Wolf (y=45, x=71, store=100) with 7-Sheep (y=50, x=65, store=400)
# ....elif adm ends....
# ---> 1-Wolf looping with 8-Sheep
# -> CS Found!
# --> 1-Wolf (y=45, x=71, store=100) before moving closer to  CS-Sheep (y=50, x=65, store=400)
# --> 1-Wolf (y=47, x=68, store=100) after moving closer to Sheep (y=50, x=65, store=400)
# ___________1-Wolf moved closer to CS+___________
#
# -> -----------2-Wolf initialised with (y=96, x=53, store=200) -----------
# --> 2-Wolf has <=500 store (y=96, x=53, store=200). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 13.601470508735444 for 2-Wolf (y=96, x=53, store=200) with 0-Sheep (y=107, x=61, store=410)
# ....elif adm ends....
# ---> 2-Wolf looping with 1-Sheep
# ---> 2-Wolf looping with 2-Sheep
# ---> 2-Wolf looping with 3-Sheep
# ---> 2-Wolf looping with 4-Sheep
# ---> 2-Wolf looping with 5-Sheep
# ---> 2-Wolf looping with 6-Sheep
# ---> 2-Wolf looping with 7-Sheep
# ---> 2-Wolf looping with 8-Sheep
# -> CS Found!
# --> 2-Wolf (y=96, x=53, store=200) before moving closer to  CS-Sheep (y=107, x=61, store=410)
# --> 2-Wolf (y=101, x=57, store=200) after moving closer to Sheep (y=107, x=61, store=410)
# ___________2-Wolf moved closer to CS+___________
#
# -> -----------3-Wolf initialised with (y=14, x=72, store=400) -----------
# --> 3-Wolf has <=500 store (y=14, x=72, store=400). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# ---> 3-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 43.86342439892262 for 3-Wolf (y=14, x=72, store=400) with 1-Sheep (y=44, x=40, store=430)
# ....elif adm ends....
# ---> 3-Wolf looping with 2-Sheep
# ---> 3-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 35.4682957019364 for 3-Wolf (y=14, x=72, store=400) with 3-Sheep (y=37, x=45, store=120)
# ....elif adm ends....
# ---> 3-Wolf looping with 4-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 10.295630140987 for 3-Wolf (y=14, x=72, store=400) with 4-Sheep (y=19, x=81, store=400)
# ....elif adm ends....
# ---> 3-Wolf looping with 5-Sheep
# ---> 3-Wolf looping with 6-Sheep
# ---> 3-Wolf looping with 7-Sheep
# ---> 3-Wolf looping with 8-Sheep
# -> CS Found!
# --> 3-Wolf (y=14, x=72, store=400) before moving closer to  CS-Sheep (y=19, x=81, store=400)
# --> 3-Wolf (y=16, x=76, store=400) after moving closer to Sheep (y=19, x=81, store=400)
# ___________3-Wolf moved closer to CS+___________
#
# -> -----------4-Wolf initialised with (y=22, x=21, store=200) -----------
# --> 4-Wolf has <=500 store (y=22, x=21, store=200). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# ---> 4-Wolf looping with 1-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 29.068883707497267 for 4-Wolf (y=22, x=21, store=200) with 1-Sheep (y=44, x=40, store=430)
# ....elif adm ends....
# ---> 4-Wolf looping with 2-Sheep
# ---> 4-Wolf looping with 3-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 28.30194339616981 for 4-Wolf (y=22, x=21, store=200) with 3-Sheep (y=37, x=45, store=120)
# ....elif adm ends....
# ---> 4-Wolf looping with 4-Sheep
# ---> 4-Wolf looping with 5-Sheep
# ---> 4-Wolf looping with 6-Sheep
# ----> action_dist < distance < min_dist
# ----> Min Distance = 8.48528137423857 for 4-Wolf (y=22, x=21, store=200) with 6-Sheep (y=16, x=27, store=400)
# ....elif adm ends....
# ---> 4-Wolf looping with 7-Sheep
# ---> 4-Wolf looping with 8-Sheep
# -> CS Found!
# --> 4-Wolf (y=22, x=21, store=200) before moving closer to  CS-Sheep (y=16, x=27, store=400)
# --> 4-Wolf (y=19, x=24, store=200) after moving closer to Sheep (y=16, x=27, store=400)
# ___________4-Wolf moved closer to CS+___________
# ________________Wolf Cycle Ends_________________
# *************** ITERATION NUMBER 4 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# ---> d<md+... 0-Sheep noticed closest 0-Wolf ...
# ---> 0-Sheep (y=107, x=61, store=410) detected 0-Wolf (y=89, x=46, store=533.3333333333333) within d=23.430749027719962.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# ---> d<md+... 0-Sheep noticed closest 2-Wolf ...
# ---> 0-Sheep (y=107, x=61, store=410) detected 2-Wolf (y=101, x=57, store=200) within d=7.211102550927978.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 0-Sheep (y=107, x=61, store=410) tries to run away from CW: (y=101, x=57, store=200).
# -> After 0-Sheep (y=110, x=63, store=410) tried to run away from CW (y=101, x=57, store=200).
# ___________ 0 Sheep tried to run away from CW ___________
#
#
# -> ------------ 1 Sheep initialised -----------
# --> 1-Sheep looping with 0-Wolf.
# --> 1-Sheep looping with 1-Wolf.
# --> 1-Sheep looping with 2-Wolf.
# --> 1-Sheep looping with 3-Wolf.
# --> 1-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->1-Sheep has Store < 600 (y=44, x=40, store=430). will move normally and eat
# -->1-Sheep (y=44, x=40, store=430) before normal moving and eating
# -->1-Sheep (y=45, x=41, store=440) after normal moving and eating
# ___e2________ 1-Sheep moved normally and ate ___________
#
#
# -> ------------ 2 Sheep initialised -----------
# --> 2-Sheep looping with 0-Wolf.
# --> 2-Sheep looping with 1-Wolf.
# --> 2-Sheep looping with 2-Wolf.
# --> 2-Sheep looping with 3-Wolf.
# --> 2-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->2-Sheep has Store < 600 (y=104, x=14, store=230). will move normally and eat
# -->2-Sheep (y=104, x=14, store=230) before normal moving and eating
# -->2-Sheep (y=105, x=15, store=240) after normal moving and eating
# ___e2________ 2-Sheep moved normally and ate ___________
#
#
# -> ------------ 3 Sheep initialised -----------
# --> 3-Sheep looping with 0-Wolf.
# --> 3-Sheep looping with 1-Wolf.
# --> 3-Sheep looping with 2-Wolf.
# --> 3-Sheep looping with 3-Wolf.
# --> 3-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->3-Sheep has Store < 600 (y=37, x=45, store=120). will move normally and eat
# -->3-Sheep (y=37, x=45, store=120) before normal moving and eating
# -->3-Sheep (y=36, x=44, store=130) after normal moving and eating
# ___e2________ 3-Sheep moved normally and ate ___________
#
#
# -> ------------ 4 Sheep initialised -----------
# --> 4-Sheep looping with 0-Wolf.
# --> 4-Sheep looping with 1-Wolf.
# --> 4-Sheep looping with 2-Wolf.
# --> 4-Sheep looping with 3-Wolf.
# ---> d<md+... 4-Sheep noticed closest 3-Wolf ...
# ---> 4-Sheep (y=19, x=81, store=400) detected 3-Wolf (y=16, x=76, store=400) within d=5.830951894845301.
# --> 4-Sheep looping with 4-Wolf.
# -> CW FOUND.
# -> Before 4-Sheep (y=19, x=81, store=400) tries to run away from CW: (y=16, x=76, store=400).
# -> After 4-Sheep (y=21, x=84, store=400) tried to run away from CW (y=16, x=76, store=400).
# ___________ 4 Sheep tried to run away from CW ___________
#
#
# -> ------------ 5 Sheep initialised -----------
# --> 5-Sheep looping with 0-Wolf.
# --> 5-Sheep looping with 1-Wolf.
# --> 5-Sheep looping with 2-Wolf.
# --> 5-Sheep looping with 3-Wolf.
# --> 5-Sheep looping with 4-Wolf.
# --> NO CW FOUND.
# -->5-Sheep has Store < 600 (y=74, x=74, store=420). will move normally and eat
# -->5-Sheep (y=74, x=74, store=420) before normal moving and eating
# -->5-Sheep (y=73, x=75, store=430) after normal moving and eating
# ___e2________ 5-Sheep moved normally and ate ___________
#
#
# -> ------------ 6 Sheep initialised -----------
# --> 6-Sheep looping with 0-Wolf.
# --> 6-Sheep looping with 1-Wolf.
# --> 6-Sheep looping with 2-Wolf.
# --> 6-Sheep looping with 3-Wolf.
# --> 6-Sheep looping with 4-Wolf.
# ---> d<md+... 6-Sheep noticed closest 4-Wolf ...
# ---> 6-Sheep (y=16, x=27, store=400) detected 4-Wolf (y=19, x=24, store=200) within d=4.242640687119285.
# -> CW FOUND.
# -> Before 6-Sheep (y=16, x=27, store=400) tries to run away from CW: (y=19, x=24, store=200).
# -> After 6-Sheep (y=15, x=29, store=400) tried to run away from CW (y=19, x=24, store=200).
# ___________ 6 Sheep tried to run away from CW ___________
#
#
# -> ------------ 7 Sheep initialised -----------
# --> 7-Sheep looping with 0-Wolf.
# --> 7-Sheep looping with 1-Wolf.
# ---> d<md+... 7-Sheep noticed closest 1-Wolf ...
# ---> 7-Sheep (y=50, x=65, store=400) detected 1-Wolf (y=47, x=68, store=100) within d=4.242640687119285.
# --> 7-Sheep looping with 2-Wolf.
# --> 7-Sheep looping with 3-Wolf.
# --> 7-Sheep looping with 4-Wolf.
# -> CW FOUND.
# ...
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=278, x=293, store=266.66666666666663) -----------
# --> 0-Wolf has <=500 store (y=278, x=293, store=266.66666666666663). Tries to find food (sheep).
# ---> 0-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 0-Wolf (y=278, x=293, store=266.66666666666663) before normal moving
# -->else1 ends: 0-Wolf (y=277, x=292, store=266.66666666666663) after normal moving
# ....el1___________0-Wolf moved normally___________
#
# -> -----------1-Wolf initialised with (y=287, x=262, store=393.33333333333326) -----------
# --> 1-Wolf has <=500 store (y=287, x=262, store=393.33333333333326). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 1-Wolf (y=287, x=262, store=393.33333333333326) before normal moving
# -->else1 ends: 1-Wolf (y=286, x=261, store=393.33333333333326) after normal moving
# ....el1___________1-Wolf moved normally___________
#
# -> -----------2-Wolf initialised with (y=280, x=263, store=403.3333333333333) -----------
# --> 2-Wolf has <=500 store (y=280, x=263, store=403.3333333333333). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 2-Wolf (y=280, x=263, store=403.3333333333333) before normal moving
# -->else1 ends: 2-Wolf (y=281, x=262, store=403.3333333333333) after normal moving
# ....el1___________2-Wolf moved normally___________
#
# -> -----------3-Wolf initialised with (y=252, x=299, store=351.66666666666663) -----------
# --> 3-Wolf has <=500 store (y=252, x=299, store=351.66666666666663). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 3-Wolf (y=252, x=299, store=351.66666666666663) before normal moving
# -->else1 ends: 3-Wolf (y=251, x=298, store=351.66666666666663) after normal moving
# ....el1___________3-Wolf moved normally___________
#
# -> -----------4-Wolf initialised with (y=295, x=260, store=264.79166666666663) -----------
# --> 4-Wolf has <=500 store (y=295, x=260, store=264.79166666666663). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 4-Wolf (y=295, x=260, store=264.79166666666663) before normal moving
# -->else1 ends: 4-Wolf (y=294, x=259, store=264.79166666666663) after normal moving
# ....el1___________4-Wolf moved normally___________
#
# -> -----------5-Wolf initialised with (y=295, x=263, store=278.85416666666663) -----------
# --> 5-Wolf has <=500 store (y=295, x=263, store=278.85416666666663). Tries to find food (sheep).
# ---> 5-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 5-Wolf (y=295, x=263, store=278.85416666666663) before normal moving
# -->else1 ends: 5-Wolf (y=294, x=264, store=278.85416666666663) after normal moving
# ....el1___________5-Wolf moved normally___________
#
# -> -----------6-Wolf initialised with (y=298, x=265, store=578.0208333333333) -----------
# --> 6-Wolf has > 500 store (y=298, x=265, store=578.0208333333333) and p > 0.5. so will try to find CW to move closer or breed/fight.
# -> No CW found. although store >500 and p>0.5!
# --->else2 begins: 6-Wolf (y=298, x=265, store=578.0208333333333) before normal moving.
# --->else2 begins: 6-Wolf (y=299, x=266, store=578.0208333333333) after normal moving.
# ....el2...... 6-Wolf moved normally
# ________________Wolf Cycle Ends_________________
# *************** ITERATION NUMBER 198 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# --> 0-Sheep looping with 5-Wolf.
# --> 0-Sheep looping with 6-Wolf.
# --> NO CW FOUND.
# ->0-Sheep has Store > 600 (y=61, x=73, store=2350).
# -> NO CW FOUND. No CS Found or Share=False.
# -> 0-Sheep (y=61, x=73, store=2350) before normally moving and eating.
# -> 0-Sheep (y=62, x=72, store=2360) after normally moving and eating.
# ___e1________ 0-Sheep moved normally and ate ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=277, x=292, store=266.66666666666663) -----------
# --> 0-Wolf has <=500 store (y=277, x=292, store=266.66666666666663). Tries to find food (sheep).
# ---> 0-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 0-Wolf (y=277, x=292, store=266.66666666666663) before normal moving
# -->else1 ends: 0-Wolf (y=278, x=291, store=266.66666666666663) after normal moving
# ....el1___________0-Wolf moved normally___________
#
# -> -----------1-Wolf initialised with (y=286, x=261, store=393.33333333333326) -----------
# --> 1-Wolf has <=500 store (y=286, x=261, store=393.33333333333326). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 1-Wolf (y=286, x=261, store=393.33333333333326) before normal moving
# -->else1 ends: 1-Wolf (y=287, x=262, store=393.33333333333326) after normal moving
# ....el1___________1-Wolf moved normally___________
#
# -> -----------2-Wolf initialised with (y=281, x=262, store=403.3333333333333) -----------
# --> 2-Wolf has <=500 store (y=281, x=262, store=403.3333333333333). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 2-Wolf (y=281, x=262, store=403.3333333333333) before normal moving
# -->else1 ends: 2-Wolf (y=282, x=261, store=403.3333333333333) after normal moving
# ....el1___________2-Wolf moved normally___________
#
# -> -----------3-Wolf initialised with (y=251, x=298, store=351.66666666666663) -----------
# --> 3-Wolf has <=500 store (y=251, x=298, store=351.66666666666663). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 3-Wolf (y=251, x=298, store=351.66666666666663) before normal moving
# -->else1 ends: 3-Wolf (y=250, x=297, store=351.66666666666663) after normal moving
# ....el1___________3-Wolf moved normally___________
#
# -> -----------4-Wolf initialised with (y=294, x=259, store=264.79166666666663) -----------
# --> 4-Wolf has <=500 store (y=294, x=259, store=264.79166666666663). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 4-Wolf (y=294, x=259, store=264.79166666666663) before normal moving
# -->else1 ends: 4-Wolf (y=295, x=260, store=264.79166666666663) after normal moving
# ....el1___________4-Wolf moved normally___________
#
# -> -----------5-Wolf initialised with (y=294, x=264, store=278.85416666666663) -----------
# --> 5-Wolf has <=500 store (y=294, x=264, store=278.85416666666663). Tries to find food (sheep).
# ---> 5-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 5-Wolf (y=294, x=264, store=278.85416666666663) before normal moving
# -->else1 ends: 5-Wolf (y=293, x=263, store=278.85416666666663) after normal moving
# ....el1___________5-Wolf moved normally___________
#
# -> -----------6-Wolf initialised with (y=299, x=266, store=578.0208333333333) -----------
# --> 6-Wolf has > 500 store (y=299, x=266, store=578.0208333333333) and p > 0.5. so will try to find CW to move closer or breed/fight.
# -> No CW found. although store >500 and p>0.5!
# --->else2 begins: 6-Wolf (y=299, x=266, store=578.0208333333333) before normal moving.
# --->else2 begins: 6-Wolf (y=298, x=265, store=578.0208333333333) after normal moving.
# ....el2...... 6-Wolf moved normally
# ________________Wolf Cycle Ends_________________
#
# *************** ITERATION NUMBER 199 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# --> 0-Sheep looping with 5-Wolf.
# --> 0-Sheep looping with 6-Wolf.
# --> NO CW FOUND.
# ->0-Sheep has Store > 600 (y=62, x=72, store=2360).
# -> NO CW FOUND. No CS Found or Share=False.
# -> 0-Sheep (y=62, x=72, store=2360) before normally moving and eating.
# -> 0-Sheep (y=61, x=71, store=2370) after normally moving and eating.
# ___e1________ 0-Sheep moved normally and ate ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=278, x=291, store=266.66666666666663) -----------
# --> 0-Wolf has <=500 store (y=278, x=291, store=266.66666666666663). Tries to find food (sheep).
# ---> 0-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 0-Wolf (y=278, x=291, store=266.66666666666663) before normal moving
# -->else1 ends: 0-Wolf (y=279, x=290, store=266.66666666666663) after normal moving
# ....el1___________0-Wolf moved normally___________
#
# -> -----------1-Wolf initialised with (y=287, x=262, store=393.33333333333326) -----------
# --> 1-Wolf has <=500 store (y=287, x=262, store=393.33333333333326). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 1-Wolf (y=287, x=262, store=393.33333333333326) before normal moving
# -->else1 ends: 1-Wolf (y=288, x=263, store=393.33333333333326) after normal moving
# ....el1___________1-Wolf moved normally___________
#
# -> -----------2-Wolf initialised with (y=282, x=261, store=403.3333333333333) -----------
# --> 2-Wolf has <=500 store (y=282, x=261, store=403.3333333333333). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 2-Wolf (y=282, x=261, store=403.3333333333333) before normal moving
# -->else1 ends: 2-Wolf (y=281, x=262, store=403.3333333333333) after normal moving
# ....el1___________2-Wolf moved normally___________
#
# -> -----------3-Wolf initialised with (y=250, x=297, store=351.66666666666663) -----------
# --> 3-Wolf has <=500 store (y=250, x=297, store=351.66666666666663). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 3-Wolf (y=250, x=297, store=351.66666666666663) before normal moving
# -->else1 ends: 3-Wolf (y=249, x=296, store=351.66666666666663) after normal moving
# ....el1___________3-Wolf moved normally___________
#
# -> -----------4-Wolf initialised with (y=295, x=260, store=264.79166666666663) -----------
# --> 4-Wolf has <=500 store (y=295, x=260, store=264.79166666666663). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 4-Wolf (y=295, x=260, store=264.79166666666663) before normal moving
# -->else1 ends: 4-Wolf (y=296, x=259, store=264.79166666666663) after normal moving
# ....el1___________4-Wolf moved normally___________
#
# -> -----------5-Wolf initialised with (y=293, x=263, store=278.85416666666663) -----------
# --> 5-Wolf has <=500 store (y=293, x=263, store=278.85416666666663). Tries to find food (sheep).
# ---> 5-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 5-Wolf (y=293, x=263, store=278.85416666666663) before normal moving
# -->else1 ends: 5-Wolf (y=294, x=264, store=278.85416666666663) after normal moving
# ....el1___________5-Wolf moved normally___________
#
# -> -----------6-Wolf initialised with (y=298, x=265, store=578.0208333333333) -----------
# --> elif not satisfied
# --->else3 begins: 6-Wolf (y=298, x=265, store=578.0208333333333) before normal moving.
# --->else3 begins: 6-Wolf (y=297, x=266, store=578.0208333333333) after normal moving.
# ....el3...... 6-Wolf moved normally
# ________________Wolf Cycle Ends_________________
#
# *************** ITERATION NUMBER 200 ************
#
# -> ------------ 0 Sheep initialised -----------
# --> 0-Sheep looping with 0-Wolf.
# --> 0-Sheep looping with 1-Wolf.
# --> 0-Sheep looping with 2-Wolf.
# --> 0-Sheep looping with 3-Wolf.
# --> 0-Sheep looping with 4-Wolf.
# --> 0-Sheep looping with 5-Wolf.
# --> 0-Sheep looping with 6-Wolf.
# --> NO CW FOUND.
# ->0-Sheep has Store > 600 (y=61, x=71, store=2370).
# -> NO CW FOUND. No CS Found or Share=False.
# -> 0-Sheep (y=61, x=71, store=2370) before normally moving and eating.
# -> 0-Sheep (y=60, x=70, store=2380) after normally moving and eating.
# ___e1________ 0-Sheep moved normally and ate ___________
#
# ________________Sheep Cycle Ends________________
# ________________Wolf Cycle Begins________________
#
# -> -----------0-Wolf initialised with (y=279, x=290, store=266.66666666666663) -----------
# --> 0-Wolf has <=500 store (y=279, x=290, store=266.66666666666663). Tries to find food (sheep).
# ---> 0-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 0-Wolf (y=279, x=290, store=266.66666666666663) before normal moving
# -->else1 ends: 0-Wolf (y=280, x=291, store=266.66666666666663) after normal moving
# ....el1___________0-Wolf moved normally___________
#
# -> -----------1-Wolf initialised with (y=288, x=263, store=393.33333333333326) -----------
# --> 1-Wolf has <=500 store (y=288, x=263, store=393.33333333333326). Tries to find food (sheep).
# ---> 1-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 1-Wolf (y=288, x=263, store=393.33333333333326) before normal moving
# -->else1 ends: 1-Wolf (y=287, x=262, store=393.33333333333326) after normal moving
# ....el1___________1-Wolf moved normally___________
#
# -> -----------2-Wolf initialised with (y=281, x=262, store=403.3333333333333) -----------
# --> 2-Wolf has <=500 store (y=281, x=262, store=403.3333333333333). Tries to find food (sheep).
# ---> 2-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 2-Wolf (y=281, x=262, store=403.3333333333333) before normal moving
# -->else1 ends: 2-Wolf (y=282, x=263, store=403.3333333333333) after normal moving
# ....el1___________2-Wolf moved normally___________
#
# -> -----------3-Wolf initialised with (y=249, x=296, store=351.66666666666663) -----------
# --> 3-Wolf has <=500 store (y=249, x=296, store=351.66666666666663). Tries to find food (sheep).
# ---> 3-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 3-Wolf (y=249, x=296, store=351.66666666666663) before normal moving
# -->else1 ends: 3-Wolf (y=248, x=297, store=351.66666666666663) after normal moving
# ....el1___________3-Wolf moved normally___________
#
# -> -----------4-Wolf initialised with (y=296, x=259, store=264.79166666666663) -----------
# --> 4-Wolf has <=500 store (y=296, x=259, store=264.79166666666663). Tries to find food (sheep).
# ---> 4-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 4-Wolf (y=296, x=259, store=264.79166666666663) before normal moving
# -->else1 ends: 4-Wolf (y=295, x=260, store=264.79166666666663) after normal moving
# ....el1___________4-Wolf moved normally___________
#
# -> -----------5-Wolf initialised with (y=294, x=264, store=278.85416666666663) -----------
# --> 5-Wolf has <=500 store (y=294, x=264, store=278.85416666666663). Tries to find food (sheep).
# ---> 5-Wolf looping with 0-Sheep
# -> No CS found and store <500!
# -->else1 begins: 5-Wolf (y=294, x=264, store=278.85416666666663) before normal moving
# -->else1 ends: 5-Wolf (y=295, x=265, store=278.85416666666663) after normal moving
# ....el1___________5-Wolf moved normally___________
#
# -> -----------6-Wolf initialised with (y=297, x=266, store=578.0208333333333) -----------
# --> elif not satisfied
# --->else3 begins: 6-Wolf (y=297, x=266, store=578.0208333333333) before normal moving.
# --->else3 begins: 6-Wolf (y=296, x=265, store=578.0208333333333) after normal moving.
# ....el3...... 6-Wolf moved normally
# ________________Wolf Cycle Ends_________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f953a7441fba> in <module>
#     439 model_menu.add_command(label="Run model", command=run)
#     440
# --> 441 tkinter.mainloop()
#     442
#     443 # print((((146 - 214)**2) + ((139 - 244)**2))**0.5)
#
# C:\ProgramData\Anaconda3\lib\tkinter\__init__.py in mainloop(n)
#     591 def mainloop(n=0):
#     592     """Run the main loop of Tcl."""
# --> 593     _default_root.tk.mainloop(n)
#     594
#     595
#
# KeyboardInterrupt:
